# %% [markdown]
# ## Signal Synchronization and Cropping
#
# This script aligns and synchronizes kinematic landmarks, EMG signals, and video data for experimental analysis. It extracts timestamps, generates time vectors, crops and interpolates data streams, and synchronizes datasets across modalities. The script also visualizes the synchronization process and extracts relevant video segments for aligned intervals which are used later on in the Data analysis pipeline to crop the videos further into different task phases.

# %%
import os
import glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# --------------------------------------------------------------------
# Global Settings
# --------------------------------------------------------------------
BASE_DIR = r"C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data"
PARTICIPANTS = list(range(1, 9))


KINEMATIC_SUBDIR = os.path.join("Kinematic Landmarks", "3D Landmarks") 
MYO_SUBDIR       = os.path.join("Processed EMG Data", "Processed Myo")
OTB_SUBDIR       = os.path.join("Processed EMG Data", "Processed OTB+")
SYNC_FOLDERNAME  = "Synchronized Data"  

SAMPLE_RATES = {
    'kinematic': 31.2,   # For both hand and pose
    'myo':       375,
    'otb':       2000
}

TIME_WINDOW = 120  # seconds search area for matching data streams

# --------------------------------------------------------------------
# 1) Timestamp Extraction 
# --------------------------------------------------------------------
def parse_kin_filename(time_str_npy):
    """
    Helper to parse time strings from filenames.
    Examples:
        '11_37_57.592' => 11*3600 + 37*60 + 57.592
        '11_37_57.592_3D' => 11*3600 + 37*60 + 57.592
    """
    time_str = time_str_npy.replace(".npy", "")
    parts = time_str.split("_")
    if len(parts) < 3:
        return None
    hh, mm, ss_milli = parts[0], parts[1], parts[2]
    milli = 0
    if '.' in ss_milli:
        ss_part, milli_part = ss_milli.split('.')
        try:
            milli = int(milli_part.ljust(3, '0')[:3])
        except ValueError:
            return None
    else:
        ss_part = ss_milli
    try:
        hours   = int(hh)
        minutes = int(mm)
        seconds = int(ss_part)
    except ValueError:
        return None
    return hours*3600 + minutes*60 + seconds + milli/1000

def extract_timestamp_hand(filename):
    if not filename.startswith("hand_landmarks_"):
        return None
    # Remove the prefix and the '_3D.npy' suffix
    time_str = filename[len("hand_landmarks_"):].replace("_3D.npy", "")
    return parse_kin_filename(time_str)

def extract_timestamp_pose(filename):
    if not filename.startswith("pose_landmarks_"):
        return None
    # Remove the prefix and the '_3D.npy' suffix
    time_str = filename[len("pose_landmarks_"):].replace("_3D.npy", "")
    return parse_kin_filename(time_str)


def extract_timestamp_myo(filename):
    """
    Expects: processed_myo_YYYY-MM-DD_10-43-32.688_normalized_envelope.npy
    => parse "10-43-32.688" => total secs from midnight
    """
    base = os.path.basename(filename)
    parts = base.split("_")
    if len(parts) < 4:
        return None
    time_part = parts[3]
    time_part = time_part.split("_")[0]
    if '-' not in time_part:
        return None
    hhmmss = time_part.split('-')
    if len(hhmmss) != 3:
        return None
    hh, mm, ss_milli = hhmmss
    milli = 0
    if '.' in ss_milli:
        ss_part, milli_part = ss_milli.split('.')
        try:
            milli = int(milli_part.ljust(3, '0')[:3])
        except ValueError:
            return None
    else:
        ss_part = ss_milli
    try:
        hours   = int(hh)
        minutes = int(mm)
        seconds = int(ss_part)
    except ValueError:
        return None
    return hours*3600 + minutes*60 + seconds + milli/1000

def extract_timestamp_otb(filename):
    """
    Expects: processed_emg_data_YYYYMMDD_104327483_normalized_emg.npy
    => parse "104327483" => total secs from midnight
    """
    base = os.path.basename(filename)
    parts = base.split("_")
    if len(parts) < 5:
        return None
    time_str = parts[4]  # e.g. "104327483"
    if len(time_str) < 6:
        return None
    try:
        hh = int(time_str[0:2])
        mm = int(time_str[2:4])
        ss = int(time_str[4:6])
        milli_str = time_str[6:]
        if not milli_str:
            milli = 0
        else:
            milli = int(milli_str.ljust(3, '0')[:3])
    except ValueError:
        return None
    return hh*3600 + mm*60 + ss + milli/1000.0

# --------------------------------------------------------------------
# 2) Time Vector Generation
# --------------------------------------------------------------------
def build_time_vector(start_sec, n_samples, sr):
    """
    length = n_samples => [start_sec + 0/sr, ..., start_sec + (n_samples-1)/sr]
    """
    return np.round(start_sec + np.arange(n_samples)/sr, 6)

# --------------------------------------------------------------------
# 3) Crop & Interpolate to match Sample Rates
# --------------------------------------------------------------------
def crop_data(time_vec, data_arr, start_t, end_t):
    idx_start = np.searchsorted(time_vec, start_t, side='left')
    idx_end   = np.searchsorted(time_vec, end_t, side='right')
    idx_start = max(0, idx_start)
    idx_end   = min(len(time_vec), idx_end)
    return time_vec[idx_start:idx_end], data_arr[idx_start:idx_end]

def interpolate_data(old_time, old_data, new_time):
    if old_time.size < 2 or old_data.shape[0] < 2:
        num_feats = old_data.shape[1] if old_data.ndim > 1 else 1
        return np.zeros((len(new_time), num_feats))
    if old_time.size != old_data.shape[0]:
        print("[WARN] Time vs data mismatch!", old_time.size, old_data.shape)
        num_feats = old_data.shape[1] if old_data.ndim > 1 else 1
        return np.zeros((len(new_time), num_feats))
    if old_data.ndim == 1:
        old_data = old_data.reshape(-1,1)
    num_features = old_data.shape[1]
    new_data = np.zeros((len(new_time), num_features))
    for i in range(num_features):
        f = interp1d(old_time, old_data[:, i], 
                     kind='linear', bounds_error=False,
                     fill_value='extrapolate')
        new_data[:, i] = f(new_time)
    return new_data

# --------------------------------------------------------------------
# 4) Load & Reshape Hand / Pose
# --------------------------------------------------------------------
def load_hand(file_path, sr=31.2):
    """
    [frame_idx, landmark_idx, X, Y, Z]
    => (n_frames, n_landmarks*3)
    => time_vec => shape (n_frames,)
    """
    arr = np.load(file_path)
    filename = os.path.basename(file_path)
    start_ts = extract_timestamp_hand(filename)
    if start_ts is None:
        start_ts = 0.0

    # --- Updated Shape Check ---
    if arr.shape[1] != 5:
        print(f"[WARN] {filename} => not (N,5). skipping hand.")
        return np.array([]), np.array([[]]), start_ts

    frame_idxs = arr[:,0].astype(int)
    lmk_idxs   = arr[:,1].astype(int)  
    n_frames   = frame_idxs.max()+1
    n_landmarks= lmk_idxs.max()+1
    data_3d = np.zeros((n_frames,n_landmarks,3), dtype=np.float32)
    for row in arr:
        f = int(row[0])
        l = int(row[1])  
        x, y, z = row[2], row[3], row[4]  
        data_3d[f, l] = [x, y, z]
    hand_data = data_3d.reshape(n_frames, -1)
    hand_time = build_time_vector(start_ts, n_frames, sr)
    return hand_time, hand_data, start_ts

def load_pose(file_path, sr=31.2):
    """
    [frame_idx, RSx, RSy, RSz, REx, REy, REz]
    => (n_frames,6)
    => time_vec => shape(n_frames,)
    """
    arr = np.load(file_path)
    filename = os.path.basename(file_path)
    start_ts = extract_timestamp_pose(filename)
    if start_ts is None:
        start_ts = 0.0

    # --- Updated Shape Check ---
    if arr.shape[1] != 7:
        print(f"[WARN] {filename} => not (N,7). skipping pose.")
        return np.array([]), np.array([[]]), start_ts

    frame_idxs = arr[:,0].astype(int)
    n_frames   = frame_idxs.max()+1
    pose_data  = np.zeros((n_frames,6), dtype=np.float32)
    for row in arr:
        f = int(row[0])
        RSx, RSy, RSz = row[1], row[2], row[3]  
        REx, REy, REz = row[4], row[5], row[6] 
        pose_data[f] = [RSx, RSy, RSz, REx, REy, REz]
    pose_time = build_time_vector(start_ts, n_frames, sr)
    return pose_time, pose_data, start_ts

# --------------------------------------------------------------------
# 5) Debug Plot
# --------------------------------------------------------------------
def debug_cropping_and_plot_all_channels(
    hand_t, hand_d,
    pose_t, pose_d,
    myo_t,  myo_d,
    otb_t,  otb_d,
    global_start, global_end,
    out_plot_dir,
    plot_basename="plot_all_channels"
):
    """
    Plots *all channels* for each signal (Hand, Pose, Myo, OTB) in separate subplots,
    places legends on the right, and saves the figure to out_plot_dir.

    hand_d, pose_d, myo_d, otb_d: shape (N, C) or (N,) => will be forced to (N,C).
    The time axis in the plot is shifted so that 'global_start' => 0 for display.

    Subplot Titles & Y-Labels:
      - Hand Landmarks => "Position (px)"
      - Elbow & Shoulder Landmarks => "Position (px)"
      - Myo Normalized Envelope => "Amplitude [%]"
      - OTB+ Normalized Envelope => "Amplitude [%]"
    """

    print(f"\n--- Cropping from {global_start:.3f}s to {global_end:.3f}s ---")
    print(f"Hand: {len(hand_t)} samples, shape={hand_d.shape}")
    print(f"Pose: {len(pose_t)} samples, shape={pose_d.shape}")
    print(f"Myo:  {len(myo_t)} samples, shape={myo_d.shape}")
    print(f"OTB:  {len(otb_t)} samples, shape={otb_d.shape}")

    # Ensure output folder exists
    os.makedirs(out_plot_dir, exist_ok=True)

    # 1) Force each data array to 2D
    def ensure_2d(arr):
        arr = np.asarray(arr)
        if arr.ndim == 1:
            return arr.reshape(-1, 1)
        return arr

    hand_d = ensure_2d(hand_d)
    pose_d = ensure_2d(pose_d)
    myo_d  = ensure_2d(myo_d)
    otb_d  = ensure_2d(otb_d)

    # 2) Shift times so the plot starts at 0
    ht0 = hand_t - global_start
    pt0 = pose_t - global_start
    mt0 = myo_t  - global_start
    ot0 = otb_t  - global_start

    # ----------------------------------------------------
    # 3) Helper to generate short labels for each channel
    # ----------------------------------------------------
    def get_labels(signal_type, n_channels):
        """
        Returns a list of short labels for each channel based on the signal_type.
        Adjust muscle_map or other lists as needed.
        """
        if signal_type == 'hand':
            # Each landmark has 3 dims (X, Y, Z)
            # => channel c -> landmark index = c//3, dim = c%3
            labels = []
            dims = ["X","Y","Z"]
            for c in range(n_channels):
                lmk = c // 3
                d   = dims[c % 3]
                labels.append(f"H{lmk+1}{d}")  # e.g. H1X, H1Y, H1Z, H2X, ...
            return labels

        elif signal_type == 'pose':
            # Mapping Landmark Dimensions for Shoulder and Elbow
            if n_channels == 6:
                return ["ShX","ShY","ShZ","EbX","EbY","EbZ"]
            else:
                return [f"Pch{c}" for c in range(n_channels)]

        elif signal_type == 'myo':
            # Mapping Muscles to Myo Channel
            muscle_map = ["ECU","EDC","ECR","BIC","TRI"]
            labels = []
            for c in range(n_channels):
                if c < len(muscle_map):
                    labels.append(muscle_map[c])
                else:
                    labels.append(f"Myo{c}") 
            return labels

        else: 
            return [f"OTB{c+1}" for c in range(n_channels)]

    # ----------------------------------------------------
    # 4) Function to plot each set of channels
    # ----------------------------------------------------
    def plot_all_ch(ax, time_vec, data_2d, title_str, ylabel_str, signal_type):
        """Plot each channel of data_2d with a short label."""
        if data_2d.size == 0:
            ax.set_title(f"{title_str} (No Data)")
            return

        ax.set_title(title_str, fontsize=11)
        colors = plt.cm.jet(np.linspace(0, 1, data_2d.shape[1]))

        # get short labels for this signal type
        ch_labels = get_labels(signal_type, data_2d.shape[1])

        for ch in range(data_2d.shape[1]):
            ax.plot(time_vec, data_2d[:, ch],
                    color=colors[ch],
                    label=ch_labels[ch])

        ax.set_ylabel(ylabel_str, fontsize=10)
        # Place legend on the right side, aligned to the top of the axes
        ax.legend(
            loc='upper left',
            bbox_to_anchor=(1.02, 1.0),
            borderaxespad=0.,
            fontsize='small',
            ncol=9
        )

    # ----------------------------------------------------
    # 5) Create subplots and plot each signal
    # ----------------------------------------------------
    fig, axs = plt.subplots(4, 1, figsize=(12, 14), sharex=True)

    # HAND
    plot_all_ch(axs[0], ht0, hand_d,
                "Hand Landmarks", "Position (px)",
                signal_type="hand")

    # POSE
    plot_all_ch(axs[1], pt0, pose_d,
                "Elbow & Shoulder Landmarks", "Position (px)",
                signal_type="pose")

    # MYO
    plot_all_ch(axs[2], mt0, myo_d,
                "Myo Normalized Envelope", "Amplitude [%]",
                signal_type="myo")

    # OTB+
    plot_all_ch(axs[3], ot0, otb_d,
                "OTB+ Normalized Envelope", "Amplitude [%]",
                signal_type="otb")

    axs[3].set_xlabel("Time from Overlap Start (s)", fontsize=10)

    # ----------------------------------------------------
    # 6) Layout & Saving
    # ----------------------------------------------------
    plt.tight_layout(rect=[0, 0, 0.65, 1])  # widen right margin for legend
    save_path = os.path.join(out_plot_dir, f"{plot_basename}.png")
    plt.savefig(save_path, dpi=150, bbox_inches='tight')
    plt.close(fig)

    print(f"Plot saved to: {save_path}")

# --------------------------------------------------------------------
# 6) Video Cropping
# --------------------------------------------------------------------
def parse_time_from_string(time_str):
    """
    Helper: parse e.g. "10_42_26.955" => 10*3600 + 42*60 + 26.955
    Returns None on failure.
    """
    parts = time_str.split("_")
    if len(parts) < 3:
        return None
    hh, mm, ss_milli = parts[0], parts[1], parts[2]
    milli = 0
    if "." in ss_milli:
        ss_part, milli_part = ss_milli.split(".")
        try:
            milli = int(milli_part.ljust(3, '0')[:3])
        except ValueError:
            return None
    else:
        ss_part = ss_milli
    try:
        hours = int(hh)
        mins  = int(mm)
        secs  = int(ss_part)
    except ValueError:
        return None
    return hours * 3600 + mins * 60 + secs + milli / 1000.0

def parse_video_recording_timestamp(video_path):
    """
    Try to extract the recording's absolute start time (seconds from midnight)
    by checking the folder name 'recording_10_42_26.955' or
    'annotated_videos_10_42_26.955'.
    
    Returns the float timestamp from midnight, or None if not found.
    """
    video_dir = os.path.dirname(video_path) 
    parent_dir = os.path.dirname(video_dir)  

    # 1) Try to parse from "recording_10_42_26.955"
    recording_base = os.path.basename(parent_dir)
    if recording_base.startswith("recording_"):
        time_str = recording_base[len("recording_"):]
        ts = parse_time_from_string(time_str)
        if ts is not None:
            return ts

    # 2) Otherwise, try from "annotated_videos_10_42_26.955"
    annotated_base = os.path.basename(video_dir)
    if annotated_base.startswith("annotated_videos_"):
        time_str = annotated_base[len("annotated_videos_"):]
        ts = parse_time_from_string(time_str)
        if ts is not None:
            return ts

    return None 

def crop_video(in_path, start_s, end_s, out_path):
    """
    Crops the video in `in_path` from local time start_s to end_s (seconds),
    writing result to `out_path`.
    """
    cap = cv2.VideoCapture(in_path)
    if not cap.isOpened():
        print(f"[ERROR] Could not open video: {in_path}")
        return False

    fps = cap.get(cv2.CAP_PROP_FPS)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    print(f"[DEBUG] crop_video -> FPS={fps:.2f}, total_frames={total_frames}, "
          f"start_s={start_s:.3f}, end_s={end_s:.3f}")

    start_frame = int(round(start_s * fps))
    end_frame   = int(round(end_s   * fps))

    print(f"[DEBUG] crop_video -> start_frame={start_frame}, end_frame={end_frame}")

    # If out of range
    if start_frame < 0:
        start_frame = 0
    if end_frame > total_frames:
        end_frame = total_frames

    # If no overlap
    if end_frame <= start_frame:
        print(f"[WARN] No overlap: start_frame={start_frame}, end_frame={end_frame} => skip cropping.")
        cap.release()
        return False

    fourcc = cv2.VideoWriter_fourcc(*"XVID")
    out_vid = cv2.VideoWriter(out_path, fourcc, fps, (w, h))
    if not out_vid.isOpened():
        print(f"[ERROR] Could not open VideoWriter for output: {out_path}")
        cap.release()
        return False

    # Read frames and write only [start_frame, end_frame)
    frame_idx = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break  # out of frames

        if start_frame <= frame_idx < end_frame:
            out_vid.write(frame)
        elif frame_idx >= end_frame:
            break

        frame_idx += 1

    out_vid.release()
    cap.release()
    return True

def videoCropping(participant_dir, matches_info):
    cropped_vids_dir = os.path.join(participant_dir, "Synchronized Data", "Cropped Videos")
    os.makedirs(cropped_vids_dir, exist_ok=True)

    # 1) Collect all .avi
    pattern = os.path.join(
        participant_dir,
        "Camera Data Timestamped",
        "recording_sessions",
        "**",
        "annotated_videos_*",
        "annotated_video_camera_0.avi"
    )
    all_video_paths = glob.glob(pattern, recursive=True)
    if not all_video_paths:
        print(f"[WARN] No annotated videos found under {participant_dir}.")
        return

    # 2) Build list of { 'path': ..., 'video_start_ts': ... }
    video_entries = []
    for vp in all_video_paths:
        # --- Skip calibration: 
        if "calibration" in vp.lower():
            # This path is for calibration – skip
            continue

        vts = parse_video_recording_timestamp(vp)
        if vts is not None:
            video_entries.append({'path': vp, 'video_start_ts': vts})

    # Sort by the absolute start time of the video
    video_entries.sort(key=lambda x: x['video_start_ts'])

    # Sort matches by the match timestamp
    matches_sorted = sorted(matches_info, key=lambda m: m['timestamp_sec'])

    # Pair Matches 1:1 in chronological order:
    n_videos = len(video_entries)
    n_matches = len(matches_sorted)
    n_to_crop = min(n_videos, n_matches)

    print(f"[INFO] Found {n_matches} matches and {n_videos} videos. Will crop {n_to_crop} videos.\n")

    for i in range(n_to_crop):
        match_i = matches_sorted[i]
        video_i = video_entries[i]

        match_num    = match_i["match_number"]
        global_start = match_i["global_start"]
        global_end   = match_i["global_end"]
        vid_path     = video_i["path"]
        vid_start_ts = video_i["video_start_ts"]

        # Convert from absolute times to local times
        local_start = global_start - vid_start_ts
        local_end   = global_end   - vid_start_ts

        out_vid_path = os.path.join(
            cropped_vids_dir,
            f"match_{match_num:02d}_cropped_camera_0.avi"
        )

        print(f"[INFO] Cropping video for Match #{match_num}:")
        print(f"       Input : {vid_path}")
        print(f"       Output: {out_vid_path}")
        print(f"       Global Start: {global_start:.3f}s, Global End: {global_end:.3f}s")
        print(f"       Video Start : {vid_start_ts:.3f}s => Local Start: {local_start:.3f}s, Local End: {local_end:.3f}s")

        success = crop_video(
            in_path=vid_path,
            start_s=local_start,
            end_s=local_end,
            out_path=out_vid_path
        )

        if success:
            print("      => Cropping succeeded.\n")
        else:
            print("      => Cropping failed or was skipped.\n")

# --------------------------------------------------------------------
# 7) Main
# --------------------------------------------------------------------
def main():
    TIME_WINDOW = 120  # seconds
    MAX_USE = 2        # Maximum number of times a file can be reused

    # For each participant separately, create a list that tracks all match info
    for p in PARTICIPANTS:
        participant_str = f"P({p})"
        participant_dir = os.path.join(BASE_DIR, participant_str)
        if not os.path.isdir(participant_dir):
            print(f"No folder for {participant_str}, skipping.")
            continue

        # -------------------------------
        # 1) Build dicts for Hand & Pose
        # -------------------------------
        hand_dict = {}
        pose_dict = {}
        kin_dir = os.path.join(participant_dir, KINEMATIC_SUBDIR)
        all_kin = glob.glob(os.path.join(kin_dir, "*.npy"))
        for fp in all_kin:
            fn = os.path.basename(fp)
            if fn.startswith("hand_landmarks_"):
                suffix = fn[len("hand_landmarks_"):]
                hand_dict[suffix] = fp
            elif fn.startswith("pose_landmarks_"):
                suffix = fn[len("pose_landmarks_"):]
                pose_dict[suffix] = fp

        # -------------------------------
        # 2) Gather Myo and OTB+ files
        # -------------------------------
        myo_files = []
        pat_myo = os.path.join(participant_dir, MYO_SUBDIR, "processed_myo_*_normalized_envelope.npy")
        for f in glob.glob(pat_myo):
            ts = extract_timestamp_myo(os.path.basename(f))
            if ts is not None:
                myo_files.append({'path': f, 'timestamp': ts})

        otb_files = []
        pat_otb = os.path.join(participant_dir, OTB_SUBDIR, "processed_emg_data_*_normalized_emg.npy")
        for f in glob.glob(pat_otb):
            ts = extract_timestamp_otb(os.path.basename(f))
            if ts is not None:
                otb_files.append({'path': f, 'timestamp': ts})

        myo_files.sort(key=lambda x: x['timestamp'])
        otb_files.sort(key=lambda x: x['timestamp'])

        # If no Myo or OTB+ files, skip
        if not myo_files or not otb_files:
            print(f"Skipping {participant_str}, missing Myo or OTB.")
            continue

        print(f"\n=== {participant_str}: Found {len(hand_dict)} hand, {len(pose_dict)} pose, "
              f"{len(myo_files)} Myo, {len(otb_files)} OTB ===")

        # -------------------------------
        # 3) Prepare output directories
        # -------------------------------
        out_dir = os.path.join(participant_dir, SYNC_FOLDERNAME)
        os.makedirs(out_dir, exist_ok=True)

        plot_dir = os.path.join(out_dir, "Plots of Synchronized Data")
        os.makedirs(plot_dir, exist_ok=True)

        # -------------------------------
        # 4) Usage Tracking & Sync Loop
        # -------------------------------
        used_myo = {}  # key: myo_idx, value: usage_count
        used_otb = {}  # key: otb_idx, value: usage_count
        sync_count = 0

        # This list will hold all the matches for current participant
        all_matches = []

        all_suffixes = sorted(set(hand_dict.keys()) | set(pose_dict.keys()))
        for suffix in all_suffixes:
            # 4.1) Load Hand / Pose for this suffix
            hand_time = np.array([])
            hand_data = np.array([[]])
            hts = None

            if suffix in hand_dict:
                htime, hdata, hts_ = load_hand(hand_dict[suffix], sr=SAMPLE_RATES['kinematic'])
                if htime.size >= 2 and hdata.shape[0] >= 2:
                    hand_time = htime
                    hand_data = hdata
                    hts = hts_
                else:
                    print(f"[WARN] Hand data for suffix {suffix} is insufficient.")

            pose_time = np.array([])
            pose_data = np.array([[]])
            pts = None

            if suffix in pose_dict:
                ptime, pdata, pts_ = load_pose(pose_dict[suffix], sr=SAMPLE_RATES['kinematic'])
                if ptime.size >= 2 and pdata.shape[0] >= 2:
                    pose_time = ptime
                    pose_data = pdata
                    pts = pts_
                else:
                    print(f"[WARN] Pose data for suffix {suffix} is insufficient.")

            # Skip if neither hand nor pose has enough data
            if hand_time.size < 2 and pose_time.size < 2:
                continue

            # 4.2) Determine a base k_ts from hand & pose
            if hts is not None and pts is not None:
                k_ts = min(hts, pts)  # or max(hts, pts)
            elif hts is not None:
                k_ts = hts
            elif pts is not None:
                k_ts = pts
            else:
                k_ts = 0.0

            # 4.3) Build candidate Myo files within TIME_WINDOW
            myo_candidates = [
                (abs(m['timestamp'] - k_ts), idx, m)
                for idx, m in enumerate(myo_files)
                if abs(m['timestamp'] - k_ts) <= TIME_WINDOW and used_myo.get(idx, 0) < MAX_USE
            ]
            myo_candidates.sort(key=lambda x: x[0])  # nearest first

            if not myo_candidates:
                # No suitable Myo => skip suffix
                continue

            # 4.4) Try each Myo candidate until OTB+ match is found
            pair_found = False
            for myo_diff, myo_idx, myo_f in myo_candidates:

                # 4.4.1) Build candidate OTB+ files
                otb_candidates = [
                    (abs(o['timestamp'] - k_ts), oidx, o)
                    for oidx, o in enumerate(otb_files)
                    if abs(o['timestamp'] - k_ts) <= TIME_WINDOW and used_otb.get(oidx, 0) < MAX_USE
                ]
                otb_candidates.sort(key=lambda x: x[0])

                if not otb_candidates:
                    
                    continue

                # 4.4.2) Use the nearest OTB candidate
                otb_diff, otb_idx, otb_f = otb_candidates[0]

                # 4.5) Load Myo & OTB
                print(f"\nSuffix {suffix}:")
                print(f"Selected Myo file: {myo_f['path']} (Timestamp: {myo_f['timestamp']} sec)")
                print(f"Selected OTB+ file: {otb_f['path']} (Timestamp: {otb_f['timestamp']} sec)")

                myo_arr = np.load(myo_f['path'])
                myo_time = build_time_vector(myo_f['timestamp'], len(myo_arr), SAMPLE_RATES['myo'])

                otb_arr = np.load(otb_f['path'])
                if (otb_arr.ndim == 2) and (otb_arr.shape[0] < otb_arr.shape[1]):
                    otb_arr = otb_arr.T
                otb_time = build_time_vector(otb_f['timestamp'], len(otb_arr), SAMPLE_RATES['otb'])
                print("\n--- Debug: Data Stream Info BEFORE Cropping ---")

                print(f"Hand: start={hand_time[0]:.3f}, end={hand_time[-1]:.3f}, total_samples={len(hand_time)}")
                print(f"Pose: start={pose_time[0]:.3f}, end={pose_time[-1]:.3f}, total_samples={len(pose_time)}")
                print(f"Myo : start={myo_time[0]:.3f}, end={myo_time[-1]:.3f}, total_samples={len(myo_time)}")
                print(f"OTB : start={otb_time[0]:.3f}, end={otb_time[-1]:.3f}, total_samples={len(otb_time)}")

                # 4.6) Compute overlap
                def get_minmax(tv):
                    return (tv[0], tv[-1]) if len(tv) >= 2 else (np.inf, -np.inf)

                hstart, hend = get_minmax(hand_time)
                pstart, pend = get_minmax(pose_time)
                mstart, mend = get_minmax(myo_time)
                ostart, oend = get_minmax(otb_time)

                global_start = max(hstart, pstart, mstart, ostart)
                global_end   = min(hend, pend, mend, oend)
                print("\n--- Debug: Overlap Computation ---")
                print(f"global_start={global_start:.3f}, global_end={global_end:.3f}, "
                    f"overlap_duration={(global_end - global_start):.3f}")

                if global_end <= global_start:
                    print("No overlap => skip this Myo-OTB+ pair.")
                    continue

                # 4.7) Crop
                h_t_crop, h_d_crop = crop_data(hand_time, hand_data, global_start, global_end)
                p_t_crop, p_d_crop = crop_data(pose_time, pose_data, global_start, global_end)
                m_t_crop, m_d_crop = crop_data(myo_time,  myo_arr,   global_start, global_end)
                o_t_crop, o_d_crop = crop_data(otb_time,  otb_arr,   global_start, global_end)
                

                # 4.8) Interpolate to OTB+ reference
                ref_time  = o_t_crop
                hand_sync = interpolate_data(h_t_crop, h_d_crop, ref_time)
                pose_sync = interpolate_data(p_t_crop, p_d_crop, ref_time)
                myo_sync  = interpolate_data(m_t_crop, m_d_crop, ref_time)
                otb_sync  = o_d_crop  # no interpolation needed

                # 4.9) Plot
                plot_basename = f"{suffix}_all_channels"
                debug_cropping_and_plot_all_channels(
                    ref_time,   hand_sync,
                    ref_time,   pose_sync,
                    ref_time,   myo_sync,
                    ref_time,   otb_sync,
                    global_start, global_end,
                    out_plot_dir=plot_dir,
                    plot_basename=plot_basename
                )

                if len(ref_time) < 2:
                    print("OTB+ data too short => skip")
                    continue

                # 4.10) Combine
                if (hand_sync.shape[1] == 0) and (pose_sync.shape[1] == 0):
                    print("No hand or pose => skip.")
                    continue
                elif hand_sync.shape[1] == 0:
                    combined_kin = pose_sync
                elif pose_sync.shape[1] == 0:
                    combined_kin = hand_sync
                else:
                    combined_kin = np.hstack([hand_sync, pose_sync])

                # 4.11) Save
                sync_count += 1
                base_out = f"match_{sync_count:02d}"

                final_time = ref_time - ref_time[0]
                np.save(os.path.join(out_dir, f"{base_out}_time.npy"), final_time)
                np.save(os.path.join(out_dir, f"{base_out}_kin.npy"),  combined_kin)
                np.save(os.path.join(out_dir, f"{base_out}_myo.npy"),  myo_sync)
                np.save(os.path.join(out_dir, f"{base_out}_otb.npy"),  otb_sync)

                used_myo[myo_idx] = used_myo.get(myo_idx, 0) + 1
                used_otb[otb_idx] = used_otb.get(otb_idx, 0) + 1

                duration = final_time[-1] if len(final_time) > 0 else 0
                print(f"Match {sync_count:02d}: Overlap => {len(ref_time)} samples, duration ~{duration:.3f}s")

                #Parse the suffix to get absolute time from midnight
                ts_kin = parse_kin_filename(suffix.replace(".npy", ""))
                if ts_kin is None:
                    ts_kin = 0.0

                # Save the match info for video cropping
                all_matches.append({
                    "match_number": sync_count,
                    "suffix": suffix,
                    "timestamp_sec": ts_kin,    # parsed from e.g. "10_42_26.955"
                    "global_start": global_start, # e.g. 38546.955
                    "global_end":   global_end
                })

                pair_found = True
                break  

            if not pair_found:
                print(f"No valid Myo-OTB+ pair found within {TIME_WINDOW}s for suffix {suffix}. Skipping.")

        # Done with all suffixes
        if sync_count == 0:
            print(f"No successful overlap matches for {participant_str}.")
        else:
            print(f"Total successful matches for {participant_str}: {sync_count}")
            # After matching, crop the videos
            videoCropping(participant_dir, all_matches)

if __name__=="__main__":
    main()
# Out:
# === P(5): Found 24 hand, 24 pose, 24 Myo, 24 OTB ===
#
# Suffix 12_28_54.090_3D.npy:
# Selected Myo file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed Myo\processed_myo_2024-10-31_12-28-41.259_normalized_envelope.npy (Timestamp: 44921.259 sec)
# Selected OTB+ file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed OTB+\processed_emg_data_20241031_122849737_normalized_emg.npy (Timestamp: 44929.737 sec)
#
# --- Debug: Data Stream Info BEFORE Cropping ---
# Hand: start=44934.090, end=44949.891, total_samples=494
# Pose: start=44934.090, end=44949.891, total_samples=494
# Myo : start=44921.259, end=44955.643, total_samples=12895
# OTB : start=44929.737, end=44954.537, total_samples=49600
#
# --- Debug: Overlap Computation ---
# global_start=44934.090, global_end=44949.891, overlap_duration=15.801
#
# --- Cropping from 44934.090s to 44949.891s ---
# Hand: 31603 samples, shape=(31603, 63)
# Pose: 31603 samples, shape=(31603, 6)
# Myo:  31603 samples, shape=(31603, 5)
# OTB:  31603 samples, shape=(31603, 112)
# C:\Users\schmi\AppData\Local\Temp\ipykernel_12020\1952413981.py:390: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout(rect=[0, 0, 0.65, 1])  # widen right margin for legend
# Plot saved to: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Plots of Synchronized Data\12_28_54.090_3D.npy_all_channels.png
# Match 01: Overlap => 31603 samples, duration ~15.801s
#
# Suffix 12_29_47.627_3D.npy:
# Selected Myo file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed Myo\processed_myo_2024-10-31_12-29-31.393_normalized_envelope.npy (Timestamp: 44971.393 sec)
# Selected OTB+ file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed OTB+\processed_emg_data_20241031_122944440_normalized_emg.npy (Timestamp: 44984.44 sec)
#
# --- Debug: Data Stream Info BEFORE Cropping ---
# Hand: start=44987.627, end=45002.306, total_samples=459
# Pose: start=44987.627, end=45002.306, total_samples=459
# Myo : start=44971.393, end=45017.836, total_samples=17417
# OTB : start=44984.440, end=45007.240, total_samples=45600
#
# --- Debug: Overlap Computation ---
# global_start=44987.627, global_end=45002.306, overlap_duration=14.679
#
# --- Cropping from 44987.627s to 45002.306s ---
# Hand: 29359 samples, shape=(29359, 63)
# Pose: 29359 samples, shape=(29359, 6)
# Myo:  29359 samples, shape=(29359, 5)
# OTB:  29359 samples, shape=(29359, 112)
# Plot saved to: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Plots of Synchronized Data\12_29_47.627_3D.npy_all_channels.png
# Match 02: Overlap => 29359 samples, duration ~14.679s
#
# Suffix 12_31_34.353_3D.npy:
# Selected Myo file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed Myo\processed_myo_2024-10-31_12-31-21.235_normalized_envelope.npy (Timestamp: 45081.235 sec)
# Selected OTB+ file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed OTB+\processed_emg_data_20241031_123128175_normalized_emg.npy (Timestamp: 45088.175 sec)
#
# --- Debug: Data Stream Info BEFORE Cropping ---
# Hand: start=45094.353, end=45108.103, total_samples=430
# Pose: start=45094.353, end=45108.103, total_samples=430
# Myo : start=45081.235, end=45111.432, total_samples=11325
# OTB : start=45088.175, end=45115.974, total_samples=55600
#
# --- Debug: Overlap Computation ---
# global_start=45094.353, global_end=45108.103, overlap_duration=13.750
#
# --- Cropping from 45094.353s to 45108.103s ---
# Hand: 27501 samples, shape=(27501, 63)
# Pose: 27501 samples, shape=(27501, 6)
# Myo:  27501 samples, shape=(27501, 5)
# OTB:  27501 samples, shape=(27501, 112)
# Plot saved to: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Plots of Synchronized Data\12_31_34.353_3D.npy_all_channels.png
# Match 03: Overlap => 27501 samples, duration ~13.750s
#
# Suffix 12_32_22.773_3D.npy:
# Selected Myo file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed Myo\processed_myo_2024-10-31_12-32-13.608_normalized_envelope.npy (Timestamp: 45133.608 sec)
# Selected OTB+ file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed OTB+\processed_emg_data_20241031_123219691_normalized_emg.npy (Timestamp: 45139.691 sec)
#
# --- Debug: Data Stream Info BEFORE Cropping ---
# Hand: start=45142.773, end=45162.260, total_samples=609
# Pose: start=45142.773, end=45162.260, total_samples=609
# Myo : start=45133.608, end=45160.581, total_samples=10116
# OTB : start=45139.691, end=45167.490, total_samples=55600
#
# --- Debug: Overlap Computation ---
# global_start=45142.773, global_end=45160.581, overlap_duration=17.808
#
# --- Cropping from 45142.773s to 45160.581s ---
# Hand: 35617 samples, shape=(35617, 63)
# Pose: 35617 samples, shape=(35617, 6)
# Myo:  35617 samples, shape=(35617, 5)
# OTB:  35617 samples, shape=(35617, 112)
# Plot saved to: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Plots of Synchronized Data\12_32_22.773_3D.npy_all_channels.png
# Match 04: Overlap => 35617 samples, duration ~17.808s
#
# Suffix 12_33_53.169_3D.npy:
# Selected Myo file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed Myo\processed_myo_2024-10-31_12-33-43.718_normalized_envelope.npy (Timestamp: 45223.718 sec)
# Selected OTB+ file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed OTB+\processed_emg_data_20241031_123349409_normalized_emg.npy (Timestamp: 45229.409 sec)
#
# --- Debug: Data Stream Info BEFORE Cropping ---
# Hand: start=45233.169, end=45249.804, total_samples=520
# Pose: start=45233.169, end=45249.804, total_samples=520
# Myo : start=45223.718, end=45254.827, total_samples=11667
# OTB : start=45229.409, end=45253.209, total_samples=47600
#
# --- Debug: Overlap Computation ---
# global_start=45233.169, global_end=45249.804, overlap_duration=16.635
#
# --- Cropping from 45233.169s to 45249.804s ---
# Hand: 33270 samples, shape=(33270, 63)
# Pose: 33270 samples, shape=(33270, 6)
# Myo:  33270 samples, shape=(33270, 5)
# OTB:  33270 samples, shape=(33270, 112)
# Plot saved to: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Plots of Synchronized Data\12_33_53.169_3D.npy_all_channels.png
# Match 05: Overlap => 33270 samples, duration ~16.635s
#
# Suffix 12_34_44.792_3D.npy:
# Selected Myo file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed Myo\processed_myo_2024-10-31_12-34-33.280_normalized_envelope.npy (Timestamp: 45273.28 sec)
# Selected OTB+ file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed OTB+\processed_emg_data_20241031_123438989_normalized_emg.npy (Timestamp: 45278.989 sec)
#
# --- Debug: Data Stream Info BEFORE Cropping ---
# Hand: start=45284.792, end=45297.677, total_samples=403
# Pose: start=45284.792, end=45297.677, total_samples=403
# Myo : start=45273.280, end=45303.029, total_samples=11157
# OTB : start=45278.989, end=45301.789, total_samples=45600
#
# --- Debug: Overlap Computation ---
# global_start=45284.792, global_end=45297.677, overlap_duration=12.885
#
# --- Cropping from 45284.792s to 45297.677s ---
# Hand: 25770 samples, shape=(25770, 63)
# Pose: 25770 samples, shape=(25770, 6)
# Myo:  25770 samples, shape=(25770, 5)
# OTB:  25770 samples, shape=(25770, 112)
# Plot saved to: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Plots of Synchronized Data\12_34_44.792_3D.npy_all_channels.png
# Match 06: Overlap => 25770 samples, duration ~12.885s
#
# Suffix 12_37_23.477_3D.npy:
# Selected Myo file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed Myo\processed_myo_2024-10-31_12-37-12.411_normalized_envelope.npy (Timestamp: 45432.411 sec)
# Selected OTB+ file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed OTB+\processed_emg_data_20241031_123718937_normalized_emg.npy (Timestamp: 45438.937 sec)
#
# --- Debug: Data Stream Info BEFORE Cropping ---
# Hand: start=45443.477, end=45459.406, total_samples=498
# Pose: start=45443.477, end=45459.406, total_samples=498
# Myo : start=45432.411, end=45477.478, total_samples=16901
# OTB : start=45438.937, end=45465.736, total_samples=53600
#
# --- Debug: Overlap Computation ---
# global_start=45443.477, global_end=45459.406, overlap_duration=15.929
#
# --- Cropping from 45443.477s to 45459.406s ---
# Hand: 31859 samples, shape=(31859, 63)
# Pose: 31859 samples, shape=(31859, 6)
# Myo:  31859 samples, shape=(31859, 5)
# OTB:  31859 samples, shape=(31859, 112)
# Plot saved to: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Plots of Synchronized Data\12_37_23.477_3D.npy_all_channels.png
# Match 07: Overlap => 31859 samples, duration ~15.929s
#
# Suffix 12_38_31.310_3D.npy:
# Selected Myo file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed Myo\processed_myo_2024-10-31_12-38-21.441_normalized_envelope.npy (Timestamp: 45501.441 sec)
# Selected OTB+ file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed OTB+\processed_emg_data_20241031_123827675_normalized_emg.npy (Timestamp: 45507.675 sec)
#
# --- Debug: Data Stream Info BEFORE Cropping ---
# Hand: start=45511.310, end=45524.739, total_samples=420
# Pose: start=45511.310, end=45524.739, total_samples=420
# Myo : start=45501.441, end=45532.833, total_samples=11773
# OTB : start=45507.675, end=45528.474, total_samples=41600
#
# --- Debug: Overlap Computation ---
# global_start=45511.310, global_end=45524.739, overlap_duration=13.429
#
# --- Cropping from 45511.310s to 45524.739s ---
# Hand: 26859 samples, shape=(26859, 63)
# Pose: 26859 samples, shape=(26859, 6)
# Myo:  26859 samples, shape=(26859, 5)
# OTB:  26859 samples, shape=(26859, 112)
# Plot saved to: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Plots of Synchronized Data\12_38_31.310_3D.npy_all_channels.png
# Match 08: Overlap => 26859 samples, duration ~13.429s
#
# Suffix 12_42_30.501_3D.npy:
# Selected Myo file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed Myo\processed_myo_2024-10-31_12-42-19.745_normalized_envelope.npy (Timestamp: 45739.745 sec)
# Selected OTB+ file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed OTB+\processed_emg_data_20241031_124226453_normalized_emg.npy (Timestamp: 45746.453 sec)
#
# --- Debug: Data Stream Info BEFORE Cropping ---
# Hand: start=45750.501, end=45765.565, total_samples=471
# Pose: start=45750.501, end=45765.565, total_samples=471
# Myo : start=45739.745, end=45768.694, total_samples=10857
# OTB : start=45746.453, end=45774.253, total_samples=55600
#
# --- Debug: Overlap Computation ---
# global_start=45750.501, global_end=45765.565, overlap_duration=15.064
#
# --- Cropping from 45750.501s to 45765.565s ---
# Hand: 30129 samples, shape=(30129, 63)
# Pose: 30129 samples, shape=(30129, 6)
# Myo:  30129 samples, shape=(30129, 5)
# OTB:  30129 samples, shape=(30129, 112)
# Plot saved to: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Plots of Synchronized Data\12_42_30.501_3D.npy_all_channels.png
# Match 09: Overlap => 30129 samples, duration ~15.064s
#
# Suffix 12_43_21.587_3D.npy:
# Selected Myo file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed Myo\processed_myo_2024-10-31_12-43-10.145_normalized_envelope.npy (Timestamp: 45790.145 sec)
# Selected OTB+ file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed OTB+\processed_emg_data_20241031_124316650_normalized_emg.npy (Timestamp: 45796.65 sec)
#
# --- Debug: Data Stream Info BEFORE Cropping ---
# Hand: start=45801.587, end=45816.972, total_samples=481
# Pose: start=45801.587, end=45816.972, total_samples=481
# Myo : start=45790.145, end=45834.300, total_samples=16559
# OTB : start=45796.650, end=45821.450, total_samples=49600
#
# --- Debug: Overlap Computation ---
# global_start=45801.587, global_end=45816.972, overlap_duration=15.385
#
# --- Cropping from 45801.587s to 45816.972s ---
# Hand: 30770 samples, shape=(30770, 63)
# Pose: 30770 samples, shape=(30770, 6)
# Myo:  30770 samples, shape=(30770, 5)
# OTB:  30770 samples, shape=(30770, 112)
# Plot saved to: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Plots of Synchronized Data\12_43_21.587_3D.npy_all_channels.png
# Match 10: Overlap => 30770 samples, duration ~15.385s
#
# Suffix 12_44_58.299_3D.npy:
# Selected Myo file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed Myo\processed_myo_2024-10-31_12-44-47.116_normalized_envelope.npy (Timestamp: 45887.116 sec)
# Selected OTB+ file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed OTB+\processed_emg_data_20241031_124454116_normalized_emg.npy (Timestamp: 45894.116 sec)
#
# --- Debug: Data Stream Info BEFORE Cropping ---
# Hand: start=45898.299, end=45915.254, total_samples=530
# Pose: start=45898.299, end=45915.254, total_samples=530
# Myo : start=45887.116, end=45920.865, total_samples=12657
# OTB : start=45894.116, end=45918.916, total_samples=49600
#
# --- Debug: Overlap Computation ---
# global_start=45898.299, global_end=45915.254, overlap_duration=16.955
#
# --- Cropping from 45898.299s to 45915.254s ---
# Hand: 33911 samples, shape=(33911, 63)
# Pose: 33911 samples, shape=(33911, 6)
# Myo:  33911 samples, shape=(33911, 5)
# OTB:  33911 samples, shape=(33911, 112)
# Plot saved to: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Plots of Synchronized Data\12_44_58.299_3D.npy_all_channels.png
# Match 11: Overlap => 33911 samples, duration ~16.955s
#
# Suffix 12_46_04.983_3D.npy:
# Selected Myo file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed Myo\processed_myo_2024-10-31_12-45-49.996_normalized_envelope.npy (Timestamp: 45949.996 sec)
# Selected OTB+ file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed OTB+\processed_emg_data_20241031_124558467_normalized_emg.npy (Timestamp: 45958.467 sec)
#
# --- Debug: Data Stream Info BEFORE Cropping ---
# Hand: start=45964.983, end=45982.675, total_samples=553
# Pose: start=45964.983, end=45982.675, total_samples=553
# Myo : start=45949.996, end=45984.596, total_samples=12976
# OTB : start=45958.467, end=45989.266, total_samples=61600
#
# --- Debug: Overlap Computation ---
# global_start=45964.983, global_end=45982.675, overlap_duration=17.692
#
# --- Cropping from 45964.983s to 45982.675s ---
# Hand: 35385 samples, shape=(35385, 63)
# Pose: 35385 samples, shape=(35385, 6)
# Myo:  35385 samples, shape=(35385, 5)
# OTB:  35385 samples, shape=(35385, 112)
# Plot saved to: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Plots of Synchronized Data\12_46_04.983_3D.npy_all_channels.png
# Match 12: Overlap => 35385 samples, duration ~17.692s
#
# Suffix 12_47_51.729_3D.npy:
# Selected Myo file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed Myo\processed_myo_2024-10-31_12-47-38.364_normalized_envelope.npy (Timestamp: 46058.364 sec)
# Selected OTB+ file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed OTB+\processed_emg_data_20241031_124745333_normalized_emg.npy (Timestamp: 46065.333 sec)
#
# --- Debug: Data Stream Info BEFORE Cropping ---
# Hand: start=46071.729, end=46088.171, total_samples=514
# Pose: start=46071.729, end=46088.171, total_samples=514
# Myo : start=46058.364, end=46095.428, total_samples=13900
# OTB : start=46065.333, end=46092.132, total_samples=53600
#
# --- Debug: Overlap Computation ---
# global_start=46071.729, global_end=46088.171, overlap_duration=16.442
#
# --- Cropping from 46071.729s to 46088.171s ---
# Hand: 32885 samples, shape=(32885, 63)
# Pose: 32885 samples, shape=(32885, 6)
# Myo:  32885 samples, shape=(32885, 5)
# OTB:  32885 samples, shape=(32885, 112)
# Plot saved to: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Plots of Synchronized Data\12_47_51.729_3D.npy_all_channels.png
# Match 13: Overlap => 32885 samples, duration ~16.442s
#
# Suffix 12_48_57.867_3D.npy:
# Selected Myo file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed Myo\processed_myo_2024-10-31_12-48-43.259_normalized_envelope.npy (Timestamp: 46123.259 sec)
# Selected OTB+ file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed OTB+\processed_emg_data_20241031_124853524_normalized_emg.npy (Timestamp: 46133.524 sec)
#
# --- Debug: Data Stream Info BEFORE Cropping ---
# Hand: start=46137.867, end=46155.495, total_samples=551
# Pose: start=46137.867, end=46155.495, total_samples=551
# Myo : start=46123.259, end=46182.526, total_samples=22226
# OTB : start=46133.524, end=46160.323, total_samples=53600
#
# --- Debug: Overlap Computation ---
# global_start=46137.867, global_end=46155.495, overlap_duration=17.628
#
# --- Cropping from 46137.867s to 46155.495s ---
# Hand: 35257 samples, shape=(35257, 63)
# Pose: 35257 samples, shape=(35257, 6)
# Myo:  35257 samples, shape=(35257, 5)
# OTB:  35257 samples, shape=(35257, 112)
# Plot saved to: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Plots of Synchronized Data\12_48_57.867_3D.npy_all_channels.png
# Match 14: Overlap => 35257 samples, duration ~17.628s
#
# Suffix 12_51_03.968_3D.npy:
# Selected Myo file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed Myo\processed_myo_2024-10-31_12-50-53.286_normalized_envelope.npy (Timestamp: 46253.286 sec)
# Selected OTB+ file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed OTB+\processed_emg_data_20241031_125058987_normalized_emg.npy (Timestamp: 46258.987 sec)
#
# --- Debug: Data Stream Info BEFORE Cropping ---
# Hand: start=46263.968, end=46282.910, total_samples=592
# Pose: start=46263.968, end=46282.910, total_samples=592
# Myo : start=46253.286, end=46301.369, total_samples=18032
# OTB : start=46258.987, end=46288.787, total_samples=59600
#
# --- Debug: Overlap Computation ---
# global_start=46263.968, global_end=46282.910, overlap_duration=18.942
#
# --- Cropping from 46263.968s to 46282.910s ---
# Hand: 37885 samples, shape=(37885, 63)
# Pose: 37885 samples, shape=(37885, 6)
# Myo:  37885 samples, shape=(37885, 5)
# OTB:  37885 samples, shape=(37885, 112)
# Plot saved to: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Plots of Synchronized Data\12_51_03.968_3D.npy_all_channels.png
# Match 15: Overlap => 37885 samples, duration ~18.942s
#
# Suffix 12_54_10.009_3D.npy:
# Selected Myo file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed Myo\processed_myo_2024-10-31_12-53-58.828_normalized_envelope.npy (Timestamp: 46438.828 sec)
# Selected OTB+ file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed OTB+\processed_emg_data_20241031_125404946_normalized_emg.npy (Timestamp: 46444.946 sec)
#
# --- Debug: Data Stream Info BEFORE Cropping ---
# Hand: start=46450.009, end=46465.490, total_samples=484
# Pose: start=46450.009, end=46465.490, total_samples=484
# Myo : start=46438.828, end=46473.247, total_samples=12908
# OTB : start=46444.946, end=46470.745, total_samples=51600
#
# --- Debug: Overlap Computation ---
# global_start=46450.009, global_end=46465.490, overlap_duration=15.481
#
# --- Cropping from 46450.009s to 46465.490s ---
# Hand: 30962 samples, shape=(30962, 63)
# Pose: 30962 samples, shape=(30962, 6)
# Myo:  30962 samples, shape=(30962, 5)
# OTB:  30962 samples, shape=(30962, 112)
# Plot saved to: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Plots of Synchronized Data\12_54_10.009_3D.npy_all_channels.png
# Match 16: Overlap => 30962 samples, duration ~15.481s
#
# Suffix 12_56_28.033_3D.npy:
# Selected Myo file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed Myo\processed_myo_2024-10-31_12-56-09.758_normalized_envelope.npy (Timestamp: 46569.758 sec)
# Selected OTB+ file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed OTB+\processed_emg_data_20241031_125616439_normalized_emg.npy (Timestamp: 46576.439 sec)
#
# --- Debug: Data Stream Info BEFORE Cropping ---
# Hand: start=46588.033, end=46605.020, total_samples=531
# Pose: start=46588.033, end=46605.020, total_samples=531
# Myo : start=46569.758, end=46620.859, total_samples=19164
# OTB : start=46576.439, end=46608.238, total_samples=63600
#
# --- Debug: Overlap Computation ---
# global_start=46588.033, global_end=46605.020, overlap_duration=16.987
#
# --- Cropping from 46588.033s to 46605.020s ---
# Hand: 33975 samples, shape=(33975, 63)
# Pose: 33975 samples, shape=(33975, 6)
# Myo:  33975 samples, shape=(33975, 5)
# OTB:  33975 samples, shape=(33975, 112)
# Plot saved to: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Plots of Synchronized Data\12_56_28.033_3D.npy_all_channels.png
# Match 17: Overlap => 33975 samples, duration ~16.987s
#
# Suffix 12_57_45.360_3D.npy:
# Selected Myo file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed Myo\processed_myo_2024-10-31_12-57-08.755_normalized_envelope.npy (Timestamp: 46628.755 sec)
# Selected OTB+ file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed OTB+\processed_emg_data_20241031_125741243_normalized_emg.npy (Timestamp: 46661.243 sec)
#
# --- Debug: Data Stream Info BEFORE Cropping ---
# Hand: start=46665.360, end=46684.078, total_samples=585
# Pose: start=46665.360, end=46684.078, total_samples=585
# Myo : start=46628.755, end=46695.595, total_samples=25066
# OTB : start=46661.243, end=46691.043, total_samples=59600
#
# --- Debug: Overlap Computation ---
# global_start=46665.360, global_end=46684.078, overlap_duration=18.718
#
# --- Cropping from 46665.360s to 46684.078s ---
# Hand: 37436 samples, shape=(37436, 63)
# Pose: 37436 samples, shape=(37436, 6)
# Myo:  37436 samples, shape=(37436, 5)
# OTB:  37436 samples, shape=(37436, 112)
# Plot saved to: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Plots of Synchronized Data\12_57_45.360_3D.npy_all_channels.png
# Match 18: Overlap => 37436 samples, duration ~18.717s
#
# Suffix 12_59_25.443_3D.npy:
# Selected Myo file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed Myo\processed_myo_2024-10-31_12-59-14.978_normalized_envelope.npy (Timestamp: 46754.978 sec)
# Selected OTB+ file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed OTB+\processed_emg_data_20241031_125922715_normalized_emg.npy (Timestamp: 46762.715 sec)
#
# --- Debug: Data Stream Info BEFORE Cropping ---
# Hand: start=46765.443, end=46781.917, total_samples=515
# Pose: start=46765.443, end=46781.917, total_samples=515
# Myo : start=46754.978, end=46787.629, total_samples=12245
# OTB : start=46762.715, end=46785.514, total_samples=45600
#
# --- Debug: Overlap Computation ---
# global_start=46765.443, global_end=46781.917, overlap_duration=16.474
#
# --- Cropping from 46765.443s to 46781.917s ---
# Hand: 32949 samples, shape=(32949, 63)
# Pose: 32949 samples, shape=(32949, 6)
# Myo:  32949 samples, shape=(32949, 5)
# OTB:  32949 samples, shape=(32949, 112)
# Plot saved to: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Plots of Synchronized Data\12_59_25.443_3D.npy_all_channels.png
# Match 19: Overlap => 32949 samples, duration ~16.474s
#
# Suffix 13_00_19.853_3D.npy:
# Selected Myo file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed Myo\processed_myo_2024-10-31_13-00-09.550_normalized_envelope.npy (Timestamp: 46809.55 sec)
# Selected OTB+ file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed OTB+\processed_emg_data_20241031_130015560_normalized_emg.npy (Timestamp: 46815.56 sec)
#
# --- Debug: Data Stream Info BEFORE Cropping ---
# Hand: start=46819.853, end=46838.507, total_samples=583
# Pose: start=46819.853, end=46838.507, total_samples=583
# Myo : start=46809.550, end=46844.286, total_samples=13027
# OTB : start=46815.560, end=46842.359, total_samples=53600
#
# --- Debug: Overlap Computation ---
# global_start=46819.853, global_end=46838.507, overlap_duration=18.654
#
# --- Cropping from 46819.853s to 46838.507s ---
# Hand: 37308 samples, shape=(37308, 63)
# Pose: 37308 samples, shape=(37308, 6)
# Myo:  37308 samples, shape=(37308, 5)
# OTB:  37308 samples, shape=(37308, 112)
# Plot saved to: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Plots of Synchronized Data\13_00_19.853_3D.npy_all_channels.png
# Match 20: Overlap => 37308 samples, duration ~18.654s
#
# Suffix 13_02_20.468_3D.npy:
# Selected Myo file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed Myo\processed_myo_2024-10-31_13-01-58.642_normalized_envelope.npy (Timestamp: 46918.642 sec)
# Selected OTB+ file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed OTB+\processed_emg_data_20241031_130216697_normalized_emg.npy (Timestamp: 46936.697 sec)
#
# --- Debug: Data Stream Info BEFORE Cropping ---
# Hand: start=46940.468, end=46957.199, total_samples=523
# Pose: start=46940.468, end=46957.199, total_samples=523
# Myo : start=46918.642, end=46963.786, total_samples=16930
# OTB : start=46936.697, end=46959.497, total_samples=45600
#
# --- Debug: Overlap Computation ---
# global_start=46940.468, global_end=46957.199, overlap_duration=16.731
#
# --- Cropping from 46940.468s to 46957.199s ---
# Hand: 33462 samples, shape=(33462, 63)
# Pose: 33462 samples, shape=(33462, 6)
# Myo:  33462 samples, shape=(33462, 5)
# OTB:  33462 samples, shape=(33462, 112)
# Plot saved to: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Plots of Synchronized Data\13_02_20.468_3D.npy_all_channels.png
# Match 21: Overlap => 33462 samples, duration ~16.730s
#
# Suffix 13_03_22.442_3D.npy:
# Selected Myo file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed Myo\processed_myo_2024-10-31_13-03-10.341_normalized_envelope.npy (Timestamp: 46990.341 sec)
# Selected OTB+ file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed OTB+\processed_emg_data_20241031_130318073_normalized_emg.npy (Timestamp: 46998.073 sec)
#
# --- Debug: Data Stream Info BEFORE Cropping ---
# Hand: start=47002.442, end=47021.096, total_samples=583
# Pose: start=47002.442, end=47021.096, total_samples=583
# Myo : start=46990.341, end=47030.525, total_samples=15070
# OTB : start=46998.073, end=47024.872, total_samples=53600
#
# --- Debug: Overlap Computation ---
# global_start=47002.442, global_end=47021.096, overlap_duration=18.654
#
# --- Cropping from 47002.442s to 47021.096s ---
# Hand: 37308 samples, shape=(37308, 63)
# Pose: 37308 samples, shape=(37308, 6)
# Myo:  37308 samples, shape=(37308, 5)
# OTB:  37308 samples, shape=(37308, 112)
# Plot saved to: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Plots of Synchronized Data\13_03_22.442_3D.npy_all_channels.png
# Match 22: Overlap => 37308 samples, duration ~18.654s
#
# Suffix 13_05_35.785_3D.npy:
# Selected Myo file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed Myo\processed_myo_2024-10-31_13-05-26.049_normalized_envelope.npy (Timestamp: 47126.049 sec)
# Selected OTB+ file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed OTB+\processed_emg_data_20241031_130532874_normalized_emg.npy (Timestamp: 47132.874 sec)
#
# --- Debug: Data Stream Info BEFORE Cropping ---
# Hand: start=47135.785, end=47153.253, total_samples=546
# Pose: start=47135.785, end=47153.253, total_samples=546
# Myo : start=47126.049, end=47160.462, total_samples=12906
# OTB : start=47132.874, end=47157.673, total_samples=49600
#
# --- Debug: Overlap Computation ---
# global_start=47135.785, global_end=47153.253, overlap_duration=17.468
#
# --- Cropping from 47135.785s to 47153.253s ---
# Hand: 34936 samples, shape=(34936, 63)
# Pose: 34936 samples, shape=(34936, 6)
# Myo:  34936 samples, shape=(34936, 5)
# OTB:  34936 samples, shape=(34936, 112)
# Plot saved to: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Plots of Synchronized Data\13_05_35.785_3D.npy_all_channels.png
# Match 23: Overlap => 34936 samples, duration ~17.467s
#
# Suffix 13_06_32.203_3D.npy:
# Selected Myo file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed Myo\processed_myo_2024-10-31_13-06-22.474_normalized_envelope.npy (Timestamp: 47182.474 sec)
# Selected OTB+ file: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Processed EMG Data\Processed OTB+\processed_emg_data_20241031_130629128_normalized_emg.npy (Timestamp: 47189.128 sec)
#
# --- Debug: Data Stream Info BEFORE Cropping ---
# Hand: start=47192.203, end=47207.043, total_samples=464
# Pose: start=47192.203, end=47207.043, total_samples=464
# Myo : start=47182.474, end=47210.917, total_samples=10667
# OTB : start=47189.128, end=47208.927, total_samples=39600
#
# --- Debug: Overlap Computation ---
# global_start=47192.203, global_end=47207.043, overlap_duration=14.840
#
# --- Cropping from 47192.203s to 47207.043s ---
# Hand: 29680 samples, shape=(29680, 63)
# Pose: 29680 samples, shape=(29680, 6)
# Myo:  29680 samples, shape=(29680, 5)
# OTB:  29680 samples, shape=(29680, 112)
# Plot saved to: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Plots of Synchronized Data\13_06_32.203_3D.npy_all_channels.png
# Match 24: Overlap => 29680 samples, duration ~14.840s
# Total successful matches for P(5): 24
# [INFO] Found 24 matches and 24 videos. Will crop 24 videos.
#
# [INFO] Cropping video for Match #1:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Camera Data Timestamped\recording_sessions\session_2024-10-31_12_26_32\recording_12_28_54.090\annotated_videos_12_28_54.090\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Cropped Videos\match_01_cropped_camera_0.avi
#        Global Start: 44934.090s, Global End: 44949.891s
#        Video Start : 44934.090s => Local Start: 0.000s, Local End: 15.801s
# [DEBUG] crop_video -> FPS=31.20, total_frames=494, start_s=0.000, end_s=15.801
# [DEBUG] crop_video -> start_frame=0, end_frame=493
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #2:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Camera Data Timestamped\recording_sessions\session_2024-10-31_12_26_32\recording_12_29_47.627\annotated_videos_12_29_47.627\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Cropped Videos\match_02_cropped_camera_0.avi
#        Global Start: 44987.627s, Global End: 45002.306s
#        Video Start : 44987.627s => Local Start: 0.000s, Local End: 14.679s
# [DEBUG] crop_video -> FPS=31.20, total_frames=459, start_s=0.000, end_s=14.679
# [DEBUG] crop_video -> start_frame=0, end_frame=458
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #3:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Camera Data Timestamped\recording_sessions\session_2024-10-31_12_26_32\recording_12_31_34.353\annotated_videos_12_31_34.353\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Cropped Videos\match_03_cropped_camera_0.avi
#        Global Start: 45094.353s, Global End: 45108.103s
#        Video Start : 45094.353s => Local Start: 0.000s, Local End: 13.750s
# [DEBUG] crop_video -> FPS=31.20, total_frames=430, start_s=0.000, end_s=13.750
# [DEBUG] crop_video -> start_frame=0, end_frame=429
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #4:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Camera Data Timestamped\recording_sessions\session_2024-10-31_12_26_32\recording_12_32_22.773\annotated_videos_12_32_22.773\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Cropped Videos\match_04_cropped_camera_0.avi
#        Global Start: 45142.773s, Global End: 45160.581s
#        Video Start : 45142.773s => Local Start: 0.000s, Local End: 17.808s
# [DEBUG] crop_video -> FPS=31.20, total_frames=609, start_s=0.000, end_s=17.808
# [DEBUG] crop_video -> start_frame=0, end_frame=556
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #5:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Camera Data Timestamped\recording_sessions\session_2024-10-31_12_26_32\recording_12_33_53.169\annotated_videos_12_33_53.169\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Cropped Videos\match_05_cropped_camera_0.avi
#        Global Start: 45233.169s, Global End: 45249.804s
#        Video Start : 45233.169s => Local Start: 0.000s, Local End: 16.635s
# [DEBUG] crop_video -> FPS=31.20, total_frames=520, start_s=0.000, end_s=16.635
# [DEBUG] crop_video -> start_frame=0, end_frame=519
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #6:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Camera Data Timestamped\recording_sessions\session_2024-10-31_12_26_32\recording_12_34_44.792\annotated_videos_12_34_44.792\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Cropped Videos\match_06_cropped_camera_0.avi
#        Global Start: 45284.792s, Global End: 45297.677s
#        Video Start : 45284.792s => Local Start: 0.000s, Local End: 12.885s
# [DEBUG] crop_video -> FPS=31.20, total_frames=403, start_s=0.000, end_s=12.885
# [DEBUG] crop_video -> start_frame=0, end_frame=402
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #7:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Camera Data Timestamped\recording_sessions\session_2024-10-31_12_26_32\recording_12_37_23.477\annotated_videos_12_37_23.477\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Cropped Videos\match_07_cropped_camera_0.avi
#        Global Start: 45443.477s, Global End: 45459.406s
#        Video Start : 45443.477s => Local Start: 0.000s, Local End: 15.929s
# [DEBUG] crop_video -> FPS=31.20, total_frames=498, start_s=0.000, end_s=15.929
# [DEBUG] crop_video -> start_frame=0, end_frame=497
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #8:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Camera Data Timestamped\recording_sessions\session_2024-10-31_12_26_32\recording_12_38_31.310\annotated_videos_12_38_31.310\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Cropped Videos\match_08_cropped_camera_0.avi
#        Global Start: 45511.310s, Global End: 45524.739s
#        Video Start : 45511.310s => Local Start: 0.000s, Local End: 13.429s
# [DEBUG] crop_video -> FPS=31.20, total_frames=420, start_s=0.000, end_s=13.429
# [DEBUG] crop_video -> start_frame=0, end_frame=419
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #9:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Camera Data Timestamped\recording_sessions\session_2024-10-31_12_26_32\recording_12_42_30.501\annotated_videos_12_42_30.501\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Cropped Videos\match_09_cropped_camera_0.avi
#        Global Start: 45750.501s, Global End: 45765.565s
#        Video Start : 45750.501s => Local Start: 0.000s, Local End: 15.064s
# [DEBUG] crop_video -> FPS=31.20, total_frames=471, start_s=0.000, end_s=15.064
# [DEBUG] crop_video -> start_frame=0, end_frame=470
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #10:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Camera Data Timestamped\recording_sessions\session_2024-10-31_12_26_32\recording_12_43_21.587\annotated_videos_12_43_21.587\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Cropped Videos\match_10_cropped_camera_0.avi
#        Global Start: 45801.587s, Global End: 45816.972s
#        Video Start : 45801.587s => Local Start: 0.000s, Local End: 15.385s
# [DEBUG] crop_video -> FPS=31.20, total_frames=481, start_s=0.000, end_s=15.385
# [DEBUG] crop_video -> start_frame=0, end_frame=480
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #11:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Camera Data Timestamped\recording_sessions\session_2024-10-31_12_26_32\recording_12_44_58.299\annotated_videos_12_44_58.299\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Cropped Videos\match_11_cropped_camera_0.avi
#        Global Start: 45898.299s, Global End: 45915.254s
#        Video Start : 45898.299s => Local Start: 0.000s, Local End: 16.955s
# [DEBUG] crop_video -> FPS=31.20, total_frames=530, start_s=0.000, end_s=16.955
# [DEBUG] crop_video -> start_frame=0, end_frame=529
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #12:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Camera Data Timestamped\recording_sessions\session_2024-10-31_12_26_32\recording_12_46_04.983\annotated_videos_12_46_04.983\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Cropped Videos\match_12_cropped_camera_0.avi
#        Global Start: 45964.983s, Global End: 45982.675s
#        Video Start : 45964.983s => Local Start: 0.000s, Local End: 17.692s
# [DEBUG] crop_video -> FPS=31.20, total_frames=553, start_s=0.000, end_s=17.692
# [DEBUG] crop_video -> start_frame=0, end_frame=552
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #13:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Camera Data Timestamped\recording_sessions\session_2024-10-31_12_26_32\recording_12_47_51.729\annotated_videos_12_47_51.729\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Cropped Videos\match_13_cropped_camera_0.avi
#        Global Start: 46071.729s, Global End: 46088.171s
#        Video Start : 46071.729s => Local Start: 0.000s, Local End: 16.442s
# [DEBUG] crop_video -> FPS=31.20, total_frames=514, start_s=0.000, end_s=16.442
# [DEBUG] crop_video -> start_frame=0, end_frame=513
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #14:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Camera Data Timestamped\recording_sessions\session_2024-10-31_12_26_32\recording_12_48_57.867\annotated_videos_12_48_57.867\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Cropped Videos\match_14_cropped_camera_0.avi
#        Global Start: 46137.867s, Global End: 46155.495s
#        Video Start : 46137.867s => Local Start: 0.000s, Local End: 17.628s
# [DEBUG] crop_video -> FPS=31.20, total_frames=551, start_s=0.000, end_s=17.628
# [DEBUG] crop_video -> start_frame=0, end_frame=550
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #15:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Camera Data Timestamped\recording_sessions\session_2024-10-31_12_26_32\recording_12_51_03.968\annotated_videos_12_51_03.968\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Cropped Videos\match_15_cropped_camera_0.avi
#        Global Start: 46263.968s, Global End: 46282.910s
#        Video Start : 46263.968s => Local Start: 0.000s, Local End: 18.942s
# [DEBUG] crop_video -> FPS=31.20, total_frames=592, start_s=0.000, end_s=18.942
# [DEBUG] crop_video -> start_frame=0, end_frame=591
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #16:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Camera Data Timestamped\recording_sessions\session_2024-10-31_12_26_32\recording_12_54_10.009\annotated_videos_12_54_10.009\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Cropped Videos\match_16_cropped_camera_0.avi
#        Global Start: 46450.009s, Global End: 46465.490s
#        Video Start : 46450.009s => Local Start: 0.000s, Local End: 15.481s
# [DEBUG] crop_video -> FPS=31.20, total_frames=484, start_s=0.000, end_s=15.481
# [DEBUG] crop_video -> start_frame=0, end_frame=483
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #17:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Camera Data Timestamped\recording_sessions\session_2024-10-31_12_26_32\recording_12_56_28.033\annotated_videos_12_56_28.033\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Cropped Videos\match_17_cropped_camera_0.avi
#        Global Start: 46588.033s, Global End: 46605.020s
#        Video Start : 46588.033s => Local Start: 0.000s, Local End: 16.987s
# [DEBUG] crop_video -> FPS=31.20, total_frames=531, start_s=0.000, end_s=16.987
# [DEBUG] crop_video -> start_frame=0, end_frame=530
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #18:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Camera Data Timestamped\recording_sessions\session_2024-10-31_12_26_32\recording_12_57_45.360\annotated_videos_12_57_45.360\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Cropped Videos\match_18_cropped_camera_0.avi
#        Global Start: 46665.360s, Global End: 46684.078s
#        Video Start : 46665.360s => Local Start: 0.000s, Local End: 18.718s
# [DEBUG] crop_video -> FPS=31.20, total_frames=585, start_s=0.000, end_s=18.718
# [DEBUG] crop_video -> start_frame=0, end_frame=584
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #19:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Camera Data Timestamped\recording_sessions\session_2024-10-31_12_26_32\recording_12_59_25.443\annotated_videos_12_59_25.443\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Cropped Videos\match_19_cropped_camera_0.avi
#        Global Start: 46765.443s, Global End: 46781.917s
#        Video Start : 46765.443s => Local Start: 0.000s, Local End: 16.474s
# [DEBUG] crop_video -> FPS=31.20, total_frames=515, start_s=0.000, end_s=16.474
# [DEBUG] crop_video -> start_frame=0, end_frame=514
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #20:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Camera Data Timestamped\recording_sessions\session_2024-10-31_12_26_32\recording_13_00_19.853\annotated_videos_13_00_19.853\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Cropped Videos\match_20_cropped_camera_0.avi
#        Global Start: 46819.853s, Global End: 46838.507s
#        Video Start : 46819.853s => Local Start: 0.000s, Local End: 18.654s
# [DEBUG] crop_video -> FPS=31.20, total_frames=583, start_s=0.000, end_s=18.654
# [DEBUG] crop_video -> start_frame=0, end_frame=582
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #21:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Camera Data Timestamped\recording_sessions\session_2024-10-31_12_26_32\recording_13_02_20.468\annotated_videos_13_02_20.468\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Cropped Videos\match_21_cropped_camera_0.avi
#        Global Start: 46940.468s, Global End: 46957.199s
#        Video Start : 46940.468s => Local Start: 0.000s, Local End: 16.731s
# [DEBUG] crop_video -> FPS=31.20, total_frames=523, start_s=0.000, end_s=16.731
# [DEBUG] crop_video -> start_frame=0, end_frame=522
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #22:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Camera Data Timestamped\recording_sessions\session_2024-10-31_12_26_32\recording_13_03_22.442\annotated_videos_13_03_22.442\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data\Cropped Videos\match_22_cropped_camera_0.avi
#        Global Start: 47002.442s, Global End: 47021.096s
#        Video Start : 47002.442s => Local Start: 0.000s, Local End: 18.654s
# [DEBUG] crop_video -> FPS=31.20, total_frames=583, start_s=0.000, end_s=18.654
# [DEBUG] crop_video -> start_frame=0, end_frame=582
#       => Cropping succeeded.
#
# ...
#        Global Start: 53598.500s, Global End: 53615.006s
#        Video Start : 53598.500s => Local Start: 0.000s, Local End: 16.506s
# [DEBUG] crop_video -> FPS=31.20, total_frames=516, start_s=0.000, end_s=16.506
# [DEBUG] crop_video -> start_frame=0, end_frame=515
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #4:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Camera Data Timestamped\recording_sessions\session_2024-11-18_14_15_03\recording_14_54_14.500\annotated_videos_14_54_14.500\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data\Cropped Videos\match_04_cropped_camera_0.avi
#        Global Start: 53654.500s, Global End: 53671.423s
#        Video Start : 53654.500s => Local Start: 0.000s, Local End: 16.923s
# [DEBUG] crop_video -> FPS=31.20, total_frames=529, start_s=0.000, end_s=16.923
# [DEBUG] crop_video -> start_frame=0, end_frame=528
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #5:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Camera Data Timestamped\recording_sessions\session_2024-11-18_14_15_03\recording_14_56_17.500\annotated_videos_14_56_17.500\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data\Cropped Videos\match_05_cropped_camera_0.avi
#        Global Start: 53777.500s, Global End: 53793.269s
#        Video Start : 53777.500s => Local Start: 0.000s, Local End: 15.769s
# [DEBUG] crop_video -> FPS=31.20, total_frames=493, start_s=0.000, end_s=15.769
# [DEBUG] crop_video -> start_frame=0, end_frame=492
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #6:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Camera Data Timestamped\recording_sessions\session_2024-11-18_14_15_03\recording_14_57_05.500\annotated_videos_14_57_05.500\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data\Cropped Videos\match_06_cropped_camera_0.avi
#        Global Start: 53825.500s, Global End: 53842.006s
#        Video Start : 53825.500s => Local Start: 0.000s, Local End: 16.506s
# [DEBUG] crop_video -> FPS=31.20, total_frames=516, start_s=0.000, end_s=16.506
# [DEBUG] crop_video -> start_frame=0, end_frame=515
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #7:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Camera Data Timestamped\recording_sessions\session_2024-11-18_15_05_49\recording_15_06_30.428\annotated_videos_15_06_30.428\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data\Cropped Videos\match_07_cropped_camera_0.avi
#        Global Start: 54390.428s, Global End: 54408.922s
#        Video Start : 54390.428s => Local Start: 0.000s, Local End: 18.494s
# [DEBUG] crop_video -> FPS=31.20, total_frames=578, start_s=0.000, end_s=18.494
# [DEBUG] crop_video -> start_frame=0, end_frame=577
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #8:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Camera Data Timestamped\recording_sessions\session_2024-11-18_15_05_49\recording_15_07_19.548\annotated_videos_15_07_19.548\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data\Cropped Videos\match_08_cropped_camera_0.avi
#        Global Start: 54439.548s, Global End: 54457.208s
#        Video Start : 54439.548s => Local Start: 0.000s, Local End: 17.660s
# [DEBUG] crop_video -> FPS=31.20, total_frames=552, start_s=0.000, end_s=17.660
# [DEBUG] crop_video -> start_frame=0, end_frame=551
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #9:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Camera Data Timestamped\recording_sessions\session_2024-11-18_15_05_49\recording_15_08_52.339\annotated_videos_15_08_52.339\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data\Cropped Videos\match_09_cropped_camera_0.avi
#        Global Start: 54532.339s, Global End: 54548.236s
#        Video Start : 54532.339s => Local Start: 0.000s, Local End: 15.897s
# [DEBUG] crop_video -> FPS=31.20, total_frames=497, start_s=0.000, end_s=15.897
# [DEBUG] crop_video -> start_frame=0, end_frame=496
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #10:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Camera Data Timestamped\recording_sessions\session_2024-11-18_15_05_49\recording_15_09_43.147\annotated_videos_15_09_43.147\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data\Cropped Videos\match_10_cropped_camera_0.avi
#        Global Start: 54583.147s, Global End: 54599.141s
#        Video Start : 54583.147s => Local Start: 0.000s, Local End: 15.994s
# [DEBUG] crop_video -> FPS=31.20, total_frames=500, start_s=0.000, end_s=15.994
# [DEBUG] crop_video -> start_frame=0, end_frame=499
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #11:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Camera Data Timestamped\recording_sessions\session_2024-11-18_15_05_49\recording_15_11_22.084\annotated_videos_15_11_22.084\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data\Cropped Videos\match_11_cropped_camera_0.avi
#        Global Start: 54682.084s, Global End: 54698.366s
#        Video Start : 54682.084s => Local Start: 0.000s, Local End: 16.282s
# [DEBUG] crop_video -> FPS=31.20, total_frames=509, start_s=0.000, end_s=16.282
# [DEBUG] crop_video -> start_frame=0, end_frame=508
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #12:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Camera Data Timestamped\recording_sessions\session_2024-11-18_15_05_49\recording_15_12_40.256\annotated_videos_15_12_40.256\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data\Cropped Videos\match_12_cropped_camera_0.avi
#        Global Start: 54760.256s, Global End: 54776.346s
#        Video Start : 54760.256s => Local Start: 0.000s, Local End: 16.090s
# [DEBUG] crop_video -> FPS=31.20, total_frames=503, start_s=0.000, end_s=16.090
# [DEBUG] crop_video -> start_frame=0, end_frame=502
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #13:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Camera Data Timestamped\recording_sessions\session_2024-11-18_15_05_49\recording_15_16_46.028\annotated_videos_15_16_46.028\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data\Cropped Videos\match_13_cropped_camera_0.avi
#        Global Start: 55006.028s, Global End: 55019.554s
#        Video Start : 55006.028s => Local Start: 0.000s, Local End: 13.526s
# [DEBUG] crop_video -> FPS=31.20, total_frames=423, start_s=0.000, end_s=13.526
# [DEBUG] crop_video -> start_frame=0, end_frame=422
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #14:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Camera Data Timestamped\recording_sessions\session_2024-11-18_15_05_49\recording_15_17_37.755\annotated_videos_15_17_37.755\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data\Cropped Videos\match_14_cropped_camera_0.avi
#        Global Start: 55057.755s, Global End: 55077.851s
#        Video Start : 55057.755s => Local Start: 0.000s, Local End: 20.096s
# [DEBUG] crop_video -> FPS=31.20, total_frames=628, start_s=0.000, end_s=20.096
# [DEBUG] crop_video -> start_frame=0, end_frame=627
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #15:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Camera Data Timestamped\recording_sessions\session_2024-11-18_15_05_49\recording_15_19_12.919\annotated_videos_15_19_12.919\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data\Cropped Videos\match_15_cropped_camera_0.avi
#        Global Start: 55152.919s, Global End: 55167.759s
#        Video Start : 55152.919s => Local Start: 0.000s, Local End: 14.840s
# [DEBUG] crop_video -> FPS=31.20, total_frames=464, start_s=0.000, end_s=14.840
# [DEBUG] crop_video -> start_frame=0, end_frame=463
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #16:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Camera Data Timestamped\recording_sessions\session_2024-11-18_15_05_49\recording_15_20_00.364\annotated_videos_15_20_00.364\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data\Cropped Videos\match_16_cropped_camera_0.avi
#        Global Start: 55200.364s, Global End: 55214.274s
#        Video Start : 55200.364s => Local Start: 0.000s, Local End: 13.910s
# [DEBUG] crop_video -> FPS=31.20, total_frames=435, start_s=0.000, end_s=13.910
# [DEBUG] crop_video -> start_frame=0, end_frame=434
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #17:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Camera Data Timestamped\recording_sessions\session_2024-11-18_15_05_49\recording_15_21_39.066\annotated_videos_15_21_39.066\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data\Cropped Videos\match_17_cropped_camera_0.avi
#        Global Start: 55299.066s, Global End: 55312.688s
#        Video Start : 55299.066s => Local Start: 0.000s, Local End: 13.622s
# [DEBUG] crop_video -> FPS=31.20, total_frames=426, start_s=0.000, end_s=13.622
# [DEBUG] crop_video -> start_frame=0, end_frame=425
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #18:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Camera Data Timestamped\recording_sessions\session_2024-11-18_15_05_49\recording_15_22_31.013\annotated_videos_15_22_31.013\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data\Cropped Videos\match_18_cropped_camera_0.avi
#        Global Start: 55351.013s, Global End: 55365.308s
#        Video Start : 55351.013s => Local Start: 0.000s, Local End: 14.295s
# [DEBUG] crop_video -> FPS=31.20, total_frames=447, start_s=0.000, end_s=14.295
# [DEBUG] crop_video -> start_frame=0, end_frame=446
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #19:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Camera Data Timestamped\recording_sessions\session_2024-11-18_15_05_49\recording_15_22_31.014\annotated_videos_15_22_31.014\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data\Cropped Videos\match_19_cropped_camera_0.avi
#        Global Start: 55351.014s, Global End: 55365.309s
#        Video Start : 55351.014s => Local Start: 0.000s, Local End: 14.295s
# [DEBUG] crop_video -> FPS=31.20, total_frames=447, start_s=0.000, end_s=14.295
# [DEBUG] crop_video -> start_frame=0, end_frame=446
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #20:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Camera Data Timestamped\recording_sessions\session_2024-11-18_15_05_49\recording_15_26_01.543\annotated_videos_15_26_01.543\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data\Cropped Videos\match_20_cropped_camera_0.avi
#        Global Start: 55561.543s, Global End: 55578.146s
#        Video Start : 55561.543s => Local Start: 0.000s, Local End: 16.603s
# [DEBUG] crop_video -> FPS=31.20, total_frames=519, start_s=0.000, end_s=16.603
# [DEBUG] crop_video -> start_frame=0, end_frame=518
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #21:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Camera Data Timestamped\recording_sessions\session_2024-11-18_15_05_49\recording_15_33_55.855\annotated_videos_15_33_55.855\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data\Cropped Videos\match_21_cropped_camera_0.avi
#        Global Start: 56035.855s, Global End: 56050.567s
#        Video Start : 56035.855s => Local Start: 0.000s, Local End: 14.712s
# [DEBUG] crop_video -> FPS=31.20, total_frames=460, start_s=0.000, end_s=14.712
# [DEBUG] crop_video -> start_frame=0, end_frame=459
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #22:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Camera Data Timestamped\recording_sessions\session_2024-11-18_15_05_49\recording_15_35_30.567\annotated_videos_15_35_30.567\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data\Cropped Videos\match_22_cropped_camera_0.avi
#        Global Start: 56130.567s, Global End: 56146.881s
#        Video Start : 56130.567s => Local Start: 0.000s, Local End: 16.314s
# [DEBUG] crop_video -> FPS=31.20, total_frames=510, start_s=0.000, end_s=16.314
# [DEBUG] crop_video -> start_frame=0, end_frame=509
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #23:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Camera Data Timestamped\recording_sessions\session_2024-11-18_15_05_49\recording_15_41_18.496\annotated_videos_15_41_18.496\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data\Cropped Videos\match_23_cropped_camera_0.avi
#        Global Start: 56478.496s, Global End: 56491.861s
#        Video Start : 56478.496s => Local Start: 0.000s, Local End: 13.365s
# [DEBUG] crop_video -> FPS=31.20, total_frames=418, start_s=0.000, end_s=13.365
# [DEBUG] crop_video -> start_frame=0, end_frame=417
#       => Cropping succeeded.
#
# [INFO] Cropping video for Match #24:
#        Input : C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Camera Data Timestamped\recording_sessions\session_2024-11-18_15_05_49\recording_15_42_12.306\annotated_videos_15_42_12.306\annotated_video_camera_0.avi
#        Output: C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data\Cropped Videos\match_24_cropped_camera_0.avi
#        Global Start: 56532.306s, Global End: 56547.402s
#        Video Start : 56532.306s => Local Start: 0.000s, Local End: 15.096s
# [DEBUG] crop_video -> FPS=31.20, total_frames=472, start_s=0.000, end_s=15.096
# [DEBUG] crop_video -> start_frame=0, end_frame=471
#       => Cropping succeeded.
