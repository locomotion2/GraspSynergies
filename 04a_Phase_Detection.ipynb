# %% [markdown]
# ## Phase Detection and Signal Splitting
#
# This script splits previously synchronized experimental data streams into two phases: **Reach and Grasp Phase** and **Lift and Hold Phase**. Segmentation is performed using averaged velocities of the hand movement. By detecting velocity thresholds and temporal patterns the start, lift onset and end of the experiment is found. Corresponding video files are also split into these phase-specific segments for visual control.
#
# - **Parsing Utilities**: Extracts timestamps, camera indices, and match numbers from file and folder names.
# - **Data Loading**: Loads synchronized time, kinematic, and myoelectric data from `.npy` files.
# - **Smoothing**: Uses a low-pass filter to smooth velocity data.
# - **Phase Detection**: Identifies phase transitions (start of reach, grasp, lift, and hold) using smoothed x- and y-velocity thresholds and temporal patterns.
# - **Data Splitting**: Segments data into phases and saves them as `.npy` files.
# - **Video Cropping**: Splits video recordings into phase-specific segments.
# - **Debugging**: Creates annotated velocity plots with vertical dashed lines marking the detected phases.

# %%
import os
import glob
import re
import numpy as np
import matplotlib.pyplot as plt
import cv2
from datetime import datetime
from scipy.signal import butter, filtfilt

# --------------------------------------------------------------------
# 1) Parsing Utilities for Camera Directory & Filenames
# --------------------------------------------------------------------
def parse_session_datetime(session_folder_name: str) -> datetime:
    """
    Parse folder name like 'session_YYYY-MM-DD_HH_MM_SS'
    => returns a datetime(YYYY, MM, DD, HH, MM, SS).
    """
    pattern = r"session_(\d{4}-\d{2}-\d{2})_(\d{2})_(\d{2})_(\d{2})"
    m = re.match(pattern, session_folder_name)
    if not m:
        raise ValueError(f"Cannot parse session folder: {session_folder_name}")
    date_str = m.group(1)  
    hh = int(m.group(2))
    mm = int(m.group(3))
    ss = int(m.group(4))

    dt_fmt = "%Y-%m-%d"
    base_date = datetime.strptime(date_str, dt_fmt)
    return datetime(
        year=base_date.year,
        month=base_date.month,
        day=base_date.day,
        hour=hh,
        minute=mm,
        second=ss
    )

def parse_recording_time(recording_folder_name: str):
    """
    Parse folder name like 'recording_HH_MM_SS.xxx'
    => returns (H, M, S_float).

    e.g. 'recording_10_42_26.955' => (10, 42, 26.955)
    """
    pattern = r"recording_(\d{2})_(\d{2})_(\d{2}\.\d+)$"
    m = re.match(pattern, recording_folder_name)
    if not m:
        raise ValueError(f"Cannot parse recording folder: {recording_folder_name}")
    hh = int(m.group(1))
    mm = int(m.group(2))
    ss_float = float(m.group(3))
    return (hh, mm, ss_float)

def parse_camera_index(video_filename: str) -> int:
    """
    For a file named 'annotated_video_camera_0.avi', returns int(0).
    If not found, returns -1.
    """
    pattern = r"annotated_video_camera_(\d+)\.avi"
    m = re.match(pattern, video_filename)
    if not m:
        return -1
    return int(m.group(1))

def parse_camera_timestamp_from_path(fullpath: str):
    """
    1) Find 'session_YYYY-MM-DD_HH_MM_SS' in path => parse date/time
    2) Find 'recording_HH_MM_SS.xxx' in path => parse time-of-day
    3) Combine them => final datetime
    4) Extract camera index from 'annotated_video_camera_<IDX>.avi'
    Returns (datetime, camera_index) or None if parse fails.
    """
    # Split the path into parts
    path_parts = fullpath.split(os.sep)

    # Parse session datetime
    session_folders = [p for p in path_parts if p.startswith("session_")]
    if not session_folders:
        return None
    session_folder_name = session_folders[-1]
    try:
        session_dt = parse_session_datetime(session_folder_name)
    except ValueError:
        return None

    # Parse recording time
    recording_folders = [p for p in path_parts if p.startswith("recording_")]
    if not recording_folders:
        return None
    recording_folder_name = recording_folders[-1]
    try:
        hh, mm, ss_float = parse_recording_time(recording_folder_name)
    except ValueError:
        return None

    # Combine session date with recording time
    combined_dt = session_dt.replace(
        hour=hh,
        minute=mm,
        second=int(ss_float),
        microsecond=int((ss_float - int(ss_float)) * 1e6)
    )

    # Parse camera index
    filename = os.path.basename(fullpath)
    camera_idx = parse_camera_index(filename)

    return (combined_dt, camera_idx)

def get_sorted_camera_files(camera_base_dir: str):
    """
    1) Glob all 'annotated_video_camera_*.avi' in camera_base_dir
    2) Parse session+recording datetime, camera index
    3) Sort by datetime, then camera index
    Returns a list of (filepath, datetime, camera_idx).
    """
    pattern = os.path.join(camera_base_dir, "**", "annotated_video_camera_*.avi")
    cam_files = glob.glob(pattern, recursive=True)
    results = []
    for cf in cam_files:
        parsed = parse_camera_timestamp_from_path(cf)
        if parsed is None:
            print(f"[WARN] Could not parse datetime from path: {cf}")
            continue
        dt, cam_idx = parsed
        results.append((cf, dt, cam_idx))

    # Sort by dt first, then camera_idx
    results.sort(key=lambda x: (x[1], x[2]))
    return results

# --------------------------------------------------------------------
# 2) Sorting Match Files
# --------------------------------------------------------------------
def parse_match_number(fname: str):
    """
    For 'match_01_time.npy', returns int(1).
    If no match, returns None.
    """
    pattern = r"match_(\d+)_time\.npy"
    m = re.match(pattern, fname)
    if not m:
        return None
    return int(m.group(1))

def get_sorted_match_files(sync_dir: str):
    """
    1) Glob all 'match_*_time.npy'
    2) Parse the numeric match index
    3) Sort ascending
    Returns list of (time_file_path, match_num).
    """
    time_files = glob.glob(os.path.join(sync_dir, "match_*_time.npy"))
    parsed_list = []
    for tf in time_files:
        base_name = os.path.basename(tf)
        match_num = parse_match_number(base_name)
        if match_num is not None:
            parsed_list.append((tf, match_num))

    parsed_list.sort(key=lambda x: x[1])  # sort by match_num
    return parsed_list

# --------------------------------------------------------------------
# 3) Load Data
# --------------------------------------------------------------------
def load_synchronized_data(sync_dir, match_prefix, hand_dims):
    """
    Loads time, kin, myo, otb from .npy files if they exist.
    Returns (time_data, kin_data, myo_data, otb_data) or None if missing files.
    """
    time_file = os.path.join(sync_dir, match_prefix + "_time.npy")
    kin_file  = os.path.join(sync_dir, match_prefix + "_kin.npy")
    myo_file  = os.path.join(sync_dir, match_prefix + "_myo.npy")
    otb_file  = os.path.join(sync_dir, match_prefix + "_otb.npy")

    if not all(os.path.exists(f) for f in [time_file, kin_file, myo_file, otb_file]):
        print(f"[WARN] Missing files for {match_prefix}.")
        return None

    time_data = np.load(time_file)
    kin_data  = np.load(kin_file)
    myo_data  = np.load(myo_file)
    otb_data  = np.load(otb_file)

    if len(time_data) < 5:
        print(f"[WARN] Not enough frames in {match_prefix}.")
        return None
    if kin_data.shape[1] < hand_dims:
        print(f"[WARN] kin_data has fewer than {hand_dims} columns.")
        return None

    return time_data, kin_data, myo_data, otb_data

# --------------------------------------------------------------------
# 4) Smoothing
# --------------------------------------------------------------------
def heavy_smooth(signal, dt, cutoff_hz=0.01, order=4):
    """
    Zero-phase Butterworth lowpass filter with filtfilt,
    so that we can smooth more without a phase shift.
    
    Parameters
    ----------
    signal : 1D array
        The raw data to filter
    dt : float
        The sampling interval (seconds between consecutive points)
    cutoff_hz : float
        The lowpass cutoff frequency in Hz (smaller => more smoothing)
    order : int
        The filter order (e.g., 4 => a 4th-order Butterworth)
    Returns
    -------
    filtered : 1D array
        The smoothed signal (same length as input)
    """
    fs = 1.0 / dt  # sampling rate in Hz
    nyquist = 0.5 * fs
    Wn = cutoff_hz / nyquist  # normalize cutoff to [0..1]
    b, a = butter(order, Wn, btype='low', analog=False)
    return filtfilt(b, a, signal)

# --------------------------------------------------------------------
# 5) Detect Task Boundaries and Phases
# --------------------------------------------------------------------
def detect_grasp_phases(
    time_data,
    kin_data,
    x_return_thresh=15.0,    # X "close to zero" threshold for iH
    x_end_thresh1=-80.0,     # X velocity threshold1 (< -50.0) for detecting i3_candidate
    x_end_thresh2=-10.0,     # X velocity threshold2 (<-10.0) for finding t3
    y_lift_thresh=10.0,       # Y-axis threshold for Phase 2 start
    y_zero_tol=5.0,          # Tolerance for zero crossing in Y velocity
    n_consec_frames=2,
    n_hand_landmarks=21
):
    """
    Detects grasp phases based on smoothed velocities. This version adds
    per-phase debug messages and partial detection results even if the
    overall detection fails.

    Returns a dictionary with keys:
      - 'failed': bool
      - 'i0','i1','i2','i3': int or None
      - 't0','t1','t2','t3': float or None
      - 'debug_i0','debug_i1','debug_i2','debug_i3': debug messages
      - 'x_vel_sm','y_vel_sm','vel_time': debugging velocity arrays
    """

    # ----------------------------------------------------------------
    # Initialize dictionary with placeholders
    # ----------------------------------------------------------------
    phase_result = {
        'failed': False,
        'i0': None, 'i1': None, 'i2': None, 'i3': None,
        't0': None, 't1': None, 't2': None, 't3': None,
        'debug_i0': "", 'debug_i1': "", 'debug_i2': "", 'debug_i3': "",
        'x_vel_sm': None, 'y_vel_sm': None, 'vel_time': None
    }

    # --------------------------------------------------------
    # 1) Compute time-step and check validity
    # --------------------------------------------------------
    dt = np.median(np.diff(time_data))
    if dt <= 0:
        phase_result['failed'] = True
        phase_result['debug_i0'] = "[WARN] dt <= 0 => invalid data."
        return phase_result

    # --------------------------------------------------------
    # 2) Compute & smooth velocities
    # --------------------------------------------------------
    # kin_data shape: (num_samples, n_hand_landmarks*3 + pose_dimensions)
    pos = kin_data[:, :n_hand_landmarks*3]  # Extract only hand landmark positions
    vel = (pos[1:] - pos[:-1]) / dt  # shape: (num_samples-1, n_hand_landmarks*3)

    x_inds = np.arange(0, 3*n_hand_landmarks, 3)
    y_inds = np.arange(1, 3*n_hand_landmarks, 3)

    raw_x_vel = np.mean(vel[:, x_inds], axis=1)
    raw_y_vel = np.mean(vel[:, y_inds], axis=1)

    cutoff_hz = 1.4  # can be tuned
    x_vel_sm = heavy_smooth(raw_x_vel, dt, cutoff_hz=cutoff_hz, order=4)
    y_vel_sm = heavy_smooth(raw_y_vel, dt, cutoff_hz=cutoff_hz, order=4)

    vel_time = 0.5 * (time_data[:-1] + time_data[1:])

    # Store in results for debugging/plotting
    phase_result['x_vel_sm'] = x_vel_sm
    phase_result['y_vel_sm'] = y_vel_sm
    phase_result['vel_time'] = vel_time

    # --------------------------------------------------------
    # 3) Try detecting i0
    # --------------------------------------------------------
    HIGH_VELOCITY_THRESHOLD = 50
    LOW_VELOCITY_THRESHOLD  = 10

    high_velocity_indices = np.where(x_vel_sm > HIGH_VELOCITY_THRESHOLD)[0]
    if high_velocity_indices.size == 0:
        phase_result['debug_i0'] = "[INFO] No velocity > 70 => i0 not found."
        phase_result['failed'] = True
        return phase_result

    first_high_idx = high_velocity_indices[0]
    i0_idx = None
    for i in range(first_high_idx, -1, -1):
        if x_vel_sm[i] < LOW_VELOCITY_THRESHOLD:
            i0_idx = i
            break

    if i0_idx is None:
        phase_result['debug_i0'] = "[INFO] Could not find a pre-high drop < 15 => i0 not found."
        phase_result['failed'] = True
        return phase_result
    else:
        t0 = vel_time[i0_idx]
        i0 = np.searchsorted(time_data, t0, side='left')
        phase_result['i0'] = i0
        phase_result['t0'] = t0
        phase_result['debug_i0'] = f"[OK] Found i0 at vel_time idx={i0_idx}, t0={t0:.3f}s"

    # --------------------------------------------------------
    # 4) Try detecting i3
    # --------------------------------------------------------
    i3_candidate_idx = None
    consec = 0

    # Scan backward to find the first valid region where x_vel_sm < x_end_thresh1
    for i in range(len(x_vel_sm) - 1, -1, -1):
        if x_vel_sm[i] < x_end_thresh1:  # e.g., -50.0 or -80.0
            consec += 1
        else:
            consec = 0
        if consec >= n_consec_frames:
            i3_candidate_idx = i - n_consec_frames + 1  # First valid region
            break

    if i3_candidate_idx is None or i3_candidate_idx <= i0_idx:
        # Fallback: set i3 to the end
        i3_idx = len(vel_time) - 1
        t3 = vel_time[i3_idx]
        i3 = len(time_data) - 1
        phase_result['debug_i3'] = "[INFO] No valid i3 found => fallback to end of data."
    else:
        # Refine i3 by moving left to find the first abs(x_vel_sm) < 10
        i3_idx_check = None
        for i in range(i3_candidate_idx, i0_idx - 1, -1):  # Go left
            if abs(x_vel_sm[i]) < 10.0:  # Absolute value check
                i3_idx_check = i
                break

        if i3_idx_check is None or i3_idx_check <= i0_idx:
            # Fallback to the end of the data if no valid crossing found
            i3_idx = len(vel_time) - 1
            phase_result['debug_i3'] = "[INFO] No crossing for i3 => fallback to end of data."
        else:
            # Use the refined index
            i3_idx = i3_idx_check

    # Set the final time and index for i3
    t3 = vel_time[i3_idx]
    i3 = np.searchsorted(time_data, t3, side='left')
    phase_result['i3'] = i3
    phase_result['t3'] = t3
    phase_result['debug_i3'] = f"[OK] Refined i3 at vel_time idx={i3_idx}, t3={t3:.3f}s"

    # --------------------------------------------------------
    # 5) Try detecting iH
    # --------------------------------------------------------
    iH_idx = None
    consec = 0
    for i in range(i0_idx, i3_idx + 1):
        if abs(x_vel_sm[i]) < x_return_thresh:
            consec += 1
        else:
            consec = 0
        if consec >= n_consec_frames:
            iH_idx = i - n_consec_frames + 1
            break

    if iH_idx is None:
        # fallback
        fallback_thresholds = [12.0, 15.0, 20.0]
        phase_result['debug_i1'] = f"[INFO] Did not find X near-zero (< {x_return_thresh}) => fallback."
        for alt_thresh in fallback_thresholds:
            consec = 0
            for i in range(i0_idx, i3_idx + 1):
                if abs(x_vel_sm[i]) < alt_thresh:
                    consec += 1
                else:
                    consec = 0
                if consec >= (n_consec_frames - 1):
                    iH_idx = i - (n_consec_frames - 1) + 1
                    phase_result['debug_i1'] += f" [OK] Found iH_idx with alt_thresh={alt_thresh}."
                    break
            if iH_idx is not None:
                break
        if iH_idx is None:
            phase_result['debug_i1'] += " [FAIL] Could not find iH."
            phase_result['failed'] = True
        else:
            tH = vel_time[iH_idx]
            phase_result['i1'] = np.searchsorted(time_data, tH, side='left')
            phase_result['t1'] = tH
    else:
        tH = vel_time[iH_idx]
        phase_result['i1'] = np.searchsorted(time_data, tH, side='left')
        phase_result['t1'] = tH
        phase_result['debug_i1'] = f"[OK] Found iH at vel_time idx={iH_idx}, tH={tH:.3f}s"

    # If iH was found but we want to add 1s shift
    if phase_result['i1'] is not None and not phase_result['failed']:
        iH_plus_idx = np.searchsorted(vel_time, tH + 2.0, side='left')
        if iH_plus_idx >= len(vel_time):
            iH_plus_idx = len(vel_time) - 1
        tH_plus = vel_time[iH_plus_idx]
        phase_result['i1'] = np.searchsorted(time_data, tH_plus, side='left')
        phase_result['t1'] = tH_plus
        phase_result['debug_i1'] += f" [SHIFT] iH => iH+1s at vel_time idx={iH_plus_idx}, tH={tH_plus:.3f}s"

    # --------------------------------------------------------
    # 6) Try detecting i2
    # --------------------------------------------------------
    # Only proceed if iH was found
    if phase_result['i1'] is None or phase_result['failed']:
        # We already failed, but keep partial results
        return phase_result

    iH_idx_updated = np.searchsorted(vel_time, phase_result['t1'], side='left')
    i2_dip_start = None
    consec = 0
    for i in range(iH_idx_updated, i3_idx + 1):
        if y_vel_sm[i] < -y_lift_thresh:
            consec += 1
        else:
            consec = 0
        if consec >= n_consec_frames:
            i2_dip_start = i - n_consec_frames + 1
            break

    if i2_dip_start is None:
        phase_result['debug_i2'] = f"[INFO] No Y-lift crossing found (< -{y_lift_thresh})."
        phase_result['failed'] = True
        return phase_result

    # Find the near-zero crossing in y velocity
    i2_idx = None
    for j in range(i2_dip_start, iH_idx_updated, -1):
        if abs(y_vel_sm[j]) < y_zero_tol:
            i2_idx = j
            break
    if i2_idx is None:
        i2_idx = i2_dip_start

    t2 = vel_time[i2_idx]
    i2 = np.searchsorted(time_data, t2, side='left')
    phase_result['i2'] = i2
    phase_result['t2'] = t2
    phase_result['debug_i2'] = f"[OK] Found i2 at vel_time idx={i2_idx}, t2={t2:.3f}s"

    # Final check
    if not (phase_result['i1'] <= i2 < i3):
        phase_result['debug_i2'] += " [FAIL] i2 not in [iH, i3)."
        phase_result['failed'] = True

    return phase_result

# --------------------------------------------------------------------
# 6) Splitting & Cropping - Single Camera Version
# --------------------------------------------------------------------
def split_save_and_crop_video_single_camera(
    match_prefix,
    time_data, kin_data, myo_data, otb_data,
    phase_dict,
    out_dir,
    camera_file,
    camera_out_dir
):
    """
    Saves Phase1 & Phase2 data as .npy,
    then crops the single camera_file into Phase1.avi and Phase2.avi.

    We assume phase_dict has keys: 'i0', 'i2', 'i3'.
    Phase1 = [i0, i2), Phase2 = [i2, i3).
    """

    i0 = phase_dict['i0']
    i2 = phase_dict['i2']
    i3 = phase_dict['i3']

    # PHASE 1 => [i0, i2)
    t_phase1  = time_data[i0:i2]
    kin_p1    = kin_data[i0:i2]
    myo_p1    = myo_data[i0:i2]
    otb_p1    = otb_data[i0:i2]

    # PHASE 2 => [i2, i3)
    t_phase2  = time_data[i2:i3]
    kin_p2    = kin_data[i2:i3]
    myo_p2    = myo_data[i2:i3]
    otb_p2    = otb_data[i2:i3]

    p1_prefix = match_prefix + "_phase1"
    p2_prefix = match_prefix + "_phase2"

    # Save each phase
    np.save(os.path.join(out_dir, p1_prefix + "_time.npy"), t_phase1)
    np.save(os.path.join(out_dir, p1_prefix + "_kin.npy"),  kin_p1)
    np.save(os.path.join(out_dir, p1_prefix + "_myo.npy"),  myo_p1)
    np.save(os.path.join(out_dir, p1_prefix + "_otb.npy"),  otb_p1)

    np.save(os.path.join(out_dir, p2_prefix + "_time.npy"), t_phase2)
    np.save(os.path.join(out_dir, p2_prefix + "_kin.npy"),  kin_p2)
    np.save(os.path.join(out_dir, p2_prefix + "_myo.npy"),  myo_p2)
    np.save(os.path.join(out_dir, p2_prefix + "_otb.npy"),  otb_p2)

    print(f"[SAVED] {match_prefix} => Phase1: {len(t_phase1)} frames, Phase2: {len(t_phase2)} frames.")

    # Video cropping
    def time_to_frame(tsec, fps, total_frames):
        frame_idx = int(round(tsec * fps))
        return max(0, min(frame_idx, total_frames - 1))

    # Convert i0, i2, i3 -> times
    t0_ = time_data[i0]
    t2_ = time_data[i2]
    t3_ = time_data[i3] if i3 < len(time_data) else time_data[-1]

    cam_name = os.path.basename(camera_file)
    cam_sub  = os.path.join(camera_out_dir, cam_name.replace(".avi",""))
    os.makedirs(cam_sub, exist_ok=True)

    cap = cv2.VideoCapture(camera_file)
    if not cap.isOpened():
        print(f"[WARN] Could not open {camera_file}")
        return

    fps = cap.get(cv2.CAP_PROP_FPS)
    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    w  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    h  = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    total_f = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    # PHASE 1 => [t0_, t2_)
    p1_file = os.path.join(cam_sub, f"{match_prefix}_phase1_{cam_name}")
    s1 = time_to_frame(t0_, fps, total_f)
    e1 = time_to_frame(t2_, fps, total_f)
    if s1 < e1:
        out1 = cv2.VideoWriter(p1_file, fourcc, fps, (w,h))
        cap.set(cv2.CAP_PROP_POS_FRAMES, s1)
        idx = s1
        while idx < e1:
            ret, frame = cap.read()
            if not ret:
                break
            out1.write(frame)
            idx += 1
        out1.release()

    # PHASE 2 => [t2_, t3_)
    p2_file = os.path.join(cam_sub, f"{match_prefix}_phase2_{cam_name}")
    s2 = time_to_frame(t2_, fps, total_f)
    e2 = time_to_frame(t3_, fps, total_f)
    if s2 < e2:
        out2 = cv2.VideoWriter(p2_file, fourcc, fps, (w,h))
        cap.set(cv2.CAP_PROP_POS_FRAMES, s2)
        idx = s2
        while idx < e2:
            ret, frame = cap.read()
            if not ret:
                break
            out2.write(frame)
            idx += 1
        out2.release()

    cap.release()

def get_cropped_camera_files(cropped_videos_dir: str):
    pattern = os.path.join(cropped_videos_dir, "match_*_cropped_camera_*.avi")
    cam_files = glob.glob(pattern)
    results = []
    for cf in cam_files:
        base_name = os.path.basename(cf)
        m = re.match(r"match_(\d+)_cropped_camera_(\d+)\.avi", base_name)
        if not m:
            continue
        match_num = int(m.group(1))
        cam_idx   = int(m.group(2))
        results.append((cf, match_num, cam_idx))
    results.sort(key=lambda x: (x[1], x[2]))  # Sort by match_num, then camera_idx
    return results

# --------------------------------------------------------------------
# 7) Debug Plot
# --------------------------------------------------------------------
def plot_debug_velocities(
    match_prefix,
    time_data,
    phase_info,
    out_dir=None,
    show_plot=False
):
    """
    Always plots velocities. If some of i0, iH, i2, i3 were found,
    draw vertical lines for them. If a phase was not found, skip it.
    Also annotate the debug messages in the console.
    """
    x_vel = phase_info['x_vel_sm']
    y_vel = phase_info['y_vel_sm']
    vel_time = phase_info['vel_time']

    # Print out debug info for each phase index
    print("\n[DEBUG] " + match_prefix)
    print("   i0 =>", phase_info['debug_i0'])
    print("   iH =>", phase_info['debug_i1'])
    print("   i2 =>", phase_info['debug_i2'])
    print("   i3 =>", phase_info['debug_i3'])

    if x_vel is None or y_vel is None or vel_time is None:
        print("[DEBUG] No velocity data => skipping plot.")
        return

    fig_title = f"Velocity Debug: {match_prefix}"
    if phase_info['failed']:
        fig_title += " (DETECTION FAILED)"

    fig, axs = plt.subplots(2, 1, figsize=(10,6), sharex=True)
    fig.suptitle(fig_title)

    # Plot X velocity
    axs[0].plot(vel_time, x_vel, label="Avg X Vel (smoothed)")
    axs[0].set_ylabel("X Velocity [units/s]")
    axs[0].legend()

    # Plot Y velocity
    axs[1].plot(vel_time, y_vel, label="Avg Y Vel (smoothed)", color='tab:orange')
    axs[1].set_ylabel("Y Velocity [units/s]")
    axs[1].set_xlabel("Time (s)")
    axs[1].legend()

    # Always attempt to plot lines if they exist
    i0, i1, i2, i3 = phase_info['i0'], phase_info['i1'], phase_info['i2'], phase_info['i3']
    t0, t1, t2, t3 = phase_info['t0'], phase_info['t1'], phase_info['t2'], phase_info['t3']

    # Each of these might be None if detection failed partially:
    def vline_if_found(ax, t, label, color):
        if t is not None:
            ax.axvline(t, color=color, linestyle='--', label=label)

    # top subplot => i0 & i3
    vline_if_found(axs[0], t0, 'i0', 'green')
    vline_if_found(axs[0], t3, 'i3', 'red')
    axs[0].legend()

    # bottom subplot => i0, iH, i2, i3
    vline_if_found(axs[1], t0, 'i0', 'green')
    vline_if_found(axs[1], t1, 'iH', 'blue')
    vline_if_found(axs[1], t2, 'i2', 'magenta')
    vline_if_found(axs[1], t3, 'i3', 'red')
    axs[1].legend()

    plt.tight_layout()

    # Save or show
    if out_dir:
        os.makedirs(out_dir, exist_ok=True)
        suffix = "_debug_vel.png"
        if phase_info['failed']:
            suffix = "_debug_vel_FAILED.png"
        fpath = os.path.join(out_dir, f"{match_prefix}{suffix}")
        plt.savefig(fpath, dpi=150)
        print(f"[SAVED] Debug plot => {fpath}")

    if show_plot:
        plt.show()
    plt.close(fig)

# --------------------------------------------------------------------
# 8) Main
# --------------------------------------------------------------------
def main():
    BASE_DIR = r"C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data"
    PARTICIPANTS = [2,3,4,5,6,7,8]

    SYNC_FOLDER   = "Synchronized Data"
    SPLIT_FOLDER  = "Synchronized Data split in Phases"
    CROPPED_VIDEOS_SUBFOLDER = "Cropped Videos"

    n_hand_landmarks = 21
    hand_dims = n_hand_landmarks * 3

    # Phase detection parameters
    X_RETURN_THRESH = 15.0
    X_END_THRESH1   = -50.0
    X_END_THRESH2   = 10.0
    Y_LIFT_THRESH   = 10.0
    N_CONSEC        = 2
    Y_ZERO_TOL      = 5.0  # Removed trailing comma to make it a float

    for p in PARTICIPANTS:
        participant_str = f"P({p})"
        participant_dir = os.path.join(BASE_DIR, participant_str)
        sync_dir = os.path.join(participant_dir, SYNC_FOLDER)
        if not os.path.isdir(sync_dir):
            print(f"[WARN] No Synchronized Data folder for {participant_str}.")
            continue

        split_dir = os.path.join(participant_dir, SPLIT_FOLDER)
        os.makedirs(split_dir, exist_ok=True)

        # We look for cropped videos in:
        cropped_videos_dir = os.path.join(sync_dir, CROPPED_VIDEOS_SUBFOLDER)
        camera_out_dir     = os.path.join(split_dir, "Camera")
        os.makedirs(camera_out_dir, exist_ok=True)

        # 1) Sorted match files
        sorted_matches = get_sorted_match_files(sync_dir)
        if not sorted_matches:
            print(f"[INFO] No matched files found for {participant_str}.")
            continue

        # 2) Sorted camera files
        sorted_cam = get_cropped_camera_files(cropped_videos_dir)
        if not sorted_cam:
            print(f"[INFO] No cropped camera videos found in {cropped_videos_dir}")
            continue

        # Pair up by index or match_num (here, we just do index-based pairing)
        N = min(len(sorted_matches), len(sorted_cam))
        if N < len(sorted_matches):
            print(f"[WARN] Fewer camera files ({len(sorted_cam)}) than match files ({len(sorted_matches)})")

        # Debug-plot folder
        debug_plot_dir = os.path.join(split_dir, "Plots_Velocity_Debug")
        os.makedirs(debug_plot_dir, exist_ok=True)

        for i in range(N):
            match_time_file, match_num = sorted_matches[i]
            cam_file, cam_match_num, cam_idx = sorted_cam[i]

            # e.g. match_01_time.npy => match_prefix='match_01'
            match_prefix = os.path.basename(match_time_file).replace("_time.npy","")

            data_tuple = load_synchronized_data(sync_dir, match_prefix, hand_dims)
            if data_tuple is None:
                print(f"[WARN] Data missing for {match_prefix}, skipping.")
                continue

            time_data, kin_data, myo_data, otb_data = data_tuple

            # Detect phases
            phase_info = detect_grasp_phases(
                time_data, 
                kin_data,
                x_return_thresh = X_RETURN_THRESH,
                x_end_thresh1   = X_END_THRESH1,
                x_end_thresh2   = X_END_THRESH2,
                y_lift_thresh   = Y_LIFT_THRESH,
                y_zero_tol      = Y_ZERO_TOL,  # Now correctly a float
                n_consec_frames = N_CONSEC,
                n_hand_landmarks= n_hand_landmarks
            )

            # Always debug-plot
            plot_debug_velocities(
                match_prefix,
                time_data,
                phase_info,
                out_dir=debug_plot_dir,
                show_plot=False
            )

            # Only proceed with cropping if detection didn't fail
            if not phase_info['failed']:
                split_save_and_crop_video_single_camera(
                    match_prefix,
                    time_data, kin_data, myo_data, otb_data,
                    phase_info,
                    out_dir       = split_dir,
                    camera_file   = cam_file,
                    camera_out_dir= camera_out_dir
                )
            else:
                print(f"[INFO] Could not detect phases for {match_prefix}, skipping cropping.")

if __name__ == "__main__":
    main()
# Out:
# [DEBUG] match_01
#    i0 => [OK] Found i0 at vel_time idx=3712, t0=1.856s
#    iH => [OK] Found iH at vel_time idx=3712, tH=1.856s [SHIFT] iH => iH+1s at vel_time idx=7712, tH=3.856s
#    i2 => [OK] Found i2 at vel_time idx=10387, t2=5.194s
#    i3 => [OK] Refined i3 at vel_time idx=27442, t3=13.721s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(2)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_01_debug_vel.png
# [SAVED] match_01 => Phase1: 6675 frames, Phase2: 17055 frames.
#
# [DEBUG] match_02
#    i0 => [OK] Found i0 at vel_time idx=4609, t0=2.305s
#    iH => [OK] Found iH at vel_time idx=4609, tH=2.305s [SHIFT] iH => iH+1s at vel_time idx=8609, tH=4.305s
#    i2 => [OK] Found i2 at vel_time idx=11963, t2=5.982s
#    i3 => [OK] Refined i3 at vel_time idx=28579, t3=14.290s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(2)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_02_debug_vel.png
# [SAVED] match_02 => Phase1: 7354 frames, Phase2: 16616 frames.
#
# [DEBUG] match_03
#    i0 => [OK] Found i0 at vel_time idx=5377, t0=2.689s
#    iH => [OK] Found iH at vel_time idx=5377, tH=2.689s [SHIFT] iH => iH+1s at vel_time idx=9377, tH=4.689s
#    i2 => [OK] Found i2 at vel_time idx=11787, t2=5.894s
#    i3 => [OK] Refined i3 at vel_time idx=24882, t3=12.441s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(2)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_03_debug_vel.png
# [SAVED] match_03 => Phase1: 6410 frames, Phase2: 13095 frames.
#
# [DEBUG] match_04
#    i0 => [OK] Found i0 at vel_time idx=3323, t0=1.662s
#    iH => [OK] Found iH at vel_time idx=3323, tH=1.662s [SHIFT] iH => iH+1s at vel_time idx=7323, tH=3.662s
#    i2 => [OK] Found i2 at vel_time idx=10482, t2=5.241s
#    i3 => [OK] Refined i3 at vel_time idx=22501, t3=11.251s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(2)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_04_debug_vel.png
# [SAVED] match_04 => Phase1: 7159 frames, Phase2: 12019 frames.
#
# [DEBUG] match_05
#    i0 => [OK] Found i0 at vel_time idx=7887, t0=3.944s
#    iH => [OK] Found iH at vel_time idx=7887, tH=3.944s [SHIFT] iH => iH+1s at vel_time idx=11887, tH=5.944s
#    i2 => [OK] Found i2 at vel_time idx=15588, t2=7.794s
#    i3 => [OK] Refined i3 at vel_time idx=33570, t3=16.785s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(2)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_05_debug_vel.png
# [SAVED] match_05 => Phase1: 7701 frames, Phase2: 17982 frames.
#
# [DEBUG] match_06
#    i0 => [OK] Found i0 at vel_time idx=4861, t0=2.431s
#    iH => [OK] Found iH at vel_time idx=4861, tH=2.431s [SHIFT] iH => iH+1s at vel_time idx=8861, tH=4.431s
#    i2 => [OK] Found i2 at vel_time idx=13184, t2=6.592s
#    i3 => [OK] Refined i3 at vel_time idx=27982, t3=13.991s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(2)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_06_debug_vel.png
# [SAVED] match_06 => Phase1: 8323 frames, Phase2: 14798 frames.
#
# [DEBUG] match_07
#    i0 => [OK] Found i0 at vel_time idx=15868, t0=7.934s
#    iH => [OK] Found iH at vel_time idx=15868, tH=7.934s [SHIFT] iH => iH+1s at vel_time idx=19868, tH=9.934s
#    i2 => [OK] Found i2 at vel_time idx=24056, t2=12.028s
#    i3 => [OK] Refined i3 at vel_time idx=38639, t3=19.320s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(2)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_07_debug_vel.png
# [SAVED] match_07 => Phase1: 8188 frames, Phase2: 14583 frames.
#
# [DEBUG] match_08
#    i0 => [OK] Found i0 at vel_time idx=3673, t0=1.837s
#    iH => [OK] Found iH at vel_time idx=3673, tH=1.837s [SHIFT] iH => iH+1s at vel_time idx=7673, tH=3.837s
#    i2 => [OK] Found i2 at vel_time idx=7673, t2=3.837s
#    i3 => [OK] Refined i3 at vel_time idx=26121, t3=13.061s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(2)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_08_debug_vel.png
# [SAVED] match_08 => Phase1: 4000 frames, Phase2: 18448 frames.
#
# [DEBUG] match_09
#    i0 => [OK] Found i0 at vel_time idx=13056, t0=6.528s
#    iH => [OK] Found iH at vel_time idx=13056, tH=6.528s [SHIFT] iH => iH+1s at vel_time idx=17056, tH=8.528s
#    i2 => [OK] Found i2 at vel_time idx=22114, t2=11.057s
#    i3 => [OK] Refined i3 at vel_time idx=36692, t3=18.346s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(2)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_09_debug_vel.png
# [SAVED] match_09 => Phase1: 9058 frames, Phase2: 14578 frames.
#
# [DEBUG] match_10
#    i0 => [OK] Found i0 at vel_time idx=7728, t0=3.864s
#    iH => [OK] Found iH at vel_time idx=7728, tH=3.864s [SHIFT] iH => iH+1s at vel_time idx=11728, tH=5.864s
#    i2 => [OK] Found i2 at vel_time idx=16348, t2=8.174s
#    i3 => [OK] Refined i3 at vel_time idx=29919, t3=14.960s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(2)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_10_debug_vel.png
# [SAVED] match_10 => Phase1: 8620 frames, Phase2: 13571 frames.
#
# [DEBUG] match_11
#    i0 => [OK] Found i0 at vel_time idx=5680, t0=2.840s
#    iH => [OK] Found iH at vel_time idx=5680, tH=2.840s [SHIFT] iH => iH+1s at vel_time idx=9680, tH=4.840s
#    i2 => [OK] Found i2 at vel_time idx=12711, t2=6.356s
#    i3 => [OK] Refined i3 at vel_time idx=25886, t3=12.943s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(2)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_11_debug_vel.png
# [SAVED] match_11 => Phase1: 7031 frames, Phase2: 13175 frames.
#
# [DEBUG] match_12
#    i0 => [OK] Found i0 at vel_time idx=7123, t0=3.562s
#    iH => [OK] Found iH at vel_time idx=7123, tH=3.562s [SHIFT] iH => iH+1s at vel_time idx=11123, tH=5.562s
#    i2 => [OK] Found i2 at vel_time idx=14417, t2=7.209s
#    i3 => [OK] Refined i3 at vel_time idx=29253, t3=14.627s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(2)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_12_debug_vel.png
# [SAVED] match_12 => Phase1: 7294 frames, Phase2: 14836 frames.
#
# [DEBUG] match_13
#    i0 => [OK] Found i0 at vel_time idx=5153, t0=2.577s
#    iH => [OK] Found iH at vel_time idx=5153, tH=2.577s [SHIFT] iH => iH+1s at vel_time idx=9153, tH=4.577s
#    i2 => [OK] Found i2 at vel_time idx=12082, t2=6.041s
#    i3 => [OK] Refined i3 at vel_time idx=24962, t3=12.481s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(2)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_13_debug_vel.png
# [SAVED] match_13 => Phase1: 6929 frames, Phase2: 12880 frames.
#
# [DEBUG] match_14
#    i0 => [OK] Found i0 at vel_time idx=3209, t0=1.605s
#    iH => [OK] Found iH at vel_time idx=3209, tH=1.605s [SHIFT] iH => iH+1s at vel_time idx=7209, tH=3.605s
#    i2 => [OK] Found i2 at vel_time idx=10705, t2=5.353s
#    i3 => [OK] Refined i3 at vel_time idx=23779, t3=11.890s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(2)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_14_debug_vel.png
# [SAVED] match_14 => Phase1: 7496 frames, Phase2: 13074 frames.
#
# [DEBUG] match_15
#    i0 => [OK] Found i0 at vel_time idx=7004, t0=3.502s
#    iH => [OK] Found iH at vel_time idx=7004, tH=3.502s [SHIFT] iH => iH+1s at vel_time idx=11004, tH=5.502s
#    i2 => [OK] Found i2 at vel_time idx=14291, t2=7.146s
#    i3 => [OK] Refined i3 at vel_time idx=28751, t3=14.376s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(2)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_15_debug_vel.png
# [SAVED] match_15 => Phase1: 7287 frames, Phase2: 14460 frames.
#
# [DEBUG] match_16
#    i0 => [OK] Found i0 at vel_time idx=6388, t0=3.194s
#    iH => [OK] Found iH at vel_time idx=6388, tH=3.194s [SHIFT] iH => iH+1s at vel_time idx=10388, tH=5.194s
#    i2 => [OK] Found i2 at vel_time idx=10388, t2=5.194s
#    i3 => [OK] Refined i3 at vel_time idx=28748, t3=14.374s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(2)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_16_debug_vel.png
# [SAVED] match_16 => Phase1: 4000 frames, Phase2: 18360 frames.
#
# [DEBUG] match_17
#    i0 => [OK] Found i0 at vel_time idx=5455, t0=2.728s
#    iH => [OK] Found iH at vel_time idx=5455, tH=2.728s [SHIFT] iH => iH+1s at vel_time idx=9455, tH=4.728s
#    i2 => [OK] Found i2 at vel_time idx=14443, t2=7.222s
#    i3 => [OK] Refined i3 at vel_time idx=30620, t3=15.310s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(2)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_17_debug_vel.png
# [SAVED] match_17 => Phase1: 8988 frames, Phase2: 16177 frames.
#
# [DEBUG] match_18
#    i0 => [OK] Found i0 at vel_time idx=8445, t0=4.223s
#    iH => [OK] Found iH at vel_time idx=8445, tH=4.223s [SHIFT] iH => iH+1s at vel_time idx=12445, tH=6.223s
#    i2 => [OK] Found i2 at vel_time idx=15312, t2=7.656s
#    i3 => [OK] Refined i3 at vel_time idx=28518, t3=14.259s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(2)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_18_debug_vel.png
# [SAVED] match_18 => Phase1: 6867 frames, Phase2: 13206 frames.
#
# [DEBUG] match_19
#    i0 => [OK] Found i0 at vel_time idx=4635, t0=2.318s
#    iH => [OK] Found iH at vel_time idx=4635, tH=2.318s [SHIFT] iH => iH+1s at vel_time idx=8635, tH=4.318s
#    i2 => [OK] Found i2 at vel_time idx=11244, t2=5.622s
#    i3 => [OK] Refined i3 at vel_time idx=27189, t3=13.595s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(2)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_19_debug_vel.png
# [SAVED] match_19 => Phase1: 6609 frames, Phase2: 15945 frames.
#
# [DEBUG] match_20
#    i0 => [OK] Found i0 at vel_time idx=3006, t0=1.503s
#    iH => [OK] Found iH at vel_time idx=3006, tH=1.503s [SHIFT] iH => iH+1s at vel_time idx=7006, tH=3.503s
#    i2 => [OK] Found i2 at vel_time idx=7813, t2=3.907s
#    i3 => [OK] Refined i3 at vel_time idx=25167, t3=12.584s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(2)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_20_debug_vel.png
# [SAVED] match_20 => Phase1: 4807 frames, Phase2: 17354 frames.
#
# [DEBUG] match_21
#    i0 => [OK] Found i0 at vel_time idx=4107, t0=2.054s
#    iH => [OK] Found iH at vel_time idx=4107, tH=2.054s [SHIFT] iH => iH+1s at vel_time idx=8107, tH=4.054s
#    i2 => [OK] Found i2 at vel_time idx=12071, t2=6.036s
#    i3 => [OK] Refined i3 at vel_time idx=25330, t3=12.665s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(2)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_21_debug_vel.png
# [SAVED] match_21 => Phase1: 7964 frames, Phase2: 13259 frames.
#
# [DEBUG] match_22
#    i0 => [OK] Found i0 at vel_time idx=4295, t0=2.148s
#    iH => [OK] Found iH at vel_time idx=4295, tH=2.148s [SHIFT] iH => iH+1s at vel_time idx=8295, tH=4.148s
#    i2 => [OK] Found i2 at vel_time idx=14895, t2=7.448s
#    i3 => [OK] Refined i3 at vel_time idx=31341, t3=15.671s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(2)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_22_debug_vel.png
# [SAVED] match_22 => Phase1: 10600 frames, Phase2: 16446 frames.
#
# [DEBUG] match_23
#    i0 => [OK] Found i0 at vel_time idx=2455, t0=1.228s
#    iH => [OK] Found iH at vel_time idx=2455, tH=1.228s [SHIFT] iH => iH+1s at vel_time idx=6455, tH=3.228s
#    i2 => [OK] Found i2 at vel_time idx=10367, t2=5.184s
#    i3 => [OK] Refined i3 at vel_time idx=29148, t3=14.574s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(2)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_23_debug_vel.png
# [SAVED] match_23 => Phase1: 7912 frames, Phase2: 18781 frames.
#
# [DEBUG] match_24
#    i0 => [OK] Found i0 at vel_time idx=6157, t0=3.079s
#    iH => [OK] Found iH at vel_time idx=6157, tH=3.079s [SHIFT] iH => iH+1s at vel_time idx=10157, tH=5.079s
#    i2 => [OK] Found i2 at vel_time idx=16159, t2=8.080s
#    i3 => [OK] Refined i3 at vel_time idx=32283, t3=16.142s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(2)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_24_debug_vel.png
# [SAVED] match_24 => Phase1: 10002 frames, Phase2: 16124 frames.
#
# [DEBUG] match_01
#    i0 => [OK] Found i0 at vel_time idx=26170, t0=13.085s
#    iH => [OK] Found iH at vel_time idx=26170, tH=13.085s [SHIFT] iH => iH+1s at vel_time idx=30170, tH=15.085s
#    i2 => [OK] Found i2 at vel_time idx=31470, t2=15.735s
#    i3 => [OK] Refined i3 at vel_time idx=44393, t3=22.197s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(3)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_01_debug_vel.png
# [SAVED] match_01 => Phase1: 5300 frames, Phase2: 12923 frames.
#
# [DEBUG] match_02
#    i0 => [OK] Found i0 at vel_time idx=8531, t0=4.266s
#    iH => [OK] Found iH at vel_time idx=8531, tH=4.266s [SHIFT] iH => iH+1s at vel_time idx=12531, tH=6.266s
#    i2 => [OK] Found i2 at vel_time idx=14358, t2=7.179s
#    i3 => [OK] Refined i3 at vel_time idx=26386, t3=13.193s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(3)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_02_debug_vel.png
# [SAVED] match_02 => Phase1: 5827 frames, Phase2: 12028 frames.
#
# [DEBUG] match_03
#    i0 => [OK] Found i0 at vel_time idx=6754, t0=3.377s
#    iH => [OK] Found iH at vel_time idx=6754, tH=3.377s [SHIFT] iH => iH+1s at vel_time idx=10754, tH=5.377s
#    i2 => [OK] Found i2 at vel_time idx=10962, t2=5.481s
#    i3 => [OK] Refined i3 at vel_time idx=23589, t3=11.795s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(3)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_03_debug_vel.png
# [SAVED] match_03 => Phase1: 4208 frames, Phase2: 12627 frames.
#
# [DEBUG] match_04
#    i0 => [OK] Found i0 at vel_time idx=8281, t0=4.141s
#    iH => [OK] Found iH at vel_time idx=8281, tH=4.141s [SHIFT] iH => iH+1s at vel_time idx=12281, tH=6.141s
#    i2 => [OK] Found i2 at vel_time idx=12281, t2=6.141s
#    i3 => [OK] Refined i3 at vel_time idx=27306, t3=13.653s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(3)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_04_debug_vel.png
# [SAVED] match_04 => Phase1: 4000 frames, Phase2: 15025 frames.
#
# [DEBUG] match_05
#    i0 => [OK] Found i0 at vel_time idx=9173, t0=4.587s
#    iH => [OK] Found iH at vel_time idx=9173, tH=4.587s [SHIFT] iH => iH+1s at vel_time idx=13173, tH=6.587s
#    i2 => [OK] Found i2 at vel_time idx=14557, t2=7.279s
#    i3 => [OK] Refined i3 at vel_time idx=26536, t3=13.268s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(3)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_05_debug_vel.png
# [SAVED] match_05 => Phase1: 5384 frames, Phase2: 11979 frames.
#
# [DEBUG] match_06
#    i0 => [OK] Found i0 at vel_time idx=9569, t0=4.785s
#    iH => [OK] Found iH at vel_time idx=9569, tH=4.785s [SHIFT] iH => iH+1s at vel_time idx=13569, tH=6.785s
#    i2 => [OK] Found i2 at vel_time idx=14218, t2=7.109s
#    i3 => [OK] Refined i3 at vel_time idx=23868, t3=11.934s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(3)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_06_debug_vel.png
# [SAVED] match_06 => Phase1: 4649 frames, Phase2: 9650 frames.
#
# [DEBUG] match_07
#    i0 => [OK] Found i0 at vel_time idx=11174, t0=5.587s
#    iH => [OK] Found iH at vel_time idx=11174, tH=5.587s [SHIFT] iH => iH+1s at vel_time idx=15174, tH=7.587s
#    i2 => [OK] Found i2 at vel_time idx=15260, t2=7.630s
#    i3 => [OK] Refined i3 at vel_time idx=26850, t3=13.425s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(3)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_07_debug_vel.png
# [SAVED] match_07 => Phase1: 4086 frames, Phase2: 11590 frames.
#
# [DEBUG] match_08
#    i0 => [OK] Found i0 at vel_time idx=10010, t0=5.005s
#    iH => [OK] Found iH at vel_time idx=10010, tH=5.005s [SHIFT] iH => iH+1s at vel_time idx=14010, tH=7.005s
#    i2 => [OK] Found i2 at vel_time idx=17464, t2=8.732s
#    i3 => [OK] Refined i3 at vel_time idx=32136, t3=16.068s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(3)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_08_debug_vel.png
# [SAVED] match_08 => Phase1: 7454 frames, Phase2: 14672 frames.
#
# [DEBUG] match_09
#    i0 => [OK] Found i0 at vel_time idx=8312, t0=4.156s
#    iH => [OK] Found iH at vel_time idx=8312, tH=4.156s [SHIFT] iH => iH+1s at vel_time idx=12312, tH=6.156s
#    i2 => [OK] Found i2 at vel_time idx=13808, t2=6.904s
#    i3 => [OK] Refined i3 at vel_time idx=27480, t3=13.740s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(3)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_09_debug_vel.png
# [SAVED] match_09 => Phase1: 5496 frames, Phase2: 13672 frames.
#
# [DEBUG] match_10
#    i0 => [OK] Found i0 at vel_time idx=5871, t0=2.936s
#    iH => [OK] Found iH at vel_time idx=5871, tH=2.936s [SHIFT] iH => iH+1s at vel_time idx=9871, tH=4.936s
#    i2 => [OK] Found i2 at vel_time idx=10232, t2=5.116s
#    i3 => [OK] Refined i3 at vel_time idx=35665, t3=17.833s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(3)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_10_debug_vel.png
# [SAVED] match_10 => Phase1: 4361 frames, Phase2: 25433 frames.
#
# [DEBUG] match_11
#    i0 => [OK] Found i0 at vel_time idx=8825, t0=4.413s
#    iH => [OK] Found iH at vel_time idx=8825, tH=4.413s [SHIFT] iH => iH+1s at vel_time idx=12825, tH=6.413s
#    i2 => [OK] Found i2 at vel_time idx=15119, t2=7.560s
#    i3 => [OK] Refined i3 at vel_time idx=32781, t3=16.391s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(3)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_11_debug_vel.png
# [SAVED] match_11 => Phase1: 6294 frames, Phase2: 17662 frames.
#
# [DEBUG] match_12
#    i0 => [OK] Found i0 at vel_time idx=9207, t0=4.604s
#    iH => [OK] Found iH at vel_time idx=9207, tH=4.604s [SHIFT] iH => iH+1s at vel_time idx=13207, tH=6.604s
#    i2 => [OK] Found i2 at vel_time idx=14065, t2=7.033s
#    i3 => [OK] Refined i3 at vel_time idx=27602, t3=13.801s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(3)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_12_debug_vel.png
# [SAVED] match_12 => Phase1: 4858 frames, Phase2: 13537 frames.
#
# [DEBUG] match_13
#    i0 => [OK] Found i0 at vel_time idx=6859, t0=3.430s
#    iH => [OK] Found iH at vel_time idx=6859, tH=3.430s [SHIFT] iH => iH+1s at vel_time idx=10859, tH=5.430s
#    i2 => [OK] Found i2 at vel_time idx=10859, t2=5.430s
#    i3 => [OK] Refined i3 at vel_time idx=26337, t3=13.169s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(3)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_13_debug_vel.png
# [SAVED] match_13 => Phase1: 4000 frames, Phase2: 15478 frames.
#
# [DEBUG] match_14
#    i0 => [OK] Found i0 at vel_time idx=6361, t0=3.181s
#    iH => [OK] Found iH at vel_time idx=6361, tH=3.181s [SHIFT] iH => iH+1s at vel_time idx=10361, tH=5.181s
#    i2 => [OK] Found i2 at vel_time idx=12950, t2=6.475s
#    i3 => [OK] Refined i3 at vel_time idx=26785, t3=13.393s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(3)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_14_debug_vel.png
# [SAVED] match_14 => Phase1: 6589 frames, Phase2: 13835 frames.
#
# [DEBUG] match_15
#    i0 => [OK] Found i0 at vel_time idx=6604, t0=3.302s
#    iH => [OK] Found iH at vel_time idx=6604, tH=3.302s [SHIFT] iH => iH+1s at vel_time idx=10604, tH=5.302s
#    i2 => [OK] Found i2 at vel_time idx=13497, t2=6.749s
#    i3 => [OK] Refined i3 at vel_time idx=26454, t3=13.227s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(3)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_15_debug_vel.png
# [SAVED] match_15 => Phase1: 6893 frames, Phase2: 12957 frames.
#
# [DEBUG] match_16
#    i0 => [OK] Found i0 at vel_time idx=7430, t0=3.715s
#    iH => [OK] Found iH at vel_time idx=7430, tH=3.715s [SHIFT] iH => iH+1s at vel_time idx=11430, tH=5.715s
#    i2 => [OK] Found i2 at vel_time idx=13718, t2=6.859s
#    i3 => [OK] Refined i3 at vel_time idx=28116, t3=14.058s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(3)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_16_debug_vel.png
# [SAVED] match_16 => Phase1: 6288 frames, Phase2: 14398 frames.
#
# [DEBUG] match_17
#    i0 => [OK] Found i0 at vel_time idx=7901, t0=3.951s
#    iH => [OK] Found iH at vel_time idx=7901, tH=3.951s [SHIFT] iH => iH+1s at vel_time idx=11901, tH=5.951s
#    i2 => [OK] Found i2 at vel_time idx=12665, t2=6.333s
#    i3 => [OK] Refined i3 at vel_time idx=26704, t3=13.352s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(3)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_17_debug_vel.png
# [SAVED] match_17 => Phase1: 4764 frames, Phase2: 14039 frames.
#
# [DEBUG] match_18
#    i0 => [OK] Found i0 at vel_time idx=12110, t0=6.055s
#    iH => [OK] Found iH at vel_time idx=12110, tH=6.055s [SHIFT] iH => iH+1s at vel_time idx=16110, tH=8.055s
#    i2 => [OK] Found i2 at vel_time idx=18480, t2=9.240s
#    i3 => [OK] Refined i3 at vel_time idx=33902, t3=16.951s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(3)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_18_debug_vel.png
# [SAVED] match_18 => Phase1: 6370 frames, Phase2: 15422 frames.
#
# [DEBUG] match_19
#    i0 => [OK] Found i0 at vel_time idx=7952, t0=3.976s
#    iH => [OK] Found iH at vel_time idx=7952, tH=3.976s [SHIFT] iH => iH+1s at vel_time idx=11952, tH=5.976s
#    i2 => [OK] Found i2 at vel_time idx=11998, t2=5.999s
#    i3 => [OK] Refined i3 at vel_time idx=26292, t3=13.146s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(3)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_19_debug_vel.png
# [SAVED] match_19 => Phase1: 4046 frames, Phase2: 14294 frames.
#
# [DEBUG] match_20
#    i0 => [OK] Found i0 at vel_time idx=8224, t0=4.112s
#    iH => [OK] Found iH at vel_time idx=8224, tH=4.112s [SHIFT] iH => iH+1s at vel_time idx=12224, tH=6.112s
#    i2 => [OK] Found i2 at vel_time idx=12224, t2=6.112s
#    i3 => [OK] Refined i3 at vel_time idx=27628, t3=13.814s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(3)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_20_debug_vel.png
# [SAVED] match_20 => Phase1: 4000 frames, Phase2: 15404 frames.
#
# [DEBUG] match_21
#    i0 => [OK] Found i0 at vel_time idx=7003, t0=3.502s
#    iH => [OK] Found iH at vel_time idx=7003, tH=3.502s [SHIFT] iH => iH+1s at vel_time idx=11003, tH=5.502s
#    i2 => [OK] Found i2 at vel_time idx=12193, t2=6.097s
#    i3 => [OK] Refined i3 at vel_time idx=25785, t3=12.893s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(3)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_21_debug_vel.png
# [SAVED] match_21 => Phase1: 5190 frames, Phase2: 13592 frames.
#
# [DEBUG] match_22
#    i0 => [OK] Found i0 at vel_time idx=4233, t0=2.117s
#    iH => [OK] Found iH at vel_time idx=4233, tH=2.117s [SHIFT] iH => iH+1s at vel_time idx=8233, tH=4.117s
#    i2 => [OK] Found i2 at vel_time idx=10781, t2=5.391s
#    i3 => [OK] Refined i3 at vel_time idx=23433, t3=11.717s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(3)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_22_debug_vel.png
# [SAVED] match_22 => Phase1: 6548 frames, Phase2: 12652 frames.
#
# [DEBUG] match_23
#    i0 => [OK] Found i0 at vel_time idx=6506, t0=3.253s
#    iH => [OK] Found iH at vel_time idx=6506, tH=3.253s [SHIFT] iH => iH+1s at vel_time idx=10506, tH=5.253s
#    i2 => [OK] Found i2 at vel_time idx=11744, t2=5.872s
#    i3 => [OK] Refined i3 at vel_time idx=26421, t3=13.211s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(3)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_23_debug_vel.png
# [SAVED] match_23 => Phase1: 5238 frames, Phase2: 14677 frames.
#
# [DEBUG] match_24
#    i0 => [OK] Found i0 at vel_time idx=7911, t0=3.956s
#    iH => [OK] Found iH at vel_time idx=7911, tH=3.956s [SHIFT] iH => iH+1s at vel_time idx=11911, tH=5.956s
#    i2 => [OK] Found i2 at vel_time idx=15284, t2=7.642s
#    i3 => [OK] Refined i3 at vel_time idx=27542, t3=13.771s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(3)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_24_debug_vel.png
# [SAVED] match_24 => Phase1: 7373 frames, Phase2: 12258 frames.
#
# [DEBUG] match_01
#    i0 => [OK] Found i0 at vel_time idx=10694, t0=5.347s
#    iH => [OK] Found iH at vel_time idx=10694, tH=5.347s [SHIFT] iH => iH+1s at vel_time idx=14694, tH=7.347s
#    i2 => [OK] Found i2 at vel_time idx=17764, t2=8.882s
#    i3 => [OK] Refined i3 at vel_time idx=33403, t3=16.702s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(4)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_01_debug_vel.png
# [SAVED] match_01 => Phase1: 7070 frames, Phase2: 15639 frames.
#
# [DEBUG] match_02
#    i0 => [OK] Found i0 at vel_time idx=8429, t0=4.215s
#    iH => [OK] Found iH at vel_time idx=8429, tH=4.215s [SHIFT] iH => iH+1s at vel_time idx=12429, tH=6.215s
#    i2 => [OK] Found i2 at vel_time idx=14570, t2=7.285s
#    i3 => [OK] Refined i3 at vel_time idx=31451, t3=15.726s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(4)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_02_debug_vel.png
# [SAVED] match_02 => Phase1: 6141 frames, Phase2: 16881 frames.
#
# [DEBUG] match_03
#    i0 => [OK] Found i0 at vel_time idx=7856, t0=3.928s
#    iH => [OK] Found iH at vel_time idx=7856, tH=3.928s [SHIFT] iH => iH+1s at vel_time idx=11856, tH=5.928s
#    i2 => [OK] Found i2 at vel_time idx=15379, t2=7.690s
#    i3 => [OK] Refined i3 at vel_time idx=33443, t3=16.722s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(4)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_03_debug_vel.png
# [SAVED] match_03 => Phase1: 7523 frames, Phase2: 18064 frames.
#
# [DEBUG] match_04
#    i0 => [OK] Found i0 at vel_time idx=7373, t0=3.687s
#    iH => [OK] Found iH at vel_time idx=7373, tH=3.687s [SHIFT] iH => iH+1s at vel_time idx=11373, tH=5.687s
#    i2 => [OK] Found i2 at vel_time idx=15168, t2=7.584s
#    i3 => [OK] Refined i3 at vel_time idx=29112, t3=14.556s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(4)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_04_debug_vel.png
# [SAVED] match_04 => Phase1: 7795 frames, Phase2: 13944 frames.
#
# [DEBUG] match_05
#    i0 => [OK] Found i0 at vel_time idx=3526, t0=1.763s
#    iH => [OK] Found iH at vel_time idx=3526, tH=1.763s [SHIFT] iH => iH+1s at vel_time idx=7526, tH=3.763s
#    i2 => [OK] Found i2 at vel_time idx=8977, t2=4.489s
#    i3 => [OK] Refined i3 at vel_time idx=24037, t3=12.019s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(4)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_05_debug_vel.png
# [SAVED] match_05 => Phase1: 5451 frames, Phase2: 15060 frames.
#
# [DEBUG] match_06
#    i0 => [OK] Found i0 at vel_time idx=28666, t0=14.333s
#    iH => [OK] Found iH at vel_time idx=28666, tH=14.333s [SHIFT] iH => iH+1s at vel_time idx=32666, tH=16.333s
#    i2 => [INFO] No Y-lift crossing found (< -10.0).
#    i3 => [OK] Refined i3 at vel_time idx=34229, t3=17.115s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(4)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_06_debug_vel_FAILED.png
# [INFO] Could not detect phases for match_06, skipping cropping.
#
# [DEBUG] match_07
#    i0 => [OK] Found i0 at vel_time idx=28480, t0=14.240s
#    iH => [OK] Found iH at vel_time idx=28480, tH=14.240s [SHIFT] iH => iH+1s at vel_time idx=31473, tH=15.737s
#    i2 => [INFO] No Y-lift crossing found (< -10.0).
#    i3 => [OK] Refined i3 at vel_time idx=31473, t3=15.737s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(4)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_07_debug_vel_FAILED.png
# [INFO] Could not detect phases for match_07, skipping cropping.
#
# [DEBUG] match_08
#    i0 => [INFO] No velocity > 70 => i0 not found.
#    iH =>
#    i2 =>
#    i3 =>
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(4)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_08_debug_vel_FAILED.png
# [INFO] Could not detect phases for match_08, skipping cropping.
#
# [DEBUG] match_09
#    i0 => [OK] Found i0 at vel_time idx=5206, t0=2.603s
#    iH => [OK] Found iH at vel_time idx=5206, tH=2.603s [SHIFT] iH => iH+1s at vel_time idx=9206, tH=4.603s
#    i2 => [OK] Found i2 at vel_time idx=9248, t2=4.624s
#    i3 => [OK] Refined i3 at vel_time idx=24529, t3=12.265s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(4)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_09_debug_vel.png
# [SAVED] match_09 => Phase1: 4042 frames, Phase2: 15281 frames.
#
# [DEBUG] match_10
#    i0 => [OK] Found i0 at vel_time idx=7526, t0=3.763s
#    iH => [OK] Found iH at vel_time idx=7526, tH=3.763s [SHIFT] iH => iH+1s at vel_time idx=11526, tH=5.763s
#    i2 => [OK] Found i2 at vel_time idx=12187, t2=6.094s
#    i3 => [OK] Refined i3 at vel_time idx=27878, t3=13.939s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(4)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_10_debug_vel.png
# [SAVED] match_10 => Phase1: 4661 frames, Phase2: 15691 frames.
#
# [DEBUG] match_11
#    i0 => [OK] Found i0 at vel_time idx=2963, t0=1.482s
#    iH => [OK] Found iH at vel_time idx=2963, tH=1.482s [SHIFT] iH => iH+1s at vel_time idx=6963, tH=3.482s
#    i2 => [OK] Found i2 at vel_time idx=7650, t2=3.825s
#    i3 => [OK] Refined i3 at vel_time idx=21144, t3=10.572s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(4)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_11_debug_vel.png
# [SAVED] match_11 => Phase1: 4687 frames, Phase2: 13494 frames.
#
# [DEBUG] match_12
#    i0 => [OK] Found i0 at vel_time idx=14946, t0=7.473s
#    iH => [OK] Found iH at vel_time idx=14946, tH=7.473s [SHIFT] iH => iH+1s at vel_time idx=18946, tH=9.473s
#    i2 => [OK] Found i2 at vel_time idx=27578, t2=13.789s
#    i3 => [OK] Refined i3 at vel_time idx=28944, t3=14.472s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(4)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_12_debug_vel.png
# [SAVED] match_12 => Phase1: 12632 frames, Phase2: 1366 frames.
#
# [DEBUG] match_13
#    i0 => [OK] Found i0 at vel_time idx=4740, t0=2.370s
#    iH => [OK] Found iH at vel_time idx=4740, tH=2.370s [SHIFT] iH => iH+1s at vel_time idx=8740, tH=4.370s
#    i2 => [OK] Found i2 at vel_time idx=9659, t2=4.830s
#    i3 => [OK] Refined i3 at vel_time idx=23233, t3=11.617s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(4)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_13_debug_vel.png
# [SAVED] match_13 => Phase1: 4919 frames, Phase2: 13574 frames.
#
# [DEBUG] match_14
#    i0 => [OK] Found i0 at vel_time idx=3559, t0=1.780s
#    iH => [OK] Found iH at vel_time idx=3559, tH=1.780s [SHIFT] iH => iH+1s at vel_time idx=7559, tH=3.780s
#    i2 => [OK] Found i2 at vel_time idx=9301, t2=4.651s
#    i3 => [OK] Refined i3 at vel_time idx=22242, t3=11.121s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(4)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_14_debug_vel.png
# [SAVED] match_14 => Phase1: 5742 frames, Phase2: 12941 frames.
#
# [DEBUG] match_15
#    i0 => [OK] Found i0 at vel_time idx=5520, t0=2.760s
#    iH => [OK] Found iH at vel_time idx=5520, tH=2.760s [SHIFT] iH => iH+1s at vel_time idx=9520, tH=4.760s
#    i2 => [OK] Found i2 at vel_time idx=11512, t2=5.756s
#    i3 => [OK] Refined i3 at vel_time idx=24685, t3=12.343s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(4)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_15_debug_vel.png
# [SAVED] match_15 => Phase1: 5992 frames, Phase2: 13173 frames.
#
# [DEBUG] match_16
#    i0 => [OK] Found i0 at vel_time idx=2398, t0=1.199s
#    iH => [OK] Found iH at vel_time idx=2398, tH=1.199s [SHIFT] iH => iH+1s at vel_time idx=6398, tH=3.199s
#    i2 => [OK] Found i2 at vel_time idx=8635, t2=4.318s
#    i3 => [OK] Refined i3 at vel_time idx=23222, t3=11.611s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(4)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_16_debug_vel.png
# [SAVED] match_16 => Phase1: 6237 frames, Phase2: 14587 frames.
#
# [DEBUG] match_17
#    i0 => [OK] Found i0 at vel_time idx=3553, t0=1.777s
#    iH => [OK] Found iH at vel_time idx=3553, tH=1.777s [SHIFT] iH => iH+1s at vel_time idx=7553, tH=3.777s
#    i2 => [OK] Found i2 at vel_time idx=10161, t2=5.081s
#    i3 => [OK] Refined i3 at vel_time idx=27154, t3=13.577s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(4)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_17_debug_vel.png
# [SAVED] match_17 => Phase1: 6608 frames, Phase2: 16993 frames.
#
# [DEBUG] match_18
#    i0 => [OK] Found i0 at vel_time idx=9091, t0=4.546s
#    iH => [OK] Found iH at vel_time idx=9091, tH=4.546s [SHIFT] iH => iH+1s at vel_time idx=13091, tH=6.546s
#    i2 => [OK] Found i2 at vel_time idx=14580, t2=7.290s
#    i3 => [OK] Refined i3 at vel_time idx=28692, t3=14.346s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(4)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_18_debug_vel.png
# [SAVED] match_18 => Phase1: 5489 frames, Phase2: 14112 frames.
#
# [DEBUG] match_19
#    i0 => [OK] Found i0 at vel_time idx=23829, t0=11.915s
#    iH => [OK] Found iH at vel_time idx=23829, tH=11.915s [SHIFT] iH => iH+1s at vel_time idx=26281, tH=13.141s
#    i2 => [INFO] No Y-lift crossing found (< -10.0).
#    i3 => [OK] Refined i3 at vel_time idx=26281, t3=13.141s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(4)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_19_debug_vel_FAILED.png
# [INFO] Could not detect phases for match_19, skipping cropping.
#
# [DEBUG] match_20
#    i0 => [OK] Found i0 at vel_time idx=23158, t0=11.579s
#    iH => [OK] Found iH at vel_time idx=23158, tH=11.579s [SHIFT] iH => iH+1s at vel_time idx=27158, tH=13.579s
#    i2 => [INFO] No Y-lift crossing found (< -10.0).
#    i3 => [OK] Refined i3 at vel_time idx=27242, t3=13.621s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(4)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_20_debug_vel_FAILED.png
# [INFO] Could not detect phases for match_20, skipping cropping.
#
# [DEBUG] match_21
#    i0 => [OK] Found i0 at vel_time idx=15579, t0=7.790s
#    iH => [OK] Found iH at vel_time idx=15579, tH=7.790s [SHIFT] iH => iH+1s at vel_time idx=19579, tH=9.790s
#    i2 => [OK] Found i2 at vel_time idx=21055, t2=10.528s
#    i3 => [OK] Refined i3 at vel_time idx=36646, t3=18.323s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(4)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_21_debug_vel.png
# [SAVED] match_21 => Phase1: 5476 frames, Phase2: 15591 frames.
#
# [DEBUG] match_22
#    i0 => [OK] Found i0 at vel_time idx=1015, t0=0.508s
#    iH => [OK] Found iH at vel_time idx=1015, tH=0.508s [SHIFT] iH => iH+1s at vel_time idx=5015, tH=2.508s
#    i2 => [OK] Found i2 at vel_time idx=7665, t2=3.833s
#    i3 => [OK] Refined i3 at vel_time idx=21583, t3=10.792s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(4)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_22_debug_vel.png
# [SAVED] match_22 => Phase1: 6650 frames, Phase2: 13918 frames.
#
# [DEBUG] match_23
#    i0 => [OK] Found i0 at vel_time idx=4891, t0=2.446s
#    iH => [OK] Found iH at vel_time idx=4891, tH=2.446s [SHIFT] iH => iH+1s at vel_time idx=8891, tH=4.446s
#    i2 => [OK] Found i2 at vel_time idx=10318, t2=5.159s
#    i3 => [OK] Refined i3 at vel_time idx=24312, t3=12.156s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(4)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_23_debug_vel.png
# [SAVED] match_23 => Phase1: 5427 frames, Phase2: 13994 frames.
#
# [DEBUG] match_24
#    i0 => [INFO] Could not find a pre-high drop < 15 => i0 not found.
#    iH =>
#    i2 =>
#    i3 =>
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(4)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_24_debug_vel_FAILED.png
# [INFO] Could not detect phases for match_24, skipping cropping.
#
# [DEBUG] match_01
#    i0 => [OK] Found i0 at vel_time idx=5094, t0=2.547s
#    iH => [OK] Found iH at vel_time idx=5094, tH=2.547s [SHIFT] iH => iH+1s at vel_time idx=9094, tH=4.547s
#    i2 => [OK] Found i2 at vel_time idx=12892, t2=6.446s
#    i3 => [OK] Refined i3 at vel_time idx=29508, t3=14.754s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_01_debug_vel.png
# [SAVED] match_01 => Phase1: 7798 frames, Phase2: 16616 frames.
#
# [DEBUG] match_02
#    i0 => [OK] Found i0 at vel_time idx=3551, t0=1.776s
#    iH => [OK] Found iH at vel_time idx=3551, tH=1.776s [SHIFT] iH => iH+1s at vel_time idx=7551, tH=3.776s
#    i2 => [OK] Found i2 at vel_time idx=10514, t2=5.257s
#    i3 => [OK] Refined i3 at vel_time idx=27339, t3=13.670s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_02_debug_vel.png
# [SAVED] match_02 => Phase1: 6963 frames, Phase2: 16825 frames.
#
# [DEBUG] match_03
#    i0 => [OK] Found i0 at vel_time idx=3711, t0=1.856s
#    iH => [OK] Found iH at vel_time idx=3711, tH=1.856s [SHIFT] iH => iH+1s at vel_time idx=7711, tH=3.856s
#    i2 => [OK] Found i2 at vel_time idx=10909, t2=5.455s
#    i3 => [OK] Refined i3 at vel_time idx=24299, t3=12.150s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_03_debug_vel.png
# [SAVED] match_03 => Phase1: 7198 frames, Phase2: 13390 frames.
#
# [DEBUG] match_04
#    i0 => [OK] Found i0 at vel_time idx=12228, t0=6.114s
#    iH => [OK] Found iH at vel_time idx=12228, tH=6.114s [SHIFT] iH => iH+1s at vel_time idx=16228, tH=8.114s
#    i2 => [OK] Found i2 at vel_time idx=20659, t2=10.330s
#    i3 => [OK] Refined i3 at vel_time idx=33317, t3=16.659s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_04_debug_vel.png
# [SAVED] match_04 => Phase1: 8431 frames, Phase2: 12658 frames.
#
# [DEBUG] match_05
#    i0 => [OK] Found i0 at vel_time idx=3985, t0=1.993s
#    iH => [OK] Found iH at vel_time idx=3985, tH=1.993s [SHIFT] iH => iH+1s at vel_time idx=7985, tH=3.993s
#    i2 => [OK] Found i2 at vel_time idx=12226, t2=6.113s
#    i3 => [OK] Refined i3 at vel_time idx=27900, t3=13.950s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_05_debug_vel.png
# [SAVED] match_05 => Phase1: 8241 frames, Phase2: 15674 frames.
#
# [DEBUG] match_06
#    i0 => [OK] Found i0 at vel_time idx=2085, t0=1.043s
#    iH => [OK] Found iH at vel_time idx=2085, tH=1.043s [SHIFT] iH => iH+1s at vel_time idx=6085, tH=3.043s
#    i2 => [OK] Found i2 at vel_time idx=9181, t2=4.591s
#    i3 => [OK] Refined i3 at vel_time idx=21742, t3=10.871s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_06_debug_vel.png
# [SAVED] match_06 => Phase1: 7096 frames, Phase2: 12561 frames.
#
# [DEBUG] match_07
#    i0 => [OK] Found i0 at vel_time idx=4162, t0=2.081s
#    iH => [OK] Found iH at vel_time idx=4162, tH=2.081s [SHIFT] iH => iH+1s at vel_time idx=8162, tH=4.081s
#    i2 => [OK] Found i2 at vel_time idx=11888, t2=5.944s
#    i3 => [OK] Refined i3 at vel_time idx=27588, t3=13.794s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_07_debug_vel.png
# [SAVED] match_07 => Phase1: 7726 frames, Phase2: 15700 frames.
#
# [DEBUG] match_08
#    i0 => [OK] Found i0 at vel_time idx=2072, t0=1.036s
#    iH => [OK] Found iH at vel_time idx=2072, tH=1.036s [SHIFT] iH => iH+1s at vel_time idx=6072, tH=3.036s
#    i2 => [OK] Found i2 at vel_time idx=10649, t2=5.325s
#    i3 => [OK] Refined i3 at vel_time idx=23707, t3=11.854s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_08_debug_vel.png
# [SAVED] match_08 => Phase1: 8577 frames, Phase2: 13058 frames.
#
# [DEBUG] match_09
#    i0 => [OK] Found i0 at vel_time idx=5052, t0=2.526s
#    iH => [OK] Found iH at vel_time idx=5052, tH=2.526s [SHIFT] iH => iH+1s at vel_time idx=9052, tH=4.526s
#    i2 => [OK] Found i2 at vel_time idx=12920, t2=6.460s
#    i3 => [OK] Refined i3 at vel_time idx=27165, t3=13.583s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_09_debug_vel.png
# [SAVED] match_09 => Phase1: 7868 frames, Phase2: 14245 frames.
#
# [DEBUG] match_10
#    i0 => [OK] Found i0 at vel_time idx=4005, t0=2.003s
#    iH => [OK] Found iH at vel_time idx=4005, tH=2.003s [SHIFT] iH => iH+1s at vel_time idx=8005, tH=4.003s
#    i2 => [OK] Found i2 at vel_time idx=13676, t2=6.838s
#    i3 => [OK] Refined i3 at vel_time idx=28372, t3=14.186s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_10_debug_vel.png
# [SAVED] match_10 => Phase1: 9671 frames, Phase2: 14696 frames.
#
# [DEBUG] match_11
#    i0 => [OK] Found i0 at vel_time idx=4824, t0=2.412s
#    iH => [OK] Found iH at vel_time idx=4824, tH=2.412s [SHIFT] iH => iH+1s at vel_time idx=8824, tH=4.412s
#    i2 => [OK] Found i2 at vel_time idx=13528, t2=6.764s
#    i3 => [OK] Refined i3 at vel_time idx=30735, t3=15.368s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_11_debug_vel.png
# [SAVED] match_11 => Phase1: 8704 frames, Phase2: 17207 frames.
#
# [DEBUG] match_12
#    i0 => [OK] Found i0 at vel_time idx=8294, t0=4.147s
#    iH => [OK] Found iH at vel_time idx=8294, tH=4.147s [SHIFT] iH => iH+1s at vel_time idx=12294, tH=6.147s
#    i2 => [OK] Found i2 at vel_time idx=18680, t2=9.340s
#    i3 => [OK] Refined i3 at vel_time idx=33125, t3=16.563s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_12_debug_vel.png
# [SAVED] match_12 => Phase1: 10386 frames, Phase2: 14445 frames.
#
# [DEBUG] match_13
#    i0 => [OK] Found i0 at vel_time idx=4182, t0=2.091s
#    iH => [OK] Found iH at vel_time idx=4182, tH=2.091s [SHIFT] iH => iH+1s at vel_time idx=8182, tH=4.091s
#    i2 => [OK] Found i2 at vel_time idx=14090, t2=7.045s
#    i3 => [OK] Refined i3 at vel_time idx=30797, t3=15.399s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_13_debug_vel.png
# [SAVED] match_13 => Phase1: 9908 frames, Phase2: 16707 frames.
#
# [DEBUG] match_14
#    i0 => [OK] Found i0 at vel_time idx=8974, t0=4.487s
#    iH => [OK] Found iH at vel_time idx=8974, tH=4.487s [SHIFT] iH => iH+1s at vel_time idx=12974, tH=6.487s
#    i2 => [OK] Found i2 at vel_time idx=17668, t2=8.834s
#    i3 => [OK] Refined i3 at vel_time idx=31432, t3=15.716s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_14_debug_vel.png
# [SAVED] match_14 => Phase1: 8694 frames, Phase2: 13764 frames.
#
# [DEBUG] match_15
#    i0 => [OK] Found i0 at vel_time idx=6551, t0=3.276s
#    iH => [OK] Found iH at vel_time idx=6551, tH=3.276s [SHIFT] iH => iH+1s at vel_time idx=10551, tH=5.276s
#    i2 => [OK] Found i2 at vel_time idx=16750, t2=8.375s
#    i3 => [OK] Refined i3 at vel_time idx=31380, t3=15.690s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_15_debug_vel.png
# [SAVED] match_15 => Phase1: 10199 frames, Phase2: 14630 frames.
#
# [DEBUG] match_16
#    i0 => [OK] Found i0 at vel_time idx=4606, t0=2.303s
#    iH => [OK] Found iH at vel_time idx=4606, tH=2.303s [SHIFT] iH => iH+1s at vel_time idx=8606, tH=4.303s
#    i2 => [OK] Found i2 at vel_time idx=14429, t2=7.215s
#    i3 => [OK] Refined i3 at vel_time idx=29596, t3=14.798s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(5)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_16_debug_vel.png
# [SAVED] match_16 => Phase1: 9823 frames, Phase2: 15167 frames.
#
# [DEBUG] match_17
#    i0 => [OK] Found i0 at vel_time idx=5158, t0=2.579s
#    iH => [OK] Found iH at vel_time idx=5158, tH=2.579s [SHIFT] iH => iH+1s at vel_time idx=9158, tH=4.579s
#    i2 => [OK] Found i2 at vel_time idx=14234, t2=7.117s
#    i3 => [OK] Refined i3 at vel_time idx=31896, t3=15.948s
# ...
#
# [DEBUG] match_19
#    i0 => [OK] Found i0 at vel_time idx=9131, t0=4.566s
#    iH => [OK] Found iH at vel_time idx=9131, tH=4.566s [SHIFT] iH => iH+1s at vel_time idx=13131, tH=6.566s
#    i2 => [OK] Found i2 at vel_time idx=16203, t2=8.102s
#    i3 => [OK] Refined i3 at vel_time idx=27474, t3=13.737s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(7)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_19_debug_vel.png
# [SAVED] match_19 => Phase1: 7072 frames, Phase2: 11271 frames.
#
# [DEBUG] match_20
#    i0 => [OK] Found i0 at vel_time idx=21940, t0=10.970s
#    iH => [OK] Found iH at vel_time idx=21940, tH=10.970s [SHIFT] iH => iH+1s at vel_time idx=25940, tH=12.970s
#    i2 => [INFO] No Y-lift crossing found (< -10.0).
#    i3 => [OK] Refined i3 at vel_time idx=27560, t3=13.780s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(7)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_20_debug_vel_FAILED.png
# [INFO] Could not detect phases for match_20, skipping cropping.
#
# [DEBUG] match_21
#    i0 => [OK] Found i0 at vel_time idx=2316, t0=1.158s
#    iH => [OK] Found iH at vel_time idx=2316, tH=1.158s [SHIFT] iH => iH+1s at vel_time idx=6316, tH=3.158s
#    i2 => [OK] Found i2 at vel_time idx=7660, t2=3.830s
#    i3 => [OK] Refined i3 at vel_time idx=19316, t3=9.658s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(7)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_21_debug_vel.png
# [SAVED] match_21 => Phase1: 5344 frames, Phase2: 11656 frames.
#
# [DEBUG] match_22
#    i0 => [INFO] No velocity > 70 => i0 not found.
#    iH =>
#    i2 =>
#    i3 =>
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(7)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_22_debug_vel_FAILED.png
# [INFO] Could not detect phases for match_22, skipping cropping.
#
# [DEBUG] match_23
#    i0 => [OK] Found i0 at vel_time idx=3977, t0=1.989s
#    iH => [OK] Found iH at vel_time idx=3977, tH=1.989s [SHIFT] iH => iH+1s at vel_time idx=7977, tH=3.989s
#    i2 => [OK] Found i2 at vel_time idx=9561, t2=4.781s
#    i3 => [OK] Refined i3 at vel_time idx=22204, t3=11.102s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(7)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_23_debug_vel.png
# [SAVED] match_23 => Phase1: 5584 frames, Phase2: 12643 frames.
#
# [DEBUG] match_24
#    i0 => [OK] Found i0 at vel_time idx=4532, t0=2.266s
#    iH => [OK] Found iH at vel_time idx=4532, tH=2.266s [SHIFT] iH => iH+1s at vel_time idx=8532, tH=4.266s
#    i2 => [OK] Found i2 at vel_time idx=10427, t2=5.214s
#    i3 => [OK] Refined i3 at vel_time idx=22440, t3=11.220s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(7)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_24_debug_vel.png
# [SAVED] match_24 => Phase1: 5895 frames, Phase2: 12013 frames.
#
# [DEBUG] match_01
#    i0 => [OK] Found i0 at vel_time idx=6552, t0=3.276s
#    iH => [OK] Found iH at vel_time idx=6552, tH=3.276s [SHIFT] iH => iH+1s at vel_time idx=10552, tH=5.276s
#    i2 => [OK] Found i2 at vel_time idx=12687, t2=6.344s
#    i3 => [OK] Refined i3 at vel_time idx=28308, t3=14.154s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_01_debug_vel.png
# [SAVED] match_01 => Phase1: 6135 frames, Phase2: 15621 frames.
#
# [DEBUG] match_02
#    i0 => [OK] Found i0 at vel_time idx=10372, t0=5.186s
#    iH => [OK] Found iH at vel_time idx=10372, tH=5.186s [SHIFT] iH => iH+1s at vel_time idx=14372, tH=7.186s
#    i2 => [OK] Found i2 at vel_time idx=16934, t2=8.467s
#    i3 => [OK] Refined i3 at vel_time idx=34143, t3=17.072s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_02_debug_vel.png
# [SAVED] match_02 => Phase1: 6562 frames, Phase2: 17209 frames.
#
# [DEBUG] match_03
#    i0 => [OK] Found i0 at vel_time idx=7518, t0=3.759s
#    iH => [OK] Found iH at vel_time idx=7518, tH=3.759s [SHIFT] iH => iH+1s at vel_time idx=11518, tH=5.759s
#    i2 => [OK] Found i2 at vel_time idx=13634, t2=6.817s
#    i3 => [OK] Refined i3 at vel_time idx=29617, t3=14.809s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_03_debug_vel.png
# [SAVED] match_03 => Phase1: 6116 frames, Phase2: 15983 frames.
#
# [DEBUG] match_04
#    i0 => [OK] Found i0 at vel_time idx=5823, t0=2.912s
#    iH => [OK] Found iH at vel_time idx=5823, tH=2.912s [SHIFT] iH => iH+1s at vel_time idx=9823, tH=4.912s
#    i2 => [OK] Found i2 at vel_time idx=12630, t2=6.315s
#    i3 => [OK] Refined i3 at vel_time idx=30010, t3=15.005s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_04_debug_vel.png
# [SAVED] match_04 => Phase1: 6807 frames, Phase2: 17380 frames.
#
# [DEBUG] match_05
#    i0 => [OK] Found i0 at vel_time idx=5788, t0=2.894s
#    iH => [OK] Found iH at vel_time idx=5788, tH=2.894s [SHIFT] iH => iH+1s at vel_time idx=9788, tH=4.894s
#    i2 => [OK] Found i2 at vel_time idx=11402, t2=5.701s
#    i3 => [OK] Refined i3 at vel_time idx=26633, t3=13.317s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_05_debug_vel.png
# [SAVED] match_05 => Phase1: 5614 frames, Phase2: 15231 frames.
#
# [DEBUG] match_06
#    i0 => [OK] Found i0 at vel_time idx=5771, t0=2.886s
#    iH => [OK] Found iH at vel_time idx=5771, tH=2.886s [SHIFT] iH => iH+1s at vel_time idx=9771, tH=4.886s
#    i2 => [OK] Found i2 at vel_time idx=13077, t2=6.539s
#    i3 => [OK] Refined i3 at vel_time idx=30140, t3=15.070s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_06_debug_vel.png
# [SAVED] match_06 => Phase1: 7306 frames, Phase2: 17063 frames.
#
# [DEBUG] match_07
#    i0 => [OK] Found i0 at vel_time idx=6543, t0=3.272s
#    iH => [OK] Found iH at vel_time idx=6543, tH=3.272s [SHIFT] iH => iH+1s at vel_time idx=10543, tH=5.272s
#    i2 => [OK] Found i2 at vel_time idx=13850, t2=6.925s
#    i3 => [OK] Refined i3 at vel_time idx=31632, t3=15.816s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_07_debug_vel.png
# [SAVED] match_07 => Phase1: 7307 frames, Phase2: 17782 frames.
#
# [DEBUG] match_08
#    i0 => [OK] Found i0 at vel_time idx=7941, t0=3.971s
#    iH => [OK] Found iH at vel_time idx=7941, tH=3.971s [SHIFT] iH => iH+1s at vel_time idx=11941, tH=5.971s
#    i2 => [OK] Found i2 at vel_time idx=14214, t2=7.107s
#    i3 => [OK] Refined i3 at vel_time idx=35319, t3=17.660s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_08_debug_vel.png
# [SAVED] match_08 => Phase1: 6273 frames, Phase2: 21105 frames.
#
# [DEBUG] match_09
#    i0 => [INFO] Could not find a pre-high drop < 15 => i0 not found.
#    iH =>
#    i2 =>
#    i3 =>
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_09_debug_vel_FAILED.png
# [INFO] Could not detect phases for match_09, skipping cropping.
#
# [DEBUG] match_10
#    i0 => [OK] Found i0 at vel_time idx=5452, t0=2.726s
#    iH => [OK] Found iH at vel_time idx=5452, tH=2.726s [SHIFT] iH => iH+1s at vel_time idx=9452, tH=4.726s
#    i2 => [OK] Found i2 at vel_time idx=9452, t2=4.726s
#    i3 => [OK] Refined i3 at vel_time idx=28733, t3=14.367s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_10_debug_vel.png
# [SAVED] match_10 => Phase1: 4000 frames, Phase2: 19281 frames.
#
# [DEBUG] match_11
#    i0 => [OK] Found i0 at vel_time idx=5690, t0=2.845s
#    iH => [OK] Found iH at vel_time idx=5690, tH=2.845s [SHIFT] iH => iH+1s at vel_time idx=9690, tH=4.845s
#    i2 => [OK] Found i2 at vel_time idx=12501, t2=6.251s
#    i3 => [OK] Refined i3 at vel_time idx=29422, t3=14.711s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_11_debug_vel.png
# [SAVED] match_11 => Phase1: 6811 frames, Phase2: 16921 frames.
#
# [DEBUG] match_12
#    i0 => [OK] Found i0 at vel_time idx=6156, t0=3.078s
#    iH => [OK] Found iH at vel_time idx=6156, tH=3.078s [SHIFT] iH => iH+1s at vel_time idx=10156, tH=5.078s
#    i2 => [OK] Found i2 at vel_time idx=10156, t2=5.078s
#    i3 => [OK] Refined i3 at vel_time idx=29749, t3=14.875s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_12_debug_vel.png
# [SAVED] match_12 => Phase1: 4000 frames, Phase2: 19593 frames.
#
# [DEBUG] match_13
#    i0 => [OK] Found i0 at vel_time idx=4273, t0=2.137s
#    iH => [OK] Found iH at vel_time idx=4273, tH=2.137s [SHIFT] iH => iH+1s at vel_time idx=8273, tH=4.137s
#    i2 => [OK] Found i2 at vel_time idx=11643, t2=5.822s
#    i3 => [OK] Refined i3 at vel_time idx=25739, t3=12.870s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_13_debug_vel.png
# [SAVED] match_13 => Phase1: 7370 frames, Phase2: 14096 frames.
#
# [DEBUG] match_14
#    i0 => [OK] Found i0 at vel_time idx=7841, t0=3.921s
#    iH => [OK] Found iH at vel_time idx=7841, tH=3.921s [SHIFT] iH => iH+1s at vel_time idx=11841, tH=5.921s
#    i2 => [OK] Found i2 at vel_time idx=13851, t2=6.926s
#    i3 => [OK] Refined i3 at vel_time idx=30586, t3=15.293s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_14_debug_vel.png
# [SAVED] match_14 => Phase1: 6010 frames, Phase2: 16735 frames.
#
# [DEBUG] match_15
#    i0 => [OK] Found i0 at vel_time idx=5386, t0=2.693s
#    iH => [OK] Found iH at vel_time idx=5386, tH=2.693s [SHIFT] iH => iH+1s at vel_time idx=9386, tH=4.693s
#    i2 => [OK] Found i2 at vel_time idx=11757, t2=5.879s
#    i3 => [OK] Refined i3 at vel_time idx=28425, t3=14.213s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_15_debug_vel.png
# [SAVED] match_15 => Phase1: 6371 frames, Phase2: 16668 frames.
#
# [DEBUG] match_16
#    i0 => [OK] Found i0 at vel_time idx=5045, t0=2.523s
#    iH => [OK] Found iH at vel_time idx=5045, tH=2.523s [SHIFT] iH => iH+1s at vel_time idx=9045, tH=4.523s
#    i2 => [OK] Found i2 at vel_time idx=9446, t2=4.723s
#    i3 => [OK] Refined i3 at vel_time idx=25524, t3=12.762s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_16_debug_vel.png
# [SAVED] match_16 => Phase1: 4401 frames, Phase2: 16078 frames.
#
# [DEBUG] match_17
#    i0 => [OK] Found i0 at vel_time idx=5011, t0=2.506s
#    iH => [OK] Found iH at vel_time idx=5011, tH=2.506s [SHIFT] iH => iH+1s at vel_time idx=9011, tH=4.506s
#    i2 => [OK] Found i2 at vel_time idx=10274, t2=5.137s
#    i3 => [OK] Refined i3 at vel_time idx=25968, t3=12.984s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_17_debug_vel.png
# [SAVED] match_17 => Phase1: 5263 frames, Phase2: 15694 frames.
#
# [DEBUG] match_18
#    i0 => [OK] Found i0 at vel_time idx=6496, t0=3.248s
#    iH => [OK] Found iH at vel_time idx=6496, tH=3.248s [SHIFT] iH => iH+1s at vel_time idx=10496, tH=5.248s
#    i2 => [OK] Found i2 at vel_time idx=12777, t2=6.389s
#    i3 => [OK] Refined i3 at vel_time idx=27372, t3=13.686s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_18_debug_vel.png
# [SAVED] match_18 => Phase1: 6281 frames, Phase2: 14595 frames.
#
# [DEBUG] match_19
#    i0 => [OK] Found i0 at vel_time idx=6496, t0=3.248s
#    iH => [OK] Found iH at vel_time idx=6496, tH=3.248s [SHIFT] iH => iH+1s at vel_time idx=10496, tH=5.248s
#    i2 => [OK] Found i2 at vel_time idx=12777, t2=6.389s
#    i3 => [OK] Refined i3 at vel_time idx=27372, t3=13.686s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_19_debug_vel.png
# [SAVED] match_19 => Phase1: 6281 frames, Phase2: 14595 frames.
#
# [DEBUG] match_20
#    i0 => [OK] Found i0 at vel_time idx=5840, t0=2.920s
#    iH => [OK] Found iH at vel_time idx=5840, tH=2.920s [SHIFT] iH => iH+1s at vel_time idx=9840, tH=4.920s
#    i2 => [OK] Found i2 at vel_time idx=12845, t2=6.423s
#    i3 => [OK] Refined i3 at vel_time idx=30076, t3=15.038s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_20_debug_vel.png
# [SAVED] match_20 => Phase1: 7005 frames, Phase2: 17231 frames.
#
# [DEBUG] match_21
#    i0 => [OK] Found i0 at vel_time idx=5229, t0=2.615s
#    iH => [OK] Found iH at vel_time idx=5229, tH=2.615s [SHIFT] iH => iH+1s at vel_time idx=9229, tH=4.615s
#    i2 => [OK] Found i2 at vel_time idx=11069, t2=5.535s
#    i3 => [OK] Refined i3 at vel_time idx=25932, t3=12.966s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_21_debug_vel.png
# [SAVED] match_21 => Phase1: 5840 frames, Phase2: 14863 frames.
#
# [DEBUG] match_22
#    i0 => [OK] Found i0 at vel_time idx=7976, t0=3.988s
#    iH => [OK] Found iH at vel_time idx=7976, tH=3.988s [SHIFT] iH => iH+1s at vel_time idx=11976, tH=5.988s
#    i2 => [OK] Found i2 at vel_time idx=14875, t2=7.438s
#    i3 => [OK] Refined i3 at vel_time idx=28567, t3=14.284s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_22_debug_vel.png
# [SAVED] match_22 => Phase1: 6899 frames, Phase2: 13692 frames.
#
# [DEBUG] match_23
#    i0 => [OK] Found i0 at vel_time idx=4847, t0=2.424s
#    iH => [OK] Found iH at vel_time idx=4847, tH=2.424s [SHIFT] iH => iH+1s at vel_time idx=8847, tH=4.424s
#    i2 => [OK] Found i2 at vel_time idx=9688, t2=4.844s
#    i3 => [OK] Refined i3 at vel_time idx=24537, t3=12.269s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_23_debug_vel.png
# [SAVED] match_23 => Phase1: 4841 frames, Phase2: 14849 frames.
#
# [DEBUG] match_24
#    i0 => [OK] Found i0 at vel_time idx=7132, t0=3.566s
#    iH => [OK] Found iH at vel_time idx=7132, tH=3.566s [SHIFT] iH => iH+1s at vel_time idx=11132, tH=5.566s
#    i2 => [OK] Found i2 at vel_time idx=12667, t2=6.334s
#    i3 => [OK] Refined i3 at vel_time idx=27172, t3=13.586s
# [SAVED] Debug plot => C:\Users\schmi\Documents\Studium\TUM\5. Semester\Masterthesis\Experimental Data\P(8)\Synchronized Data split in Phases\Plots_Velocity_Debug\match_24_debug_vel.png
# [SAVED] match_24 => Phase1: 5535 frames, Phase2: 14505 frames.
