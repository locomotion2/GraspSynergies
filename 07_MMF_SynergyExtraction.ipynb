# %% [markdown]
# ## Extraction of Combined Kinematic-Muscular Synergies without Pose Data
#
# This Python script performs a detailed muscle and kinematic synergy analysis on preprocessed experimental data for multiple participants. It is designed to be the final processing step, working from standardized data matrices to produce publication-ready results.
#
# **Key Features:**
#
# * **Works from Correctly Preprocessed Data:** The script loads two separate, pre-standardized data matrices (one for phase1, one for phase2) for each participant.
#
# * **Multi-Level Analysis Loop:** It systematically iterates through Participants, number of Synergies, and Trials.
#
# * **Four Distinct, Separate Analyses per Trial:** For every trial, four analyses are conducted and organized under the `Full Phases` and `Lift-Onset` naming convention:
#     * **Full Phases / Phase 1:** Synergies from the complete reach-and-grasp phase.
#     * **Full Phases / Phase 2:** Synergies from the complete lift-and-hold phase.
#     * **Lift-Onset / Pre-Lift:** Synergies from the last 0.5s of Phase 1.
#     * **Lift-Onset / Post-Lift:** Synergies from the first 1.0s of Phase 2.
#
# * **Adaptive MMF Algorithm:** Uses an intelligent Mixed Matrix Factorization (MMF) method with adaptive iterations.
#
# * **Exception Handling:** Handles and flags known missing trials for Participant 7.
#
# * **Organized Output:** All results are saved into a highly organized folder structure.
#
# ```markdown
# └── P(1)/  (Example for a standard participant)
#     └── Synergies Publication/
#         ├── Full Phases/
#         │   ├── Phase 1/
#         │   │   ├── 1_Syn/
#         │   │   │   ├── Trial_01/
#         │   │   │   │   ├── W_synergies.npy
#         │   │   │   │   ├── C_activations.npy
#         │   │   │   │   └── synergies_Full_Phases_Phase_1.png
#         │   │   │   ├── Trial_02/
#         │   │   │   └── ... (up to Trial_24)
#         │   │   ├── 2_Syn/
#         │   │   └── ... (up to 8_Syn)
#         │   │
#         │   └── Phase 2/
#         │       └── ... (same structure as Phase 1)
#         │
#         └── Lift-Onset/
#             ├── Phase 1/
#             │   └── ... (same structure as in Full Phases)
#             │
#             └── Phase 2/
#                 └── ... (same structure as in Full Phases)

# %%
import os
import numpy as np
import joblib
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import gc

# =====================================================================
# 0) Global Parameters & Configuration
# =====================================================================
BASE_DIR = r"C:\Users\schmi\Documents\Studium\TUM\Masterthesis\Experimental Data"
PARTICIPANTS = list(range(1, 9))
PREPROCESSED_DATA_DIR_NAME = "Preprocessed_Data_Matrix"
N_SYNERGIES_TO_ANALYZE = [1,2,3,4,5]         # For Full-Phase
N_SYNERGIES_LIFT_ONSET = [1,3]         # For Lift-Onset

DTYPE = np.float32
P7_SKIPPED_TRIALS = [20, 22]

# MMF Parameters
MU_S = DTYPE(0.1)
LAMBD_S = DTYPE(50.0)
NUM_EMG_CHANNELS = 117
FIXED_ITERATIONS = 5000
COST_TRACKING_INTERVAL = 100
INIT_SCALE = DTYPE(0.05)

# Data & Clipping Parameters
SAMPLING_RATE = 2000.0
PRE_LIFT_CLIP_SECONDS = 1.0
POST_LIFT_CLIP_SECONDS = 1.5
PRE_LIFT_SAMPLES = int(PRE_LIFT_CLIP_SECONDS * SAMPLING_RATE)
POST_LIFT_SAMPLES = int(POST_LIFT_CLIP_SECONDS * SAMPLING_RATE)


# =====================================================================
# 1) Helper Functions (No changes)
# =====================================================================
def trial_info(trial_number):
    """Returns a dictionary with details for a given trial number."""
    protocol = {1: ("Precision Grasp (Four Fingers and Thumb)", "Precision Handle", 0.25, "Left Lever", "No"), 2: ("Precision Grasp (Four Fingers and Thumb)", "Precision Handle", 0.25, "Left Lever", "Yes"), 3: ("Lateral Pinch Grasp", "Lateral Pinch Handle", 0.25, "Right Lever", "No"), 4: ("Lateral Pinch Grasp", "Lateral Pinch Handle", 0.25, "Right Lever", "Yes"), 5: ("Ball Grasp", "Ball Handle", 0.50, "Left Lever", "No"), 6: ("Ball Grasp", "Ball Handle", 0.50, "Left Lever", "Yes"), 7: ("Precision Grasp (Thumb and Index)", "Precision Handle", 0.25, "Front Lever", "No"), 8: ("Precision Grasp (Thumb and Index)", "Precision Handle", 0.25, "Front Lever", "Yes"), 9: ("Disc Grip", "Disc Handle", 0.50, "Back Lever", "No"), 10: ("Disc Grip", "Disc Handle", 0.50, "Back Lever", "Yes"), 11: ("Power Bar Grasp", "Power Bar Handle", 0.50, "Front Lever", "No"), 12: ("Power Bar Grasp", "Power Bar Handle", 0.50, "Front Lever", "Yes"), 13: ("Precision Grasp (Four Fingers and Thumb)", "Precision Handle", 0.25, "Front Lever", "No"), 14: ("Precision Grasp (Four Fingers and Thumb)", "Precision Handle", 0.25, "Front Lever", "Yes"), 15: ("Lateral Pinch Grasp", "Lateral Pinch Handle", 0.25, "Back Lever", "No"), 16: ("Lateral Pinch Grasp", "Lateral Pinch Handle", 0.25, "Back Lever", "Yes"), 17: ("Ball Grasp", "Ball Handle", 0.50, "Front Lever", "No"), 18: ("Ball Grasp", "Ball Handle", 0.50, "Front Lever", "Yes"), 19: ("Precision Grasp (Thumb and Index)", "Precision Handle", 0.25, "Back Lever", "No"), 20: ("Precision Grasp (Thumb and Index)", "Precision Handle", 0.25, "Back Lever", "Yes"), 21: ("Disc Grip", "Disc Handle", 0.50, "Left Lever", "No"), 22: ("Disc Grip", "Disc Handle", 0.50, "Left Lever", "Yes"), 23: ("Power Bar Grasp", "Power Bar Handle", 0.50, "Right Lever", "No"), 24: ("Power Bar Grasp", "Power Bar Handle", 0.50, "Right Lever", "Yes")}
    if trial_number not in protocol: return None
    tup = protocol[trial_number]
    return {'grasp_type': tup[0], 'handle_type': tup[1], 'weight_kg': tup[2], 'lever_side': tup[3], 'knowledge': tup[4]}

def r2_score_matrix(original_2d: np.ndarray, reconstructed_2d: np.ndarray) -> float:
    """Compute R² for two equally‑shaped matrices using float32 throughout."""
    orig = original_2d.astype(DTYPE, copy=False)
    recon = reconstructed_2d.astype(DTYPE, copy=False)
    if not np.isfinite(recon).all():
        return -np.inf
    diff = np.subtract(orig, recon, dtype=DTYPE)
    ss_res = np.sum(diff * diff, dtype=DTYPE)
    mean_orig = np.mean(orig, dtype=DTYPE, keepdims=True)
    diff_tot = np.subtract(orig, mean_orig, dtype=DTYPE)
    ss_tot = np.sum(diff_tot * diff_tot, dtype=DTYPE)
    if ss_tot == 0: return 1.0
    return float(1.0 - (ss_res / ss_tot))

# =====================================================================
# 2) MMF Core & Cost Function (No changes)
# =====================================================================
def calculate_cost(X, W, C, lambd):
    """Calculates the MMF cost function."""
    reconstruction_error = 0.5 * np.sum((X - W @ C)**2)
    regularization_term = 0.5 * lambd * np.sum(W**2)
    return reconstruction_error + regularization_term

def run_mmf_iterations(X, W, C, k, mu_s, lambd_s, num_iters, track_interval):
    """Run MMF updates with an early exit sanity check."""
    n_vars, n_synergies = W.shape
    normX = np.linalg.norm(X.astype(DTYPE, copy=False))
    if normX == 0: return W, C, []

    mu_W = mu_s / normX
    mu_C = mu_s / normX
    lambd = lambd_s / (n_vars * n_synergies)
    cost_history = []
    cost_threshold = 1.2 * (0.5 * normX**2)

    for i in range(num_iters):
        W_update = mu_W * ((X @ C.T) - (W @ (C @ C.T)) - lambd * W)
        C_update = mu_C * ((W.T @ X) - ((W.T @ W) @ C))
        W += W_update.astype(DTYPE)
        C += C_update.astype(DTYPE)
        W[:k, :] = np.maximum(W[:k, :], 0)
        C = np.maximum(C, 0)

        if i == 200:
            cost = calculate_cost(X, W, C, lambd)
            if not np.isfinite(cost) or cost > cost_threshold:
                return None, None, []

        if i % track_interval == 0:
            cost = calculate_cost(X, W, C, lambd)
            cost_history.append(cost)

    return W, C, cost_history


# =====================================================================
# 3) Plotting Function (No changes)
# =====================================================================
def plot_and_save_synergies(W, C, synergy_out_dir, prefix, index_dict, r2_score):
    """Plots synergies with the specified coloring."""
    n_features, n_synergies = W.shape
    if C.shape[0] != n_synergies: raise ValueError("Number of synergies in W and C must match.")
    otb_start, otb_end = index_dict.get('otb_indices', (0,0))
    myo_start, myo_end = index_dict.get('myo_indices', (0,0))
    kin_hand_start, kin_hand_end = index_dict.get('kin_hand_indices', (0,0))

    colors = ["gray"] * n_features
    for i in range(otb_start, otb_end): colors[i] = '#4F81BD'
    for i in range(myo_start, myo_end): colors[i] = 'pink'
    for i in range(kin_hand_start, kin_hand_end): colors[i] = 'orange'

    os.makedirs(synergy_out_dir, exist_ok=True)
    fig_height = 4 * n_synergies
    fig, axes = plt.subplots(n_synergies, 2, figsize=(20, fig_height), squeeze=False)
    fig.suptitle(f'Synergy Analysis for {prefix} | Overall R²: {r2_score:.4f}', fontsize=16, fontweight='bold')

    for i in range(n_synergies):
        ax_bar = axes[i, 0]
        ax_bar.bar(np.arange(n_features), W[:, i], color=colors, alpha=0.7, width=1.0)
        ax_bar.set_title(f"Synergy {i+1} (W column {i+1})", fontsize=14)
        ax_bar.set_xlabel("Variables", fontsize=12)
        ax_bar.set_ylabel("Synergy Component Value", fontsize=12)
        if otb_end > otb_start: ax_bar.text((otb_start + otb_end)/2, ax_bar.get_ylim()[1]*0.95, 'OTB', ha='center', va='top', fontsize=12, color='#4F81BD')
        if myo_end > myo_start: ax_bar.text((myo_start + myo_end)/2, ax_bar.get_ylim()[1]*0.95, 'Myo', ha='center', va='top', fontsize=12, color='pink')
        if kin_hand_end > kin_hand_start: ax_bar.text((kin_hand_start + kin_hand_end)/2, ax_bar.get_ylim()[1]*0.95, 'Kinematic Hand', ha='center', va='top', fontsize=12, color='orange')
        ax_bar.set_xticks([])
        legend_elems = [Patch(facecolor='#4F81BD', label='OTB'), Patch(facecolor='pink', label='Myo'), Patch(facecolor='orange', label='Kinematic Hand')]
        ax_bar.legend(handles=legend_elems, loc='upper left')
        ax_line = axes[i, 1]
        time_axis = np.arange(C.shape[1]) / SAMPLING_RATE
        ax_line.plot(time_axis, C[i, :], label=f'Activation {i+1}', color='green', linewidth=1.5)
        ax_line.set_title(f"Activation {i+1} (C row {i+1})", fontsize=14)
        ax_line.set_xlabel('Time (s)', fontsize=12)
        ax_line.set_ylabel('Activation', fontsize=12)
        ax_line.grid(True, which='both', linestyle='--', linewidth=0.5)

    plt.tight_layout(rect=[0, 0, 1, 0.96])
    out_filename = f"{prefix}_synergies.png"
    out_path = os.path.join(synergy_out_dir, out_filename)
    plt.savefig(out_path, dpi=150)
    plt.close(fig)

def plot_cost_convergence(cost_history, save_dir, prefix):
    """Plots the convergence of the cost function and saves it."""
    if not cost_history:
        return
    fig, ax = plt.subplots(figsize=(10, 6))
    iterations = np.arange(len(cost_history)) * COST_TRACKING_INTERVAL
    ax.plot(iterations, cost_history, marker='.', linestyle='-', color='b')
    ax.set_xlabel('Iteration')
    ax.set_ylabel('Cost Function Value')
    ax.set_title(f'Cost Function Convergence for {prefix}')
    ax.grid(True)
    out_filename = f"{prefix}_cost_convergence.png"
    out_path = os.path.join(save_dir, out_filename)
    plt.savefig(out_path, dpi=150)
    plt.close(fig)

# =====================================================================
# 4) Main Execution Helpers
# =====================================================================

def run_single_mmf(data_matrix: np.ndarray, n_synergies: int, rng: np.random.Generator, W_init=None, C_init=None):
    """Runs MMF, initialized with a provided generator object."""
    if data_matrix is None or data_matrix.shape[0] < 5:
        return None, None, []

    X = data_matrix.T.astype(DTYPE, copy=False)
    n_vars, n_samples = X.shape

    W = rng.random((n_vars, n_synergies), dtype=DTYPE) * INIT_SCALE
    C = rng.random((n_synergies, n_samples), dtype=DTYPE) * INIT_SCALE

    if W_init is not None and C_init is not None and W_init.shape[1] < n_synergies:
        prev_n_syn = W_init.shape[1]
        W[:, :prev_n_syn] = W_init
        C[:prev_n_syn, :] = C_init

    W, C, cost_history = run_mmf_iterations(X, W, C, NUM_EMG_CHANNELS, MU_S, LAMBD_S, FIXED_ITERATIONS, COST_TRACKING_INTERVAL)

    return W, C, cost_history

def run_analysis_block(analysis_path: str, data_matrix: np.ndarray, n_syn: int, trial_idx: int,
                       participant_dir: str, index_dict: dict, is_skipped: bool,
                       master_rng: np.random.Generator, W_init=None, C_init=None): # MODIFIED: Accepts master_rng
    """
    Run and save one full analysis block.
    MODIFIED: Generates and prints a seed for each random repetition.
    """
    analysis_name = os.path.normpath(analysis_path).replace(os.sep, "_")
    save_dir = os.path.join(participant_dir, "Synergies Publication 5X", analysis_path,
                            f"{n_syn}_Syn", f"Trial_{trial_idx:02d}")
    if is_skipped:
        save_dir += "_SKIPPED_TRIAL"
    os.makedirs(save_dir, exist_ok=True)

    if is_skipped or data_matrix is None:
        if is_skipped:
            print("  -> Skipping analysis for this trial as marked.")
        return None, None

    best_r2 = -np.inf
    best_W, best_C, best_cost_history = None, None, []

    if n_syn == 1:
        num_random_reps = 5
        has_warm_start_rep = False
        print(f"  -> Running {analysis_path} for {n_syn} synergy ({num_random_reps} random repetitions)...")
    else:
        num_random_reps = 4
        has_warm_start_rep = True
        print(f"  -> Running {analysis_path} for {n_syn} synergies (1 warm start + {num_random_reps} random repetitions)...")

    total_reps = num_random_reps + (1 if has_warm_start_rep else 0)

    if has_warm_start_rep:
        print(f"    - Repetition 1/{total_reps} (Warm Start with fixed seed: 42)...")
        warm_start_rng = np.random.default_rng(42)
        W, C, cost_history = run_single_mmf(data_matrix, n_syn, warm_start_rng, W_init, C_init)
        if W is not None:
            reconstructed = (W @ C).astype(DTYPE)
            r2 = r2_score_matrix(data_matrix.T.astype(DTYPE, copy=False), reconstructed)
            if r2 > best_r2:
                best_r2, best_W, best_C, best_cost_history = r2, W, C, cost_history
                print(f"      -> R²: {best_r2:.5f} (New Best)")
            else:
                 print(f"      -> R²: {r2:.5f}")
        else:
            print("      -> Run failed (unstable).")

    for i in range(num_random_reps):
        rep_num = i + (2 if has_warm_start_rep else 1)
        # MODIFIED: Generate and print a unique seed for this repetition
        random_seed = master_rng.integers(0, 2**31 - 1)
        print(f"    - Repetition {rep_num}/{total_reps} (Random Start with seed: {random_seed})...")
        
        rep_rng = np.random.default_rng(random_seed)
        W, C, cost_history = run_single_mmf(data_matrix, n_syn, rng=rep_rng)

        if W is not None:
            reconstructed = (W @ C).astype(DTYPE)
            r2 = r2_score_matrix(data_matrix.T.astype(DTYPE, copy=False), reconstructed)
            if r2 > best_r2:
                best_r2, best_W, best_C, best_cost_history = r2, W, C, cost_history
                print(f"      -> R²: {r2:.5f} (New Best)")
            else:
                print(f"      -> R²: {r2:.5f}")
        else:
            print("      -> Run failed (unstable), retrying with new seed.")

    if best_W is None:
        print("  -> MMF failed for all repetitions.")
        return None, None

    print(f"  -> Final best R² for {n_syn} synergies: {best_r2:.5f}")
    np.save(os.path.join(save_dir, "W_synergies.npy"), best_W)
    np.save(os.path.join(save_dir, "C_activations.npy"), best_C)

    plot_prefix = f"synergies_{analysis_name}"
    plot_and_save_synergies(best_W, best_C, save_dir, plot_prefix, index_dict, best_r2)
    plot_cost_convergence(best_cost_history, save_dir, plot_prefix)

    del best_W, best_C, W, C, best_cost_history, cost_history
    gc.collect()

    return np.load(os.path.join(save_dir, "W_synergies.npy")), np.load(os.path.join(save_dir, "C_activations.npy"))

# =====================================================================
# 5) Pipeline Entrypoint
# =====================================================================

def main():
    """
    Main execution function.
    Runs two separate analyses: a clipped "Lift-Onset" analysis and a "Full-Phase" analysis.
    CORRECTED: Ensures that the warm-start for N synergies correctly uses the
    result from the N-1 synergy analysis within the same trial and phase.
    """
    master_rng = np.random.default_rng()

    for pid in PARTICIPANTS:
        participant_str = f"P({pid})"
        participant_dir = os.path.join(BASE_DIR, participant_str)
        pre_dir = os.path.join(participant_dir, PREPROCESSED_DATA_DIR_NAME)

        paths = {
            "p1": os.path.join(pre_dir, f"P{pid}_combined_matrix_phase1.npy"),
            "p2": os.path.join(pre_dir, f"P{pid}_combined_matrix_phase2.npy"),
            "idx": os.path.join(pre_dir, f"P{pid}_feature_indices.joblib")
        }
        if not all(os.path.exists(p) for p in paths.values()):
            print(f"ERROR: Preprocessed files not found for P{pid}. Skipping participant.")
            continue

        print("\n" + "=" * 80 + f"\nProcessing Participant: {pid}\n" + "=" * 80)
        
        p1_full_mmap = np.load(paths["p1"], mmap_mode='r')
        p2_full_mmap = np.load(paths["p2"], mmap_mode='r')
        index_dict = joblib.load(paths["idx"])

        if "phase1_trial_lengths" not in index_dict or "phase2_trial_lengths" not in index_dict:
            print(f"ERROR: Trial length information missing; update preprocessing script.")
            continue

        p1_lens, p2_lens = index_dict["phase1_trial_lengths"], index_dict["phase2_trial_lengths"]
        skip_list = P7_SKIPPED_TRIALS if pid == 7 else []
        valid_trials = [t for t in range(1, 25) if t not in skip_list]

        if len(p1_lens) != len(valid_trials) or len(p2_lens) != len(valid_trials):
            print(f"ERROR: Length mismatch for P{pid} between trials and recorded lengths. Skipping.")
            continue

        p1_map, p2_map = {}, {}
        p1_row, p2_row = 0, 0
        for trial_idx_map, p1_len, p2_len in zip(valid_trials, p1_lens, p2_lens):
            p1_map[trial_idx_map] = (p1_row, p1_row + p1_len)
            p2_map[trial_idx_map] = (p2_row, p2_row + p2_len)
            p1_row += p1_len
            p2_row += p2_len

        for trial_idx in range(1, 25):
            print(f"\n{'*' * 20} Processing Trial {trial_idx} {'*' * 20}")
            is_skip = (pid == 7 and trial_idx in skip_list)
            
            # --- Extract data for BOTH analysis types ---
            lift_p1, lift_p2, full_p1, full_p2 = None, None, None, None
            if not is_skip and trial_idx in p1_map and trial_idx in p2_map:
                p1_sl = slice(*p1_map[trial_idx])
                p2_sl = slice(*p2_map[trial_idx])
                
                # Data for Lift-Onset analysis (clipped)
                lift_p1 = p1_full_mmap[p1_sl][-PRE_LIFT_SAMPLES:].astype(DTYPE)
                lift_p2 = p2_full_mmap[p2_sl][:POST_LIFT_SAMPLES].astype(DTYPE)

                # Data for Full-Phase analysis (un-clipped)
                full_p1 = p1_full_mmap[p1_sl].astype(DTYPE)
                full_p2 = p2_full_mmap[p2_sl].astype(DTYPE)
            else:
                is_skip = True

            # --- 1. LIFT-ONSET ANALYSIS ---
            print("\n--- Running Lift-Onset Analysis (Synergies: 1-3) ---")
            # Initialize warm-start matrices for this trial's Lift-Onset analysis
            prev_W_lift_p1, prev_C_lift_p1 = None, None
            prev_W_lift_p2, prev_C_lift_p2 = None, None
            for n_syn in N_SYNERGIES_LIFT_ONSET:
                print(f"\n-- P{pid}, N_Syn={n_syn}, Trial={trial_idx} --")
                
                path1 = os.path.join("Lift-Onset", "Phase 1")
                W_res_1, C_res_1 = run_analysis_block(path1, lift_p1, n_syn, trial_idx, participant_dir, index_dict, is_skip, master_rng, W_init=prev_W_lift_p1, C_init=prev_C_lift_p1)
                if W_res_1 is not None:
                    prev_W_lift_p1, prev_C_lift_p1 = W_res_1, C_res_1
                
                path2 = os.path.join("Lift-Onset", "Phase 2")
                W_res_2, C_res_2 = run_analysis_block(path2, lift_p2, n_syn, trial_idx, participant_dir, index_dict, is_skip, master_rng, W_init=prev_W_lift_p2, C_init=prev_C_lift_p2)
                if W_res_2 is not None:
                    prev_W_lift_p2, prev_C_lift_p2 = W_res_2, C_res_2

            # --- 2. FULL-PHASE ANALYSIS ---
            print("\n--- Running Full-Phase Analysis (Synergies: 1-7) ---")
            # Initialize warm-start matrices for this trial's Full-Phase analysis
            prev_W_full_p1, prev_C_full_p1 = None, None
            prev_W_full_p2, prev_C_full_p2 = None, None
            for n_syn in N_SYNERGIES_TO_ANALYZE:
                print(f"\n-- P{pid}, N_Syn={n_syn}, Trial={trial_idx} --")

                path1 = os.path.join("Full-Phase", "Phase 1")
                W_res_1, C_res_1 = run_analysis_block(path1, full_p1, n_syn, trial_idx, participant_dir, index_dict, is_skip, master_rng, W_init=prev_W_full_p1, C_init=prev_C_full_p1)
                if W_res_1 is not None:
                    prev_W_full_p1, prev_C_full_p1 = W_res_1, C_res_1

                path2 = os.path.join("Full-Phase", "Phase 2")
                W_res_2, C_res_2 = run_analysis_block(path2, full_p2, n_syn, trial_idx, participant_dir, index_dict, is_skip, master_rng, W_init=prev_W_full_p2, C_init=prev_C_full_p2)
                if W_res_2 is not None:
                    prev_W_full_p2, prev_C_full_p2 = W_res_2, C_res_2

    print("\nSelective regeneration complete for all specified participants and synergy levels.")

if __name__ == "__main__":
    main()
# Out:
# ================================================================================
# Processing Participant: 1
# ================================================================================
#
# ******************** Processing Trial 1 ********************
#
# --- Running Lift-Onset Analysis (Synergies: 1-3) ---
#
# -- P1, N_Syn=1, Trial=1 --
#   -> Running Lift-Onset\Phase 1 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 1248724113)...
#       -> R²: 0.96081 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1994742490)...
#       -> R²: 0.96081
#     - Repetition 3/5 (Random Start with seed: 2052793459)...
#       -> R²: 0.96081
#     - Repetition 4/5 (Random Start with seed: 1053454869)...
#       -> R²: 0.96081
#     - Repetition 5/5 (Random Start with seed: 458307680)...
#       -> R²: 0.96081
#   -> Final best R² for 1 synergies: 0.96081
#   -> Running Lift-Onset\Phase 2 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 580736302)...
#       -> R²: 0.99670 (New Best)
#     - Repetition 2/5 (Random Start with seed: 966756322)...
#       -> R²: 0.99670
#     - Repetition 3/5 (Random Start with seed: 1735965640)...
#       -> R²: 0.99670
#     - Repetition 4/5 (Random Start with seed: 254830629)...
#       -> R²: 0.99670
#     - Repetition 5/5 (Random Start with seed: 246488933)...
#       -> R²: 0.99670
#   -> Final best R² for 1 synergies: 0.99670
#
# -- P1, N_Syn=3, Trial=1 --
#   -> Running Lift-Onset\Phase 1 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99862 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1794534620)...
#       -> R²: 0.99875 (New Best)
#     - Repetition 3/5 (Random Start with seed: 53103559)...
#       -> R²: 0.99874
#     - Repetition 4/5 (Random Start with seed: 168757012)...
#       -> R²: 0.99874
#     - Repetition 5/5 (Random Start with seed: 505839004)...
#       -> R²: 0.99871
#   -> Final best R² for 3 synergies: 0.99875
#   -> Running Lift-Onset\Phase 2 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99906 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1123001675)...
#       -> R²: 0.99951 (New Best)
#     - Repetition 3/5 (Random Start with seed: 272655628)...
#       -> R²: 0.99951 (New Best)
#     - Repetition 4/5 (Random Start with seed: 223480882)...
#       -> R²: 0.99944
#     - Repetition 5/5 (Random Start with seed: 908347924)...
#       -> R²: 0.99950
#   -> Final best R² for 3 synergies: 0.99951
#
# --- Running Full-Phase Analysis (Synergies: 1-7) ---
#
# -- P1, N_Syn=1, Trial=1 --
#   -> Running Full-Phase\Phase 1 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 1935236584)...
#       -> R²: 0.92690 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1354040443)...
#       -> R²: 0.92690
#     - Repetition 3/5 (Random Start with seed: 899650697)...
#       -> R²: 0.92690
#     - Repetition 4/5 (Random Start with seed: 33293678)...
#       -> R²: 0.92690
#     - Repetition 5/5 (Random Start with seed: 569208942)...
#       -> R²: 0.92690
#   -> Final best R² for 1 synergies: 0.92690
#   -> Running Full-Phase\Phase 2 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 1897455618)...
#       -> R²: 0.95254 (New Best)
#     - Repetition 2/5 (Random Start with seed: 785032483)...
#       -> R²: 0.95254
#     - Repetition 3/5 (Random Start with seed: 1180178156)...
#       -> R²: 0.95254
#     - Repetition 4/5 (Random Start with seed: 1616381542)...
#       -> R²: 0.95254
#     - Repetition 5/5 (Random Start with seed: 1524085917)...
#       -> R²: 0.95254
#   -> Final best R² for 1 synergies: 0.95254
#
# -- P1, N_Syn=2, Trial=1 --
#   -> Running Full-Phase\Phase 1 for 2 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.98395 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1225120096)...
#       -> R²: 0.98395 (New Best)
#     - Repetition 3/5 (Random Start with seed: 735847954)...
#       -> R²: 0.98395
#     - Repetition 4/5 (Random Start with seed: 1621599949)...
#       -> R²: 0.98395
#     - Repetition 5/5 (Random Start with seed: 1026683499)...
#       -> R²: 0.98395
#   -> Final best R² for 2 synergies: 0.98395
#   -> Running Full-Phase\Phase 2 for 2 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99501 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1432131754)...
#       -> R²: 0.99499
#     - Repetition 3/5 (Random Start with seed: 1337576915)...
#       -> R²: 0.99499
#     - Repetition 4/5 (Random Start with seed: 312800705)...
#       -> R²: 0.99499
#     - Repetition 5/5 (Random Start with seed: 1019728589)...
#       -> R²: 0.99499
#   -> Final best R² for 2 synergies: 0.99501
#
# -- P1, N_Syn=3, Trial=1 --
#   -> Running Full-Phase\Phase 1 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99374 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1470555947)...
#       -> R²: 0.99377 (New Best)
#     - Repetition 3/5 (Random Start with seed: 110654818)...
#       -> R²: 0.99377
#     - Repetition 4/5 (Random Start with seed: 886056651)...
#       -> R²: 0.99377
#     - Repetition 5/5 (Random Start with seed: 1553017329)...
#       -> R²: 0.99376
#   -> Final best R² for 3 synergies: 0.99377
#   -> Running Full-Phase\Phase 2 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99713 (New Best)
#     - Repetition 2/5 (Random Start with seed: 66489086)...
#       -> R²: 0.99716 (New Best)
#     - Repetition 3/5 (Random Start with seed: 742492691)...
#       -> R²: 0.99715
#     - Repetition 4/5 (Random Start with seed: 283052992)...
#       -> R²: 0.99715
#     - Repetition 5/5 (Random Start with seed: 1131069961)...
#       -> R²: 0.99716 (New Best)
#   -> Final best R² for 3 synergies: 0.99716
#
# -- P1, N_Syn=5, Trial=1 --
#   -> Running Full-Phase\Phase 1 for 5 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99899 (New Best)
#     - Repetition 2/5 (Random Start with seed: 73243401)...
#       -> R²: 0.99892
#     - Repetition 3/5 (Random Start with seed: 749357284)...
#       -> R²: 0.99904 (New Best)
#     - Repetition 4/5 (Random Start with seed: 1828568686)...
#       -> R²: 0.99903
#     - Repetition 5/5 (Random Start with seed: 1809894063)...
#       -> R²: 0.99907 (New Best)
#   -> Final best R² for 5 synergies: 0.99907
#   -> Running Full-Phase\Phase 2 for 5 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99841 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1198890905)...
#       -> R²: 0.99881 (New Best)
#     - Repetition 3/5 (Random Start with seed: 404594924)...
#       -> R²: 0.99874
#     - Repetition 4/5 (Random Start with seed: 1841323953)...
#       -> R²: 0.99880
#     - Repetition 5/5 (Random Start with seed: 1393129226)...
#       -> R²: 0.99881 (New Best)
#   -> Final best R² for 5 synergies: 0.99881
#
# ******************** Processing Trial 2 ********************
#
# --- Running Lift-Onset Analysis (Synergies: 1-3) ---
#
# -- P1, N_Syn=1, Trial=2 --
#   -> Running Lift-Onset\Phase 1 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 389686088)...
#       -> R²: 0.98102 (New Best)
#     - Repetition 2/5 (Random Start with seed: 90268806)...
#       -> R²: 0.98102
#     - Repetition 3/5 (Random Start with seed: 978821476)...
#       -> R²: 0.98102
#     - Repetition 4/5 (Random Start with seed: 166105495)...
#       -> R²: 0.98102
#     - Repetition 5/5 (Random Start with seed: 1148464686)...
#       -> R²: 0.98102
#   -> Final best R² for 1 synergies: 0.98102
#   -> Running Lift-Onset\Phase 2 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 2094771740)...
#       -> R²: 0.97370 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1161892922)...
#       -> R²: 0.97370
#     - Repetition 3/5 (Random Start with seed: 2017713770)...
#       -> R²: 0.97370
#     - Repetition 4/5 (Random Start with seed: 1509773283)...
#       -> R²: 0.97370
#     - Repetition 5/5 (Random Start with seed: 598194981)...
#       -> R²: 0.97370
#   -> Final best R² for 1 synergies: 0.97370
#
# -- P1, N_Syn=3, Trial=2 --
#   -> Running Lift-Onset\Phase 1 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99971 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1945776562)...
#       -> R²: 0.99972 (New Best)
#     - Repetition 3/5 (Random Start with seed: 435166042)...
#       -> R²: 0.99974 (New Best)
#     - Repetition 4/5 (Random Start with seed: 1254500300)...
#       -> R²: 0.99975 (New Best)
#     - Repetition 5/5 (Random Start with seed: 2071590953)...
#       -> R²: 0.99962
#   -> Final best R² for 3 synergies: 0.99975
#   -> Running Lift-Onset\Phase 2 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99891 (New Best)
#     - Repetition 2/5 (Random Start with seed: 954272175)...
#       -> R²: 0.99907 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1284429481)...
#       -> R²: 0.99905
#     - Repetition 4/5 (Random Start with seed: 65372819)...
#       -> R²: 0.99900
#     - Repetition 5/5 (Random Start with seed: 244934823)...
#       -> R²: 0.99904
#   -> Final best R² for 3 synergies: 0.99907
#
# --- Running Full-Phase Analysis (Synergies: 1-7) ---
#
# -- P1, N_Syn=1, Trial=2 --
#   -> Running Full-Phase\Phase 1 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 1334900501)...
#       -> R²: 0.92626 (New Best)
#     - Repetition 2/5 (Random Start with seed: 623420634)...
#       -> R²: 0.92626
#     - Repetition 3/5 (Random Start with seed: 752901313)...
#       -> R²: 0.92626
#     - Repetition 4/5 (Random Start with seed: 1113177892)...
#       -> R²: 0.92626
#     - Repetition 5/5 (Random Start with seed: 1325964016)...
#       -> R²: 0.92626
#   -> Final best R² for 1 synergies: 0.92626
#   -> Running Full-Phase\Phase 2 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 943781859)...
#       -> R²: 0.93475 (New Best)
#     - Repetition 2/5 (Random Start with seed: 488137159)...
#       -> R²: 0.93475
#     - Repetition 3/5 (Random Start with seed: 1884002472)...
#       -> R²: 0.93475
#     - Repetition 4/5 (Random Start with seed: 1181830483)...
#       -> R²: 0.93475
#     - Repetition 5/5 (Random Start with seed: 1381509441)...
#       -> R²: 0.93475
#   -> Final best R² for 1 synergies: 0.93475
#
# -- P1, N_Syn=2, Trial=2 --
#   -> Running Full-Phase\Phase 1 for 2 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.96405 (New Best)
#     - Repetition 2/5 (Random Start with seed: 986911024)...
#       -> R²: 0.96406 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1191279851)...
#       -> R²: 0.96406
#     - Repetition 4/5 (Random Start with seed: 768257512)...
#       -> R²: 0.96406
#     - Repetition 5/5 (Random Start with seed: 1911093586)...
#       -> R²: 0.96406
#   -> Final best R² for 2 synergies: 0.96406
#   -> Running Full-Phase\Phase 2 for 2 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.98214 (New Best)
#     - Repetition 2/5 (Random Start with seed: 565626647)...
#       -> R²: 0.98215 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1353503921)...
#       -> R²: 0.98215
#     - Repetition 4/5 (Random Start with seed: 321054285)...
#       -> R²: 0.98215
#     - Repetition 5/5 (Random Start with seed: 521649053)...
#       -> R²: 0.98215
#   -> Final best R² for 2 synergies: 0.98215
#
# -- P1, N_Syn=3, Trial=2 --
#   -> Running Full-Phase\Phase 1 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.98296 (New Best)
#     - Repetition 2/5 (Random Start with seed: 534266049)...
#       -> R²: 0.98239
#     - Repetition 3/5 (Random Start with seed: 1797251556)...
#       -> R²: 0.98285
#     - Repetition 4/5 (Random Start with seed: 1570241524)...
#       -> R²: 0.98292
#     - Repetition 5/5 (Random Start with seed: 179876202)...
#       -> R²: 0.98300 (New Best)
#   -> Final best R² for 3 synergies: 0.98300
#   -> Running Full-Phase\Phase 2 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99209 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1298606455)...
#       -> R²: 0.99210 (New Best)
#     - Repetition 3/5 (Random Start with seed: 560823385)...
#       -> R²: 0.99210
#     - Repetition 4/5 (Random Start with seed: 247312750)...
#       -> R²: 0.99210 (New Best)
#     - Repetition 5/5 (Random Start with seed: 1883179928)...
#       -> R²: 0.99210 (New Best)
#   -> Final best R² for 3 synergies: 0.99210
#
# -- P1, N_Syn=5, Trial=2 --
#   -> Running Full-Phase\Phase 1 for 5 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99525 (New Best)
#     - Repetition 2/5 (Random Start with seed: 747828393)...
#       -> R²: 0.99527 (New Best)
#     - Repetition 3/5 (Random Start with seed: 761711212)...
#       -> R²: 0.99517
#     - Repetition 4/5 (Random Start with seed: 992436808)...
#       -> R²: 0.99524
#     - Repetition 5/5 (Random Start with seed: 1963045610)...
#       -> R²: 0.99519
#   -> Final best R² for 5 synergies: 0.99527
#   -> Running Full-Phase\Phase 2 for 5 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99708 (New Best)
#     - Repetition 2/5 (Random Start with seed: 631851045)...
#       -> R²: 0.99737 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1627572633)...
#       -> R²: 0.99738 (New Best)
#     - Repetition 4/5 (Random Start with seed: 386188795)...
#       -> R²: 0.99737
#     - Repetition 5/5 (Random Start with seed: 830008795)...
#       -> R²: 0.99740 (New Best)
#   -> Final best R² for 5 synergies: 0.99740
#
# ******************** Processing Trial 3 ********************
#
# --- Running Lift-Onset Analysis (Synergies: 1-3) ---
#
# -- P1, N_Syn=1, Trial=3 --
#   -> Running Lift-Onset\Phase 1 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 285912605)...
#       -> R²: 0.98759 (New Best)
#     - Repetition 2/5 (Random Start with seed: 378861269)...
#       -> R²: 0.98759
#     - Repetition 3/5 (Random Start with seed: 421216941)...
#       -> R²: 0.98759
#     - Repetition 4/5 (Random Start with seed: 1805081222)...
#       -> R²: 0.98759
#     - Repetition 5/5 (Random Start with seed: 891095019)...
#       -> R²: 0.98759
#   -> Final best R² for 1 synergies: 0.98759
#   -> Running Lift-Onset\Phase 2 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 697261110)...
#       -> R²: 0.98321 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1234332997)...
#       -> R²: 0.98321
#     - Repetition 3/5 (Random Start with seed: 514145526)...
#       -> R²: 0.98321
#     - Repetition 4/5 (Random Start with seed: 1312205380)...
#       -> R²: 0.98321
#     - Repetition 5/5 (Random Start with seed: 1969824512)...
#       -> R²: 0.98321
#   -> Final best R² for 1 synergies: 0.98321
#
# -- P1, N_Syn=3, Trial=3 --
#   -> Running Lift-Onset\Phase 1 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99872 (New Best)
#     - Repetition 2/5 (Random Start with seed: 2062178987)...
#       -> R²: 0.99862
#     - Repetition 3/5 (Random Start with seed: 545031501)...
#       -> R²: 0.99875 (New Best)
#     - Repetition 4/5 (Random Start with seed: 697726456)...
#       -> R²: 0.99877 (New Best)
#     - Repetition 5/5 (Random Start with seed: 1385637967)...
#       -> R²: 0.99871
#   -> Final best R² for 3 synergies: 0.99877
#   -> Running Lift-Onset\Phase 2 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99851 (New Best)
#     - Repetition 2/5 (Random Start with seed: 2011437316)...
#       -> R²: 0.99858 (New Best)
#     - Repetition 3/5 (Random Start with seed: 165407628)...
#       -> R²: 0.99856
#     - Repetition 4/5 (Random Start with seed: 716624985)...
#       -> R²: 0.99858
#     - Repetition 5/5 (Random Start with seed: 695259346)...
#       -> R²: 0.99857
#   -> Final best R² for 3 synergies: 0.99858
#
# --- Running Full-Phase Analysis (Synergies: 1-7) ---
#
# -- P1, N_Syn=1, Trial=3 --
#   -> Running Full-Phase\Phase 1 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 531271378)...
#       -> R²: 0.90711 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1895009848)...
#       -> R²: 0.90711
#     - Repetition 3/5 (Random Start with seed: 1187618281)...
#       -> R²: 0.90711
#     - Repetition 4/5 (Random Start with seed: 270098298)...
#       -> R²: 0.90711
#     - Repetition 5/5 (Random Start with seed: 2053240849)...
#       -> R²: 0.90711
#   -> Final best R² for 1 synergies: 0.90711
#   -> Running Full-Phase\Phase 2 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 946708149)...
#       -> R²: 0.96811 (New Best)
#     - Repetition 2/5 (Random Start with seed: 82653362)...
#       -> R²: 0.96811
#     - Repetition 3/5 (Random Start with seed: 38772774)...
#       -> R²: 0.96811
#     - Repetition 4/5 (Random Start with seed: 2017186887)...
#       -> R²: 0.96811
#     - Repetition 5/5 (Random Start with seed: 547651455)...
#       -> R²: 0.96811
#   -> Final best R² for 1 synergies: 0.96811
#
# -- P1, N_Syn=2, Trial=3 --
#   -> Running Full-Phase\Phase 1 for 2 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.95326 (New Best)
#     - Repetition 2/5 (Random Start with seed: 142059249)...
#       -> R²: 0.95327 (New Best)
#     - Repetition 3/5 (Random Start with seed: 763537140)...
#       -> R²: 0.95327
#     - Repetition 4/5 (Random Start with seed: 1211523157)...
#       -> R²: 0.95327
#     - Repetition 5/5 (Random Start with seed: 1798869049)...
#       -> R²: 0.95327
#   -> Final best R² for 2 synergies: 0.95327
#   -> Running Full-Phase\Phase 2 for 2 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.97837 (New Best)
#     - Repetition 2/5 (Random Start with seed: 506537178)...
#       -> R²: 0.97956 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1836587146)...
#       -> R²: 0.97956 (New Best)
#     - Repetition 4/5 (Random Start with seed: 96050915)...
#       -> R²: 0.97956
#     - Repetition 5/5 (Random Start with seed: 993576804)...
#       -> R²: 0.97956
#   -> Final best R² for 2 synergies: 0.97956
#
# -- P1, N_Syn=3, Trial=3 --
#   -> Running Full-Phase\Phase 1 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.98108 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1035313657)...
#       -> R²: 0.98116 (New Best)
#     - Repetition 3/5 (Random Start with seed: 870047860)...
#       -> R²: 0.98114
#     - Repetition 4/5 (Random Start with seed: 905154578)...
#       -> R²: 0.98117 (New Best)
#     - Repetition 5/5 (Random Start with seed: 566446293)...
#       -> R²: 0.98118 (New Best)
#   -> Final best R² for 3 synergies: 0.98118
#   -> Running Full-Phase\Phase 2 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.98861 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1391473830)...
#       -> R²: 0.98862 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1832439835)...
#       -> R²: 0.98862 (New Best)
#     - Repetition 4/5 (Random Start with seed: 1382544100)...
#       -> R²: 0.98861
#     - Repetition 5/5 (Random Start with seed: 73555748)...
#       -> R²: 0.98861
#   -> Final best R² for 3 synergies: 0.98862
#
# -- P1, N_Syn=5, Trial=3 --
#   -> Running Full-Phase\Phase 1 for 5 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99520 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1696435322)...
#       -> R²: 0.99526 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1674307008)...
#       -> R²: 0.99543 (New Best)
#     - Repetition 4/5 (Random Start with seed: 664766247)...
#       -> R²: 0.99528
#     - Repetition 5/5 (Random Start with seed: 1723622131)...
#       -> R²: 0.99543 (New Best)
#   -> Final best R² for 5 synergies: 0.99543
#   -> Running Full-Phase\Phase 2 for 5 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99425 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1516599214)...
#       -> R²: 0.99511 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1593250625)...
#       -> R²: 0.99509
#     - Repetition 4/5 (Random Start with seed: 822377220)...
#       -> R²: 0.99512 (New Best)
#     - Repetition 5/5 (Random Start with seed: 1176436117)...
#       -> R²: 0.99512
#   -> Final best R² for 5 synergies: 0.99512
#
# ******************** Processing Trial 4 ********************
#
# --- Running Lift-Onset Analysis (Synergies: 1-3) ---
#
# -- P1, N_Syn=1, Trial=4 --
#   -> Running Lift-Onset\Phase 1 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 1396245909)...
#       -> R²: 0.99590 (New Best)
#     - Repetition 2/5 (Random Start with seed: 951234448)...
#       -> R²: 0.99590
#     - Repetition 3/5 (Random Start with seed: 681344887)...
#       -> R²: 0.99590
#     - Repetition 4/5 (Random Start with seed: 1786967438)...
#       -> R²: 0.99590
#     - Repetition 5/5 (Random Start with seed: 378142875)...
#       -> R²: 0.99590
#   -> Final best R² for 1 synergies: 0.99590
#   -> Running Lift-Onset\Phase 2 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 1075734892)...
#       -> R²: 0.97721 (New Best)
#     - Repetition 2/5 (Random Start with seed: 2129470963)...
#       -> R²: 0.97721
#     - Repetition 3/5 (Random Start with seed: 472018469)...
#       -> R²: 0.97721
#     - Repetition 4/5 (Random Start with seed: 225616713)...
#       -> R²: 0.97721
#     - Repetition 5/5 (Random Start with seed: 2052075042)...
#       -> R²: 0.97721
#   -> Final best R² for 1 synergies: 0.97721
#
# -- P1, N_Syn=3, Trial=4 --
#   -> Running Lift-Onset\Phase 1 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99906 (New Best)
#     - Repetition 2/5 (Random Start with seed: 2000608123)...
#       -> R²: 0.99945 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1025890640)...
#       -> R²: 0.99945 (New Best)
#     - Repetition 4/5 (Random Start with seed: 808429958)...
#       -> R²: 0.99945 (New Best)
#     - Repetition 5/5 (Random Start with seed: 555751222)...
#       -> R²: 0.99946 (New Best)
#   -> Final best R² for 3 synergies: 0.99946
#   -> Running Lift-Onset\Phase 2 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99819 (New Best)
#     - Repetition 2/5 (Random Start with seed: 73702071)...
#       -> R²: 0.99819 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1494282892)...
#       -> R²: 0.99820 (New Best)
#     - Repetition 4/5 (Random Start with seed: 1940709658)...
#       -> R²: 0.99816
#     - Repetition 5/5 (Random Start with seed: 678249259)...
#       -> R²: 0.99799
#   -> Final best R² for 3 synergies: 0.99820
#
# --- Running Full-Phase Analysis (Synergies: 1-7) ---
#
# -- P1, N_Syn=1, Trial=4 --
#   -> Running Full-Phase\Phase 1 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 147989869)...
#       -> R²: 0.94096 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1673401050)...
#       -> R²: 0.94096
#     - Repetition 3/5 (Random Start with seed: 330249953)...
#       -> R²: 0.94096
#     - Repetition 4/5 (Random Start with seed: 1646449486)...
#       -> R²: 0.94096
#     - Repetition 5/5 (Random Start with seed: 1302986498)...
#       -> R²: 0.94096
#   -> Final best R² for 1 synergies: 0.94096
#   -> Running Full-Phase\Phase 2 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 2081401181)...
#       -> R²: 0.97542 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1338550178)...
#       -> R²: 0.97542
#     - Repetition 3/5 (Random Start with seed: 1168556234)...
#       -> R²: 0.97542
#     - Repetition 4/5 (Random Start with seed: 798991755)...
#       -> R²: 0.97542
#     - Repetition 5/5 (Random Start with seed: 1518305648)...
#       -> R²: 0.97542
#   -> Final best R² for 1 synergies: 0.97542
#
# -- P1, N_Syn=2, Trial=4 --
#   -> Running Full-Phase\Phase 1 for 2 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.97449 (New Best)
#     - Repetition 2/5 (Random Start with seed: 840839831)...
#       -> R²: 0.97449 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1863504670)...
#       -> R²: 0.97449
#     - Repetition 4/5 (Random Start with seed: 203390616)...
#       -> R²: 0.97449
#     - Repetition 5/5 (Random Start with seed: 1481757488)...
#       -> R²: 0.97449
#   -> Final best R² for 2 synergies: 0.97449
#   -> Running Full-Phase\Phase 2 for 2 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.98510 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1880431133)...
#       -> R²: 0.98510 (New Best)
#     - Repetition 3/5 (Random Start with seed: 231686591)...
#       -> R²: 0.98510
#     - Repetition 4/5 (Random Start with seed: 1030232889)...
#       -> R²: 0.98510
#     - Repetition 5/5 (Random Start with seed: 1181662640)...
#       -> R²: 0.98510
#   -> Final best R² for 2 synergies: 0.98510
#
# -- P1, N_Syn=3, Trial=4 --
#   -> Running Full-Phase\Phase 1 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.98762 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1231164627)...
#       -> R²: 0.98766 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1888450984)...
#       -> R²: 0.98770 (New Best)
#     - Repetition 4/5 (Random Start with seed: 2139771394)...
#       -> R²: 0.98770 (New Best)
#     - Repetition 5/5 (Random Start with seed: 1693611394)...
#       -> R²: 0.98766
#   -> Final best R² for 3 synergies: 0.98770
#   -> Running Full-Phase\Phase 2 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99042 (New Best)
#     - Repetition 2/5 (Random Start with seed: 682617051)...
#       -> R²: 0.99047 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1412277179)...
#       -> R²: 0.99046
#     - Repetition 4/5 (Random Start with seed: 525908392)...
#       -> R²: 0.99026
#     - Repetition 5/5 (Random Start with seed: 863842712)...
#       -> R²: 0.99047 (New Best)
#   -> Final best R² for 3 synergies: 0.99047
#
# -- P1, N_Syn=5, Trial=4 --
#   -> Running Full-Phase\Phase 1 for 5 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99512 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1726289739)...
#       -> R²: 0.99506
#     - Repetition 3/5 (Random Start with seed: 540906775)...
#       -> R²: 0.99501
#     - Repetition 4/5 (Random Start with seed: 1374859970)...
#       -> R²: 0.99520 (New Best)
#     - Repetition 5/5 (Random Start with seed: 1225050750)...
#       -> R²: 0.99517
#   -> Final best R² for 5 synergies: 0.99520
#   -> Running Full-Phase\Phase 2 for 5 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99530 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1109183165)...
#       -> R²: 0.99538 (New Best)
#     - Repetition 3/5 (Random Start with seed: 242433112)...
#       -> R²: 0.99535
#     - Repetition 4/5 (Random Start with seed: 1478348345)...
#       -> R²: 0.99542 (New Best)
#     - Repetition 5/5 (Random Start with seed: 1564845508)...
#       -> R²: 0.99536
#   -> Final best R² for 5 synergies: 0.99542
#
# ******************** Processing Trial 5 ********************
#
# --- Running Lift-Onset Analysis (Synergies: 1-3) ---
#
# -- P1, N_Syn=1, Trial=5 --
#   -> Running Lift-Onset\Phase 1 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 1134482097)...
#       -> R²: 0.97621 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1186629980)...
#       -> R²: 0.97621
#     - Repetition 3/5 (Random Start with seed: 1227831628)...
#       -> R²: 0.97621
#     - Repetition 4/5 (Random Start with seed: 1998226040)...
#       -> R²: 0.97621
#     - Repetition 5/5 (Random Start with seed: 2122742101)...
#       -> R²: 0.97621
#   -> Final best R² for 1 synergies: 0.97621
#   -> Running Lift-Onset\Phase 2 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 2129141119)...
#       -> R²: 0.91610 (New Best)
#     - Repetition 2/5 (Random Start with seed: 149040877)...
#       -> R²: 0.91610
#     - Repetition 3/5 (Random Start with seed: 2125018393)...
#       -> R²: 0.91610
#     - Repetition 4/5 (Random Start with seed: 1382439206)...
#       -> R²: 0.91610
#     - Repetition 5/5 (Random Start with seed: 1148731071)...
#       -> R²: 0.91610
#   -> Final best R² for 1 synergies: 0.91610
#
# -- P1, N_Syn=3, Trial=5 --
#   -> Running Lift-Onset\Phase 1 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99570 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1492759842)...
#       -> R²: 0.99641 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1417697707)...
#       -> R²: 0.99644 (New Best)
#     - Repetition 4/5 (Random Start with seed: 1882021692)...
#       -> R²: 0.99643
#     - Repetition 5/5 (Random Start with seed: 409876929)...
#       -> R²: 0.99543
#   -> Final best R² for 3 synergies: 0.99644
#   -> Running Lift-Onset\Phase 2 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99732 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1311433757)...
#       -> R²: 0.99748 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1322623460)...
#       -> R²: 0.99750 (New Best)
#     - Repetition 4/5 (Random Start with seed: 137382629)...
#       -> R²: 0.99750
#     - Repetition 5/5 (Random Start with seed: 2027279096)...
#       -> R²: 0.99750
#   -> Final best R² for 3 synergies: 0.99750
#
# --- Running Full-Phase Analysis (Synergies: 1-7) ---
#
# -- P1, N_Syn=1, Trial=5 --
#   -> Running Full-Phase\Phase 1 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 1281224968)...
#       -> R²: 0.91014 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1775921118)...
#       -> R²: 0.91014
#     - Repetition 3/5 (Random Start with seed: 754108933)...
#       -> R²: 0.91014
#     - Repetition 4/5 (Random Start with seed: 794405875)...
#       -> R²: 0.91014
#     - Repetition 5/5 (Random Start with seed: 1804090299)...
#       -> R²: 0.91014
#   -> Final best R² for 1 synergies: 0.91014
#   -> Running Full-Phase\Phase 2 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 980621832)...
#       -> R²: 0.90985 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1150586843)...
#       -> R²: 0.90985
#     - Repetition 3/5 (Random Start with seed: 540285193)...
#       -> R²: 0.90985
#     - Repetition 4/5 (Random Start with seed: 1333665367)...
#       -> R²: 0.90985
#     - Repetition 5/5 (Random Start with seed: 820950880)...
#       -> R²: 0.90985
#   -> Final best R² for 1 synergies: 0.90985
#
# -- P1, N_Syn=2, Trial=5 --
#   -> Running Full-Phase\Phase 1 for 2 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.95716 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1051666141)...
#       -> R²: 0.95717 (New Best)
#     - Repetition 3/5 (Random Start with seed: 978746358)...
#       -> R²: 0.95717
#     - Repetition 4/5 (Random Start with seed: 301626383)...
#       -> R²: 0.95717
#     - Repetition 5/5 (Random Start with seed: 1851772593)...
#       -> R²: 0.95717
#   -> Final best R² for 2 synergies: 0.95717
#   -> Running Full-Phase\Phase 2 for 2 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.95132 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1896085634)...
#       -> R²: 0.95135 (New Best)
#     - Repetition 3/5 (Random Start with seed: 740990220)...
#       -> R²: 0.95135 (New Best)
#     - Repetition 4/5 (Random Start with seed: 2082986410)...
#       -> R²: 0.95135
#     - Repetition 5/5 (Random Start with seed: 1648682112)...
#       -> R²: 0.95135
#   -> Final best R² for 2 synergies: 0.95135
#
# -- P1, N_Syn=3, Trial=5 --
#   -> Running Full-Phase\Phase 1 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.96974 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1508607912)...
#       -> R²: 0.96934
#     - Repetition 3/5 (Random Start with seed: 1874173009)...
#       -> R²: 0.96940
#     - Repetition 4/5 (Random Start with seed: 945239537)...
#       -> R²: 0.96934
#     - Repetition 5/5 (Random Start with seed: 1128953121)...
#       -> R²: 0.96933
#   -> Final best R² for 3 synergies: 0.96974
#   -> Running Full-Phase\Phase 2 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.98093 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1344210205)...
#       -> R²: 0.98097 (New Best)
#     - Repetition 3/5 (Random Start with seed: 199844346)...
#       -> R²: 0.98067
#     - Repetition 4/5 (Random Start with seed: 283831574)...
#       -> R²: 0.98095
#     - Repetition 5/5 (Random Start with seed: 2041479613)...
#       -> R²: 0.98055
#   -> Final best R² for 3 synergies: 0.98097
#
# -- P1, N_Syn=5, Trial=5 --
#   -> Running Full-Phase\Phase 1 for 5 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.98806 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1494582992)...
#       -> R²: 0.98834 (New Best)
#     - Repetition 3/5 (Random Start with seed: 433348318)...
#       -> R²: 0.98859 (New Best)
#     - Repetition 4/5 (Random Start with seed: 945488341)...
#       -> R²: 0.98835
#     - Repetition 5/5 (Random Start with seed: 1770117866)...
#       -> R²: 0.98842
#   -> Final best R² for 5 synergies: 0.98859
#   -> Running Full-Phase\Phase 2 for 5 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99419 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1348059763)...
#       -> R²: 0.99432 (New Best)
#     - Repetition 3/5 (Random Start with seed: 2064788977)...
#       -> R²: 0.99432
#     - Repetition 4/5 (Random Start with seed: 1938013028)...
#       -> R²: 0.99418
#     - Repetition 5/5 (Random Start with seed: 2084865619)...
#       -> R²: 0.99431
#   -> Final best R² for 5 synergies: 0.99432
#
# ******************** Processing Trial 6 ********************
#
# --- Running Lift-Onset Analysis (Synergies: 1-3) ---
#
# -- P1, N_Syn=1, Trial=6 --
#   -> Running Lift-Onset\Phase 1 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 2054020261)...
#       -> R²: 0.94727 (New Best)
#     - Repetition 2/5 (Random Start with seed: 269200245)...
#       -> R²: 0.94727
#     - Repetition 3/5 (Random Start with seed: 1493340358)...
#       -> R²: 0.94727
#     - Repetition 4/5 (Random Start with seed: 597312125)...
#       -> R²: 0.94727
#     - Repetition 5/5 (Random Start with seed: 170730450)...
#       -> R²: 0.94727
#   -> Final best R² for 1 synergies: 0.94727
#   -> Running Lift-Onset\Phase 2 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 467610158)...
#       -> R²: 0.95156 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1035384412)...
#       -> R²: 0.95156
#     - Repetition 3/5 (Random Start with seed: 519889144)...
#       -> R²: 0.95156
#     - Repetition 4/5 (Random Start with seed: 608756181)...
#       -> R²: 0.95156
#     - Repetition 5/5 (Random Start with seed: 1808288601)...
#       -> R²: 0.95156
#   -> Final best R² for 1 synergies: 0.95156
#
# -- P1, N_Syn=3, Trial=6 --
#   -> Running Lift-Onset\Phase 1 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99715 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1025395989)...
#       -> R²: 0.99722 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1783474161)...
#       -> R²: 0.99722
#     - Repetition 4/5 (Random Start with seed: 1298140202)...
#       -> R²: 0.99722
#     - Repetition 5/5 (Random Start with seed: 2087233675)...
#       -> R²: 0.99722 (New Best)
#   -> Final best R² for 3 synergies: 0.99722
#   -> Running Lift-Onset\Phase 2 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99809 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1013045943)...
#       -> R²: 0.99837 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1129746741)...
#       -> R²: 0.99837
#     - Repetition 4/5 (Random Start with seed: 55734164)...
#       -> R²: 0.99837 (New Best)
#     - Repetition 5/5 (Random Start with seed: 1791748185)...
#       -> R²: 0.99837 (New Best)
#   -> Final best R² for 3 synergies: 0.99837
#
# --- Running Full-Phase Analysis (Synergies: 1-7) ---
#
# -- P1, N_Syn=1, Trial=6 --
#   -> Running Full-Phase\Phase 1 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 346110675)...
#       -> R²: 0.84635 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1075972675)...
#       -> R²: 0.84635
#     - Repetition 3/5 (Random Start with seed: 1060531456)...
#       -> R²: 0.84635
#     - Repetition 4/5 (Random Start with seed: 1891550652)...
#       -> R²: 0.84635
#     - Repetition 5/5 (Random Start with seed: 665703773)...
#       -> R²: 0.84635
#   -> Final best R² for 1 synergies: 0.84635
#   -> Running Full-Phase\Phase 2 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 1833071087)...
#       -> R²: 0.97246 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1265939597)...
#       -> R²: 0.97246
#     - Repetition 3/5 (Random Start with seed: 816149223)...
#       -> R²: 0.97246
#     - Repetition 4/5 (Random Start with seed: 779542663)...
#       -> R²: 0.97246
#     - Repetition 5/5 (Random Start with seed: 1136357550)...
#       -> R²: 0.97246
#   -> Final best R² for 1 synergies: 0.97246
#
# -- P1, N_Syn=2, Trial=6 --
#   -> Running Full-Phase\Phase 1 for 2 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.95537 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1642135516)...
#       -> R²: 0.95537 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1402994526)...
#       -> R²: 0.95537
#     - Repetition 4/5 (Random Start with seed: 2139065404)...
#       -> R²: 0.95537
#     - Repetition 5/5 (Random Start with seed: 621710674)...
#       -> R²: 0.95537
#   -> Final best R² for 2 synergies: 0.95537
#   -> Running Full-Phase\Phase 2 for 2 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.98602 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1497746966)...
#       -> R²: 0.98603 (New Best)
#     - Repetition 3/5 (Random Start with seed: 387603564)...
#       -> R²: 0.98603
#     - Repetition 4/5 (Random Start with seed: 1440252420)...
#       -> R²: 0.98603
#     - Repetition 5/5 (Random Start with seed: 1113869077)...
#       -> R²: 0.98603
#   -> Final best R² for 2 synergies: 0.98603
#
# -- P1, N_Syn=3, Trial=6 --
#   -> Running Full-Phase\Phase 1 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.97786 (New Best)
#     - Repetition 2/5 (Random Start with seed: 420191363)...
#       -> R²: 0.97784
#     - Repetition 3/5 (Random Start with seed: 1010424719)...
#       -> R²: 0.97779
#     - Repetition 4/5 (Random Start with seed: 666540887)...
#       -> R²: 0.97788 (New Best)
#     - Repetition 5/5 (Random Start with seed: 1203061792)...
#       -> R²: 0.97794 (New Best)
#   -> Final best R² for 3 synergies: 0.97794
#   -> Running Full-Phase\Phase 2 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99427 (New Best)
#     - Repetition 2/5 (Random Start with seed: 466383758)...
#       -> R²: 0.99432 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1482832744)...
#       -> R²: 0.99431
#     - Repetition 4/5 (Random Start with seed: 582890642)...
#       -> R²: 0.99432
#     - Repetition 5/5 (Random Start with seed: 394515014)...
#       -> R²: 0.99432
#   -> Final best R² for 3 synergies: 0.99432
#
# -- P1, N_Syn=5, Trial=6 --
#   -> Running Full-Phase\Phase 1 for 5 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99378 (New Best)
#     - Repetition 2/5 (Random Start with seed: 920833882)...
#       -> R²: 0.99377
#     - Repetition 3/5 (Random Start with seed: 893315326)...
#       -> R²: 0.99375
#     - Repetition 4/5 (Random Start with seed: 1692692657)...
#       -> R²: 0.99185
#     - Repetition 5/5 (Random Start with seed: 636504836)...
#       -> R²: 0.99381 (New Best)
#   -> Final best R² for 5 synergies: 0.99381
#   -> Running Full-Phase\Phase 2 for 5 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99693 (New Best)
#     - Repetition 2/5 (Random Start with seed: 805091392)...
#       -> R²: 0.99695 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1418416292)...
#       -> R²: 0.99737 (New Best)
#     - Repetition 4/5 (Random Start with seed: 158600877)...
#       -> R²: 0.99734
#     - Repetition 5/5 (Random Start with seed: 924640226)...
#       -> R²: 0.99737 (New Best)
#   -> Final best R² for 5 synergies: 0.99737
#
# ******************** Processing Trial 7 ********************
#
# --- Running Lift-Onset Analysis (Synergies: 1-3) ---
#
# -- P1, N_Syn=1, Trial=7 --
#   -> Running Lift-Onset\Phase 1 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 1694832858)...
#       -> R²: 0.98561 (New Best)
#     - Repetition 2/5 (Random Start with seed: 804769278)...
#       -> R²: 0.98561
#     - Repetition 3/5 (Random Start with seed: 1151311918)...
#       -> R²: 0.98561
#     - Repetition 4/5 (Random Start with seed: 1275537645)...
#       -> R²: 0.98561
#     - Repetition 5/5 (Random Start with seed: 1909032496)...
#       -> R²: 0.98561
#   -> Final best R² for 1 synergies: 0.98561
#   -> Running Lift-Onset\Phase 2 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 744501042)...
#       -> R²: 0.96593 (New Best)
#     - Repetition 2/5 (Random Start with seed: 576266952)...
#       -> R²: 0.96593
#     - Repetition 3/5 (Random Start with seed: 793519092)...
#       -> R²: 0.96593
#     - Repetition 4/5 (Random Start with seed: 1005427)...
#       -> R²: 0.96593
#     - Repetition 5/5 (Random Start with seed: 819604626)...
#       -> R²: 0.96593
#   -> Final best R² for 1 synergies: 0.96593
#
# -- P1, N_Syn=3, Trial=7 --
#   -> Running Lift-Onset\Phase 1 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99895 (New Best)
#     - Repetition 2/5 (Random Start with seed: 112334036)...
#       -> R²: 0.99901 (New Best)
#     - Repetition 3/5 (Random Start with seed: 78780332)...
#       -> R²: 0.99900
#     - Repetition 4/5 (Random Start with seed: 1387851936)...
#       -> R²: 0.99902 (New Best)
#     - Repetition 5/5 (Random Start with seed: 982194844)...
#       -> R²: 0.99901
#   -> Final best R² for 3 synergies: 0.99902
#   -> Running Lift-Onset\Phase 2 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99892 (New Best)
#     - Repetition 2/5 (Random Start with seed: 745997715)...
#       -> R²: 0.99895 (New Best)
#     - Repetition 3/5 (Random Start with seed: 827911592)...
#       -> R²: 0.99895
#     - Repetition 4/5 (Random Start with seed: 843417912)...
#       -> R²: 0.99895
#     - Repetition 5/5 (Random Start with seed: 872069766)...
#       -> R²: 0.99895
#   -> Final best R² for 3 synergies: 0.99895
#
# --- Running Full-Phase Analysis (Synergies: 1-7) ---
#
# -- P1, N_Syn=1, Trial=7 --
#   -> Running Full-Phase\Phase 1 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 352327221)...
#       -> R²: 0.93913 (New Best)
#     - Repetition 2/5 (Random Start with seed: 843593270)...
#       -> R²: 0.93913
#     - Repetition 3/5 (Random Start with seed: 1478175639)...
#       -> R²: 0.93913
#     - Repetition 4/5 (Random Start with seed: 425941441)...
#       -> R²: 0.93913
#     - Repetition 5/5 (Random Start with seed: 896743452)...
#       -> R²: 0.93913
#   -> Final best R² for 1 synergies: 0.93913
#   -> Running Full-Phase\Phase 2 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 1531799195)...
#       -> R²: 0.97827 (New Best)
#     - Repetition 2/5 (Random Start with seed: 91466265)...
#       -> R²: 0.97827
#     - Repetition 3/5 (Random Start with seed: 1785657967)...
#       -> R²: 0.97827
#     - Repetition 4/5 (Random Start with seed: 1321208812)...
#       -> R²: 0.97827
#     - Repetition 5/5 (Random Start with seed: 313785715)...
#       -> R²: 0.97827
#   -> Final best R² for 1 synergies: 0.97827
#
# -- P1, N_Syn=2, Trial=7 --
#   -> Running Full-Phase\Phase 1 for 2 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.97078 (New Best)
#     - Repetition 2/5 (Random Start with seed: 800171509)...
#       -> R²: 0.97080 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1115190845)...
#       -> R²: 0.97080
#     - Repetition 4/5 (Random Start with seed: 142156673)...
#       -> R²: 0.97080
#     - Repetition 5/5 (Random Start with seed: 1781380890)...
#       -> R²: 0.97080
#   -> Final best R² for 2 synergies: 0.97080
#   -> Running Full-Phase\Phase 2 for 2 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.98662 (New Best)
#     - Repetition 2/5 (Random Start with seed: 13938234)...
#       -> R²: 0.98678 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1372678759)...
#       -> R²: 0.98679 (New Best)
#     - Repetition 4/5 (Random Start with seed: 374465998)...
#       -> R²: 0.98679 (New Best)
#     - Repetition 5/5 (Random Start with seed: 1280816163)...
#       -> R²: 0.98679
#   -> Final best R² for 2 synergies: 0.98679
#
# -- P1, N_Syn=3, Trial=7 --
#   -> Running Full-Phase\Phase 1 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.98389 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1616599764)...
#       -> R²: 0.98389 (New Best)
#     - Repetition 3/5 (Random Start with seed: 2118868618)...
#       -> R²: 0.98388
#     - Repetition 4/5 (Random Start with seed: 782904986)...
#       -> R²: 0.98376
#     - Repetition 5/5 (Random Start with seed: 858817278)...
#       -> R²: 0.98389 (New Best)
#   -> Final best R² for 3 synergies: 0.98389
#   -> Running Full-Phase\Phase 2 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99415 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1544272408)...
#       -> R²: 0.99416 (New Best)
#     - Repetition 3/5 (Random Start with seed: 540812103)...
#       -> R²: 0.99411
#     - Repetition 4/5 (Random Start with seed: 1482647470)...
#       -> R²: 0.99415
# ...
#       -> R²: 0.95651 (New Best)
#     - Repetition 5/5 (Random Start with seed: 45725412)...
#       -> R²: 0.95651
#   -> Final best R² for 3 synergies: 0.95651
#   -> Running Full-Phase\Phase 2 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.98482 (New Best)
#     - Repetition 2/5 (Random Start with seed: 701986014)...
#       -> R²: 0.98481
#     - Repetition 3/5 (Random Start with seed: 371917859)...
#       -> R²: 0.98478
#     - Repetition 4/5 (Random Start with seed: 110227632)...
#       -> R²: 0.98481
#     - Repetition 5/5 (Random Start with seed: 1210998720)...
#       -> R²: 0.98481
#   -> Final best R² for 3 synergies: 0.98482
#
# -- P8, N_Syn=5, Trial=22 --
#   -> Running Full-Phase\Phase 1 for 5 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99459 (New Best)
#     - Repetition 2/5 (Random Start with seed: 2144895550)...
#       -> R²: 0.99457
#     - Repetition 3/5 (Random Start with seed: 733699083)...
#       -> R²: 0.99468 (New Best)
#     - Repetition 4/5 (Random Start with seed: 1566625004)...
#       -> R²: 0.99468 (New Best)
#     - Repetition 5/5 (Random Start with seed: 1231511673)...
#       -> R²: 0.99472 (New Best)
#   -> Final best R² for 5 synergies: 0.99472
#   -> Running Full-Phase\Phase 2 for 5 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99382 (New Best)
#     - Repetition 2/5 (Random Start with seed: 121834367)...
#       -> R²: 0.99411 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1037599253)...
#       -> R²: 0.99413 (New Best)
#     - Repetition 4/5 (Random Start with seed: 1186693786)...
#       -> R²: 0.99408
#     - Repetition 5/5 (Random Start with seed: 2090484438)...
#       -> R²: 0.99408
#   -> Final best R² for 5 synergies: 0.99413
#
# ******************** Processing Trial 23 ********************
#
# --- Running Lift-Onset Analysis (Synergies: 1-3) ---
#
# -- P8, N_Syn=1, Trial=23 --
#   -> Running Lift-Onset\Phase 1 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 495580684)...
#       -> R²: 0.95151 (New Best)
#     - Repetition 2/5 (Random Start with seed: 2063486850)...
#       -> R²: 0.95151
#     - Repetition 3/5 (Random Start with seed: 1356453559)...
#       -> R²: 0.95151
#     - Repetition 4/5 (Random Start with seed: 430347093)...
#       -> R²: 0.95151
#     - Repetition 5/5 (Random Start with seed: 1460693309)...
#       -> R²: 0.95151
#   -> Final best R² for 1 synergies: 0.95151
#   -> Running Lift-Onset\Phase 2 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 182107104)...
#       -> R²: 0.94561 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1492852247)...
#       -> R²: 0.94561
#     - Repetition 3/5 (Random Start with seed: 734801055)...
#       -> R²: 0.94561
#     - Repetition 4/5 (Random Start with seed: 849544957)...
#       -> R²: 0.94561
#     - Repetition 5/5 (Random Start with seed: 1409016099)...
#       -> R²: 0.94561
#   -> Final best R² for 1 synergies: 0.94561
#
# -- P8, N_Syn=3, Trial=23 --
#   -> Running Lift-Onset\Phase 1 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99645 (New Best)
#     - Repetition 2/5 (Random Start with seed: 2145566704)...
#       -> R²: 0.99649 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1971022713)...
#       -> R²: 0.99650 (New Best)
#     - Repetition 4/5 (Random Start with seed: 104229194)...
#       -> R²: 0.99650 (New Best)
#     - Repetition 5/5 (Random Start with seed: 562790690)...
#       -> R²: 0.99650
#   -> Final best R² for 3 synergies: 0.99650
#   -> Running Lift-Onset\Phase 2 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99355 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1320253561)...
#       -> R²: 0.99363 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1817437288)...
#       -> R²: 0.99363
#     - Repetition 4/5 (Random Start with seed: 163118535)...
#       -> R²: 0.99363
#     - Repetition 5/5 (Random Start with seed: 1292063123)...
#       -> R²: 0.99364 (New Best)
#   -> Final best R² for 3 synergies: 0.99364
#
# --- Running Full-Phase Analysis (Synergies: 1-7) ---
#
# -- P8, N_Syn=1, Trial=23 --
#   -> Running Full-Phase\Phase 1 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 1643866900)...
#       -> R²: 0.82640 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1969572624)...
#       -> R²: 0.82640
#     - Repetition 3/5 (Random Start with seed: 1016116507)...
#       -> R²: 0.82640
#     - Repetition 4/5 (Random Start with seed: 969594516)...
#       -> R²: 0.82640
#     - Repetition 5/5 (Random Start with seed: 290275219)...
#       -> R²: 0.82640
#   -> Final best R² for 1 synergies: 0.82640
#   -> Running Full-Phase\Phase 2 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 1664117372)...
#       -> R²: 0.90636 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1326079122)...
#       -> R²: 0.90636
#     - Repetition 3/5 (Random Start with seed: 759967032)...
#       -> R²: 0.90636
#     - Repetition 4/5 (Random Start with seed: 2061029868)...
#       -> R²: 0.90636
#     - Repetition 5/5 (Random Start with seed: 1515201730)...
#       -> R²: 0.90636
#   -> Final best R² for 1 synergies: 0.90636
#
# -- P8, N_Syn=2, Trial=23 --
#   -> Running Full-Phase\Phase 1 for 2 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.91760 (New Best)
#     - Repetition 2/5 (Random Start with seed: 415444958)...
#       -> R²: 0.91760 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1117837690)...
#       -> R²: 0.91760
#     - Repetition 4/5 (Random Start with seed: 880487241)...
#       -> R²: 0.91760
#     - Repetition 5/5 (Random Start with seed: 2060164588)...
#       -> R²: 0.91760
#   -> Final best R² for 2 synergies: 0.91760
#   -> Running Full-Phase\Phase 2 for 2 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.98196 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1386172546)...
#       -> R²: 0.98196 (New Best)
#     - Repetition 3/5 (Random Start with seed: 201446305)...
#       -> R²: 0.98196
#     - Repetition 4/5 (Random Start with seed: 1007140763)...
#       -> R²: 0.98196
#     - Repetition 5/5 (Random Start with seed: 758154052)...
#       -> R²: 0.98196
#   -> Final best R² for 2 synergies: 0.98196
#
# -- P8, N_Syn=3, Trial=23 --
#   -> Running Full-Phase\Phase 1 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.96501 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1970083020)...
#       -> R²: 0.96501
#     - Repetition 3/5 (Random Start with seed: 760164459)...
#       -> R²: 0.96501
#     - Repetition 4/5 (Random Start with seed: 416067154)...
#       -> R²: 0.96501
#     - Repetition 5/5 (Random Start with seed: 877893224)...
#       -> R²: 0.96496
#   -> Final best R² for 3 synergies: 0.96501
#   -> Running Full-Phase\Phase 2 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.98817 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1315834111)...
#       -> R²: 0.98820 (New Best)
#     - Repetition 3/5 (Random Start with seed: 498906401)...
#       -> R²: 0.98819
#     - Repetition 4/5 (Random Start with seed: 869708017)...
#       -> R²: 0.98819
#     - Repetition 5/5 (Random Start with seed: 1132189271)...
#       -> R²: 0.98820
#   -> Final best R² for 3 synergies: 0.98820
#
# -- P8, N_Syn=5, Trial=23 --
#   -> Running Full-Phase\Phase 1 for 5 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99404 (New Best)
#     - Repetition 2/5 (Random Start with seed: 806632253)...
#       -> R²: 0.99410 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1323767082)...
#       -> R²: 0.99407
#     - Repetition 4/5 (Random Start with seed: 1015579186)...
#       -> R²: 0.99403
#     - Repetition 5/5 (Random Start with seed: 257368916)...
#       -> R²: 0.99408
#   -> Final best R² for 5 synergies: 0.99410
#   -> Running Full-Phase\Phase 2 for 5 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99496 (New Best)
#     - Repetition 2/5 (Random Start with seed: 2037550843)...
#       -> R²: 0.99500 (New Best)
#     - Repetition 3/5 (Random Start with seed: 428720684)...
#       -> R²: 0.99513 (New Best)
#     - Repetition 4/5 (Random Start with seed: 358858072)...
#       -> R²: 0.99510
#     - Repetition 5/5 (Random Start with seed: 1219052102)...
#       -> R²: 0.99509
#   -> Final best R² for 5 synergies: 0.99513
#
# ******************** Processing Trial 24 ********************
#
# --- Running Lift-Onset Analysis (Synergies: 1-3) ---
#
# -- P8, N_Syn=1, Trial=24 --
#   -> Running Lift-Onset\Phase 1 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 1754773145)...
#       -> R²: 0.92321 (New Best)
#     - Repetition 2/5 (Random Start with seed: 81555346)...
#       -> R²: 0.92321
#     - Repetition 3/5 (Random Start with seed: 2050445520)...
#       -> R²: 0.92321
#     - Repetition 4/5 (Random Start with seed: 2013445822)...
#       -> R²: 0.92321
#     - Repetition 5/5 (Random Start with seed: 1001808443)...
#       -> R²: 0.92321
#   -> Final best R² for 1 synergies: 0.92321
#   -> Running Lift-Onset\Phase 2 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 224679908)...
#       -> R²: 0.90494 (New Best)
#     - Repetition 2/5 (Random Start with seed: 483759756)...
#       -> R²: 0.90494
#     - Repetition 3/5 (Random Start with seed: 456326980)...
#       -> R²: 0.90494
#     - Repetition 4/5 (Random Start with seed: 1956487026)...
#       -> R²: 0.90494
#     - Repetition 5/5 (Random Start with seed: 573161365)...
#       -> R²: 0.90494
#   -> Final best R² for 1 synergies: 0.90494
#
# -- P8, N_Syn=3, Trial=24 --
#   -> Running Lift-Onset\Phase 1 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99735 (New Best)
#     - Repetition 2/5 (Random Start with seed: 498140474)...
#       -> R²: 0.99736 (New Best)
#     - Repetition 3/5 (Random Start with seed: 571103265)...
#       -> R²: 0.99736 (New Best)
#     - Repetition 4/5 (Random Start with seed: 1386979471)...
#       -> R²: 0.99736
#     - Repetition 5/5 (Random Start with seed: 390349245)...
#       -> R²: 0.99734
#   -> Final best R² for 3 synergies: 0.99736
#   -> Running Lift-Onset\Phase 2 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99530 (New Best)
#     - Repetition 2/5 (Random Start with seed: 879210741)...
#       -> R²: 0.99537 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1701614839)...
#       -> R²: 0.99537
#     - Repetition 4/5 (Random Start with seed: 1608377875)...
#       -> R²: 0.99537 (New Best)
#     - Repetition 5/5 (Random Start with seed: 35356669)...
#       -> R²: 0.99532
#   -> Final best R² for 3 synergies: 0.99537
#
# --- Running Full-Phase Analysis (Synergies: 1-7) ---
#
# -- P8, N_Syn=1, Trial=24 --
#   -> Running Full-Phase\Phase 1 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 127456270)...
#       -> R²: 0.82885 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1889772591)...
#       -> R²: 0.82885
#     - Repetition 3/5 (Random Start with seed: 1909318332)...
#       -> R²: 0.82885
#     - Repetition 4/5 (Random Start with seed: 871308350)...
#       -> R²: 0.82885
#     - Repetition 5/5 (Random Start with seed: 271084465)...
#       -> R²: 0.82885
#   -> Final best R² for 1 synergies: 0.82885
#   -> Running Full-Phase\Phase 2 for 1 synergy (5 random repetitions)...
#     - Repetition 1/5 (Random Start with seed: 352976568)...
#       -> R²: 0.91803 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1179276517)...
#       -> R²: 0.91803
#     - Repetition 3/5 (Random Start with seed: 1994648796)...
#       -> R²: 0.91803
#     - Repetition 4/5 (Random Start with seed: 1626250959)...
#       -> R²: 0.91803
#     - Repetition 5/5 (Random Start with seed: 957100433)...
#       -> R²: 0.91803
#   -> Final best R² for 1 synergies: 0.91803
#
# -- P8, N_Syn=2, Trial=24 --
#   -> Running Full-Phase\Phase 1 for 2 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.89028 (New Best)
#     - Repetition 2/5 (Random Start with seed: 499281027)...
#       -> R²: 0.89039 (New Best)
#     - Repetition 3/5 (Random Start with seed: 572117447)...
#       -> R²: 0.89039
#     - Repetition 4/5 (Random Start with seed: 2008340800)...
#       -> R²: 0.89040 (New Best)
#     - Repetition 5/5 (Random Start with seed: 1129326236)...
#       -> R²: 0.89038
#   -> Final best R² for 2 synergies: 0.89040
#   -> Running Full-Phase\Phase 2 for 2 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.96853 (New Best)
#     - Repetition 2/5 (Random Start with seed: 468633781)...
#       -> R²: 0.96854 (New Best)
#     - Repetition 3/5 (Random Start with seed: 812264044)...
#       -> R²: 0.96854 (New Best)
#     - Repetition 4/5 (Random Start with seed: 461634982)...
#       -> R²: 0.96854
#     - Repetition 5/5 (Random Start with seed: 2054131187)...
#       -> R²: 0.96854
#   -> Final best R² for 2 synergies: 0.96854
#
# -- P8, N_Syn=3, Trial=24 --
#   -> Running Full-Phase\Phase 1 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.94455 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1546720399)...
#       -> R²: 0.94457 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1942372321)...
#       -> R²: 0.94457 (New Best)
#     - Repetition 4/5 (Random Start with seed: 291067850)...
#       -> R²: 0.94456
#     - Repetition 5/5 (Random Start with seed: 994754349)...
#       -> R²: 0.94457
#   -> Final best R² for 3 synergies: 0.94457
#   -> Running Full-Phase\Phase 2 for 3 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.98780 (New Best)
#     - Repetition 2/5 (Random Start with seed: 2079920116)...
#       -> R²: 0.98783 (New Best)
#     - Repetition 3/5 (Random Start with seed: 1111045396)...
#       -> R²: 0.98783
#     - Repetition 4/5 (Random Start with seed: 1911002265)...
#       -> R²: 0.98772
#     - Repetition 5/5 (Random Start with seed: 1994881746)...
#       -> R²: 0.98780
#   -> Final best R² for 3 synergies: 0.98783
#
# -- P8, N_Syn=5, Trial=24 --
#   -> Running Full-Phase\Phase 1 for 5 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99238 (New Best)
#     - Repetition 2/5 (Random Start with seed: 142631613)...
#       -> R²: 0.99219
#     - Repetition 3/5 (Random Start with seed: 1122846465)...
#       -> R²: 0.99229
#     - Repetition 4/5 (Random Start with seed: 500622932)...
#       -> R²: 0.99223
#     - Repetition 5/5 (Random Start with seed: 2048328855)...
#       -> R²: 0.99232
#   -> Final best R² for 5 synergies: 0.99238
#   -> Running Full-Phase\Phase 2 for 5 synergies (1 warm start + 4 random repetitions)...
#     - Repetition 1/5 (Warm Start with fixed seed: 42)...
#       -> R²: 0.99472 (New Best)
#     - Repetition 2/5 (Random Start with seed: 1942102339)...
#       -> R²: 0.99472
#     - Repetition 3/5 (Random Start with seed: 991267620)...
#       -> R²: 0.99462
#     - Repetition 4/5 (Random Start with seed: 468324830)...
#       -> R²: 0.99475 (New Best)
#     - Repetition 5/5 (Random Start with seed: 1025945847)...
#       -> R²: 0.99475 (New Best)
#   -> Final best R² for 5 synergies: 0.99475
#
# Selective regeneration complete for all specified participants and synergy levels.
